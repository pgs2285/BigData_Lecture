# %% [markdown]
# # **Apriori로 연관 분석 구현 방법**

# %%
import apriori

# %%
from imp import reload
reload(apriori)
# Out:
# <module 'apriori' from 'C:\\MLPython3\\Apriori\\apriori.py'>

# %%
dataSet = apriori.loadDataSet()
dataSet
# Out:
# [[1, 3, 4], [2, 3, 5], [1, 2, 3, 5], [2, 5]]

# %%
C1 = apriori.createC1(dataSet)
C1
# Out:
# [frozenset({1}),
#  frozenset({2}),
#  frozenset({3}),
#  frozenset({4}),
#  frozenset({5})]

# %%
D = list(map(set, dataSet))

# %%
L1, suppData0 = apriori.scanD(D, C1, 0.5)

# %%
L, suppData = apriori.apriori(dataSet)

# %%
L
# Out:
# [[frozenset({5}), frozenset({2}), frozenset({3}), frozenset({1})],
#  [frozenset({2, 3}), frozenset({3, 5}), frozenset({2, 5}), frozenset({1, 3})],
#  [frozenset({2, 3, 5})],
#  []]

# %% [markdown]
# L은 빈발 아이템 집합에 대한 목록을 포함하고 있으며, 최소 지지도는 0.5이다. 이를 확인해보자.

# %%
L[0]
# Out:
# [frozenset({5}), frozenset({2}), frozenset({3}), frozenset({1})]

# %%
L[1]
# Out:
# [frozenset({2, 3}), frozenset({3, 5}), frozenset({2, 5}), frozenset({1, 3})]

# %%
L[2]
# Out:
# [frozenset({2, 3, 5})]

# %%
L[3]
# Out:
# []

# %%
suppData
# Out:
# {frozenset({1}): 0.5,
#  frozenset({3}): 0.75,
#  frozenset({4}): 0.25,
#  frozenset({2}): 0.75,
#  frozenset({5}): 0.75,
#  frozenset({1, 3}): 0.5,
#  frozenset({2, 5}): 0.75,
#  frozenset({3, 5}): 0.5,
#  frozenset({2, 3}): 0.5,
#  frozenset({1, 5}): 0.25,
#  frozenset({1, 2}): 0.25,
#  frozenset({2, 3, 5}): 0.5}

# %% [markdown]
# 이들 각각의 아이템 집합은 aprioriGen()과 함께 apriori()에서 생성된다.

# %%
apriori.aprioriGen(L[0], 2)
# Out:
# [frozenset({2, 5}),
#  frozenset({3, 5}),
#  frozenset({1, 5}),
#  frozenset({2, 3}),
#  frozenset({1, 2}),
#  frozenset({1, 3})]

# %% [markdown]
# 여기에 있는 6개의 아이템은 후보 아이템 집합인 Ck이다. 이 아이템들 중 4개는 L[1]에 있고 다른 2개의 아이템은 scanD()에 의해 걸러지게 된다.
# 지지도를 70%로 변경하여 시도해 보자.

# %%
L, suppData = apriori.apriori(dataSet, minSupport=0.7)
L
# Out:
# [[frozenset({5}), frozenset({2}), frozenset({3})], [frozenset({2, 5})], []]

# %% [markdown]
# ## 빈발 아이템 집합으로 연관 규칙 마이닝하기

# %% [markdown]
# 지지도를 0.5로 하는 빈발 아이템 집합을 생성하자.

# %%
L, suppData = apriori.apriori(dataSet, minSupport=0.5)
rules = apriori.generateRules(L, suppData, minConf=0.7)
# Out:
# frozenset({5}) --> frozenset({2}) conf: 1.0
# frozenset({2}) --> frozenset({5}) conf: 1.0
# frozenset({1}) --> frozenset({3}) conf: 1.0

# %%
rules
# Out:
# [(frozenset({5}), frozenset({2}), 1.0),
#  (frozenset({2}), frozenset({5}), 1.0),
#  (frozenset({1}), frozenset({3}), 1.0)]

# %% [markdown]
# 여기서는 {1}-->{3}, {5}-->{2}, {2}-->{5}의 3개의 규칙이 생성되었다. 흥미로운 것은 2와 5를 가지는 규칙은 서로 뒤바뀔 수 있는 반면, 1과 3을 가지는 규칙은 그렇지 않다는 것이다.
# 신뢰도의 임계 값을 더 낮게 설정하고 어떤 규칙이 생성되는지 확인해 보자.

# %%
rules = apriori.generateRules(L, suppData, minConf=0.5)
# Out:
# frozenset({3}) --> frozenset({2}) conf: 0.6666666666666666
# frozenset({2}) --> frozenset({3}) conf: 0.6666666666666666
# frozenset({5}) --> frozenset({3}) conf: 0.6666666666666666
# frozenset({3}) --> frozenset({5}) conf: 0.6666666666666666
# frozenset({5}) --> frozenset({2}) conf: 1.0
# frozenset({2}) --> frozenset({5}) conf: 1.0
# frozenset({3}) --> frozenset({1}) conf: 0.6666666666666666
# frozenset({1}) --> frozenset({3}) conf: 1.0
# frozenset({5}) --> frozenset({2, 3}) conf: 0.6666666666666666
# frozenset({3}) --> frozenset({2, 5}) conf: 0.6666666666666666
# frozenset({2}) --> frozenset({3, 5}) conf: 0.6666666666666666

# %%
rules
# Out:
# [(frozenset({3}), frozenset({2}), 0.6666666666666666),
#  (frozenset({2}), frozenset({3}), 0.6666666666666666),
#  (frozenset({5}), frozenset({3}), 0.6666666666666666),
#  (frozenset({3}), frozenset({5}), 0.6666666666666666),
#  (frozenset({5}), frozenset({2}), 1.0),
#  (frozenset({2}), frozenset({5}), 1.0),
#  (frozenset({3}), frozenset({1}), 0.6666666666666666),
#  (frozenset({1}), frozenset({3}), 1.0),
#  (frozenset({5}), frozenset({2, 3}), 0.6666666666666666),
#  (frozenset({3}), frozenset({2, 5}), 0.6666666666666666),
#  (frozenset({2}), frozenset({3, 5}), 0.6666666666666666)]

# %% [markdown]
# 신뢰도를 더 낮게 설정하여 더 많은 규칙(11개)을 얻게 되었다.

# %% [markdown]
# ## 예제: 장바구니 항목의 연관 분석

# %%
import apriori as ap

# %%
fr = open('groceries.csv')
dataSet = [inst.strip().split(',') for inst in fr.readlines()]

# %%
dataSet
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['beef'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['sausage', 'rolls/buns', 'soda', 'chocolate'],
#  ['other vegetables'],
#  ['brown bread',
#   'soda',
#   'fruit/vegetable juice',
#   'canned beer',
#   'newspapers',
#   'shopping bags'],
#  ['yogurt', 'beverages', 'bottled water', 'specialty bar'],
#  ['hamburger meat',
#   'other vegetables',
#   'rolls/buns',
#   'spices',
#   'bottled water',
#   'hygiene articles',
#   'napkins'],
#  ['root vegetables', 'other vegetables', 'whole milk', 'beverages', 'sugar'],
#  ['pork',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'artif. sweetener',
#   'soda',
#   'abrasive cleaner'],
#  ['beef', 'grapes', 'detergent'],
#  ['pastry', 'soda'],
#  ['fruit/vegetable juice'],
#  ['canned beer'],
#  ['root vegetables', 'other vegetables', 'whole milk', 'dessert'],
#  ['citrus fruit', 'zwieback', 'newspapers'],
#  ['sausage',
#   'rolls/buns',
#   'soda',
#   'canned beer',
#   'specialty bar',
#   'shopping bags'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'domestic eggs',
#   'brown bread',
#   'pastry',
#   'sugar',
#   'cereals',
#   'coffee',
#   'soda',
#   'waffles',
#   'candy'],
#  ['berries', 'yogurt'],
#  ['canned beer'],
#  ['butter milk',
#   'yogurt',
#   'cream cheese',
#   'spread cheese',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'newspapers'],
#  ['coffee'],
#  ['pastry', 'bottled water'],
#  ['rolls/buns'],
#  ['misc. beverages'],
#  ['root vegetables',
#   'other vegetables',
#   'butter',
#   'curd',
#   'whipped/sour cream',
#   'UHT-milk',
#   'hard cheese',
#   'rolls/buns',
#   'bottled water',
#   'long life bakery product'],
#  ['sausage', 'rolls/buns', 'cat food', 'newspapers'],
#  ['canned beer'],
#  ['ham', 'grapes', 'other vegetables', 'whole milk'],
#  ['turkey',
#   'tropical fruit',
#   'other vegetables',
#   'curd',
#   'domestic eggs',
#   'brown bread',
#   'semi-finished bread',
#   'margarine',
#   'baking powder',
#   'fruit/vegetable juice'],
#  ['whole milk', 'yogurt', 'processed cheese', 'pickled vegetables', 'soda'],
#  ['whole milk', 'curd', 'yogurt', 'pastry'],
#  ['packaged fruit/vegetables', 'brown bread', 'canned beer'],
#  ['rolls/buns',
#   'oil',
#   'bottled water',
#   'chewing gum',
#   'chocolate marshmallow',
#   'hygiene articles',
#   'napkins'],
#  ['ham', 'beef', 'whipped/sour cream', 'ice cream', 'rolls/buns', 'cat food'],
#  ['rolls/buns', 'pastry', 'sugar'],
#  ['other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'canned fish',
#   'salty snack',
#   'seasonal products',
#   'detergent'],
#  ['sausage', 'pastry'],
#  ['sausage', 'beef', 'whole milk'],
#  ['frankfurter', 'tropical fruit', 'rolls/buns', 'brown bread', 'sugar'],
#  ['rolls/buns', 'pastry', 'soda'],
#  ['whole milk'],
#  ['curd cheese', 'coffee'],
#  ['red/blush wine', 'newspapers'],
#  ['sausage', 'whole milk', 'curd'],
#  ['tropical fruit',
#   'pip fruit',
#   'berries',
#   'whole milk',
#   'frozen potato products',
#   'rolls/buns',
#   'pickled vegetables',
#   'chocolate'],
#  ['red/blush wine'],
#  ['whole milk',
#   'butter',
#   'margarine',
#   'specialty fat',
#   'specialty chocolate',
#   'candles',
#   'flower (seeds)'],
#  ['frankfurter',
#   'citrus fruit',
#   'whole milk',
#   'domestic eggs',
#   'oil',
#   'sparkling wine',
#   'specialty chocolate',
#   'newspapers'],
#  ['whole milk', 'meat spreads', 'soda'],
#  ['frozen potato products'],
#  ['other vegetables', 'whole milk', 'rolls/buns', 'sugar'],
#  ['citrus fruit', 'whole milk', 'curd', 'butter milk', 'pastry'],
#  ['flour', 'salt', 'bottled water', 'fruit/vegetable juice', 'bottled beer'],
#  ['sugar', 'bottled water', 'soda', 'bottled beer'],
#  ['frozen meals', 'coffee'],
#  ['chocolate'],
#  ['root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'canned vegetables',
#   'fruit/vegetable juice',
#   'bathroom cleaner'],
#  ['root vegetables', 'onions', 'hard cheese', 'frozen vegetables'],
#  ['herbs',
#   'condensed milk',
#   'frozen vegetables',
#   'salt',
#   'oil',
#   'white wine',
#   'candles'],
#  ['bottled water'],
#  ['sausage',
#   'root vegetables',
#   'onions',
#   'yogurt',
#   'rolls/buns',
#   'brandy',
#   'detergent'],
#  ['coffee', 'newspapers'],
#  ['pork', 'other vegetables', 'whipped/sour cream'],
#  ['berries', 'yogurt'],
#  ['soda'],
#  ['berries'],
#  ['fruit/vegetable juice', 'salty snack', 'candles'],
#  ['citrus fruit', 'butter milk', 'yogurt', 'cream cheese'],
#  ['pork',
#   'hamburger meat',
#   'citrus fruit',
#   'berries',
#   'onions',
#   'whipped/sour cream',
#   'rice',
#   'coffee',
#   'chocolate'],
#  ['detergent'],
#  ['grapes', 'photo/film'],
#  ['sausage',
#   'sliced cheese',
#   'rolls/buns',
#   'brown bread',
#   'fruit/vegetable juice',
#   'canned beer',
#   'red/blush wine',
#   'waffles',
#   'shopping bags'],
#  ['chicken',
#   'hamburger meat',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'butter',
#   'pasta',
#   'oil',
#   'detergent'],
#  ['whole milk', 'yogurt', 'brown bread'],
#  ['citrus fruit', 'tropical fruit'],
#  ['soda', 'misc. beverages'],
#  ['sausage',
#   'pork',
#   'grapes',
#   'whole milk',
#   'rolls/buns',
#   'pastry',
#   'soda',
#   'specialty bar',
#   'bathroom cleaner'],
#  ['frankfurter', 'rolls/buns', 'bottled water'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'coffee',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'softener',
#   'napkins',
#   'photo/film',
#   'shopping bags'],
#  ['soda'],
#  ['rolls/buns', 'fruit/vegetable juice'],
#  ['beef',
#   'citrus fruit',
#   'berries',
#   'root vegetables',
#   'brown bread',
#   'detergent'],
#  ['whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'soda',
#   'waffles',
#   'candy',
#   'cling film/bags'],
#  ['processed cheese'],
#  ['tropical fruit', 'pip fruit'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'other vegetables',
#   'rolls/buns',
#   'oil',
#   'pickled vegetables',
#   'bottled beer',
#   'chewing gum',
#   'dishes'],
#  ['packaged fruit/vegetables', 'bottled water'],
#  ['whole milk',
#   'dessert',
#   'frozen vegetables',
#   'rolls/buns',
#   'margarine',
#   'bottled water',
#   'red/blush wine',
#   'newspapers'],
#  ['berries', 'whipped/sour cream'],
#  ['citrus fruit', 'berries', 'UHT-milk', 'processed cheese'],
#  ['tropical fruit', 'whole milk', 'yogurt'],
#  ['hamburger meat',
#   'whole milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'bottled beer',
#   'sparkling wine'],
#  ['hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'domestic eggs',
#   'soda',
#   'dishes'],
#  ['whole milk', 'cream cheese', 'soda'],
#  ['fish',
#   'other vegetables',
#   'pastry',
#   'margarine',
#   'coffee',
#   'long life bakery product',
#   'male cosmetics',
#   'shopping bags'],
#  ['frankfurter', 'sausage', 'long life bakery product', 'waffles'],
#  ['packaged fruit/vegetables',
#   'dessert',
#   'semi-finished bread',
#   'canned beer'],
#  ['pastry', 'soda'],
#  ['other vegetables', 'red/blush wine'],
#  ['misc. beverages'],
#  ['frankfurter',
#   'sausage',
#   'citrus fruit',
#   'tropical fruit',
#   'pip fruit',
#   'whole milk',
#   'hard cheese',
#   'cream cheese',
#   'domestic eggs',
#   'rice',
#   'sugar',
#   'canned fruit',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['sparkling wine'],
#  ['specialty bar'],
#  ['sausage', 'butter milk', 'rolls/buns'],
#  ['curd cheese'],
#  ['frankfurter', 'dessert'],
#  ['whole milk', 'yogurt', 'beverages', 'brown bread', 'shopping bags'],
#  ['newspapers'],
#  ['berries', 'soda'],
#  ['curd', 'flour', 'liquor (appetizer)'],
#  ['tropical fruit', 'other vegetables', 'coffee'],
#  ['soda'],
#  ['rolls/buns', 'Instant food products'],
#  ['canned beer'],
#  ['canned beer'],
#  ['frankfurter', 'sausage', 'whole milk', 'rolls/buns', 'margarine'],
#  ['other vegetables', 'misc. beverages', 'canned beer'],
#  ['whole milk', 'frozen vegetables'],
#  ['whole milk'],
#  ['citrus fruit',
#   'butter',
#   'cream cheese',
#   'white bread',
#   'oil',
#   'margarine',
#   'newspapers'],
#  ['frankfurter', 'rolls/buns'],
#  ['frankfurter',
#   'ham',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'soft cheese',
#   'frozen vegetables',
#   'rolls/buns',
#   'sugar',
#   'baking powder'],
#  ['butter milk', 'yogurt', 'honey', 'soda', 'detergent'],
#  ['hamburger meat',
#   'citrus fruit',
#   'onions',
#   'rolls/buns',
#   'bottled water',
#   'dental care'],
#  ['pasta', 'popcorn'],
#  ['other vegetables',
#   'whole milk',
#   'meat spreads',
#   'cake bar',
#   'chocolate',
#   'shopping bags'],
#  ['sausage',
#   'pork',
#   'citrus fruit',
#   'dessert',
#   'white bread',
#   'dishes',
#   'candles'],
#  ['rolls/buns'],
#  ['grapes', 'other vegetables', 'curd', 'dessert', 'yogurt', 'napkins'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'beverages',
#   'soft cheese',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['coffee', 'shopping bags'],
#  ['popcorn'],
#  ['whole milk', 'rolls/buns', 'sugar', 'bottled water', 'soda'],
#  ['tropical fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'snack products'],
#  ['beef', 'herbs', 'flour', 'cling film/bags', 'flower soil/fertilizer'],
#  ['whole milk', 'butter', 'dessert', 'rolls/buns'],
#  ['frankfurter', 'soda', 'chewing gum'],
#  ['tropical fruit', 'specialty cheese', 'bottled water'],
#  ['canned beer'],
#  ['finished products',
#   'other vegetables',
#   'frozen vegetables',
#   'bottled beer'],
#  ['beverages', 'soda'],
#  ['hamburger meat', 'root vegetables', 'whole milk'],
#  ['whole milk', 'pastry', 'long life bakery product'],
#  ['finished products', 'white wine', 'shopping bags'],
#  ['other vegetables'],
#  ['ham',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'white bread',
#   'brown bread',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['other vegetables'],
#  ['curd', 'butter milk', 'cocoa drinks', 'salty snack', 'popcorn'],
#  ['bottled beer'],
#  ['curd',
#   'dessert',
#   'soda',
#   'salty snack',
#   'waffles',
#   'cake bar',
#   'chocolate',
#   'shopping bags'],
#  ['whole milk', 'cream cheese', 'cereals', 'dog food'],
#  ['whole milk', 'salt'],
#  ['dessert', 'ice cream'],
#  ['sausage', 'soft cheese', 'coffee'],
#  ['other vegetables', 'bottled water', 'waffles', 'dishes', 'shopping bags'],
#  ['ham', 'whole milk', 'rolls/buns'],
#  ['other vegetables', 'ice cream'],
#  ['other vegetables', 'bottled water'],
#  ['soda', 'bottled beer', 'white wine', 'prosecco'],
#  ['herbs', 'candy'],
#  ['frankfurter',
#   'ham',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'soft cheese',
#   'sliced cheese',
#   'cream cheese',
#   'frozen meals',
#   'frozen fish',
#   'domestic eggs',
#   'white bread',
#   'sugar',
#   'cereals',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'waffles'],
#  ['rolls/buns', 'canned beer'],
#  ['curd',
#   'cream cheese',
#   'semi-finished bread',
#   'zwieback',
#   'cake bar',
#   'specialty bar',
#   'shopping bags'],
#  ['frankfurter',
#   'tropical fruit',
#   'whole milk',
#   'spread cheese',
#   'margarine',
#   'shopping bags'],
#  ['other vegetables'],
#  ['dog food'],
#  ['specialty bar'],
#  ['curd', 'salt', 'liquor (appetizer)', 'detergent', 'shopping bags'],
#  ['frankfurter', 'rolls/buns'],
#  ['soda'],
#  ['beef',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'dessert',
#   'spread cheese',
#   'brown bread'],
#  ['canned beer'],
#  ['pork', 'beef', 'pip fruit', 'herbs', 'spices'],
#  ['frankfurter', 'citrus fruit', 'UHT-milk', 'margarine', 'sugar'],
#  ['sausage', 'bottled beer', 'liquor (appetizer)'],
#  ['canned beer'],
#  ['specialty chocolate'],
#  ['curd', 'rolls/buns'],
#  ['canned beer'],
#  ['whole milk', 'bottled water', 'newspapers'],
#  ['rolls/buns', 'chewing gum'],
#  ['pork', 'root vegetables', 'other vegetables', 'whole milk', 'dishes'],
#  ['citrus fruit', 'pastry'],
#  ['potted plants'],
#  ['rolls/buns', 'pastry', 'soda'],
#  ['butter',
#   'yogurt',
#   'bottled water',
#   'soda',
#   'make up remover',
#   'hygiene articles'],
#  ['condensed milk', 'sugar', 'coffee', 'shopping bags'],
#  ['sausage', 'other vegetables', 'yogurt', 'soda', 'shopping bags'],
#  ['whole milk', 'beverages', 'UHT-milk', 'soda'],
#  ['sausage', 'pork', 'beef', 'whole milk', 'rolls/buns', 'margarine'],
#  ['beverages'],
#  ['beverages', 'specialty bar'],
#  ['bottled water', 'fruit/vegetable juice'],
#  ['newspapers'],
#  ['cleaner', 'female sanitary products'],
#  ['sausage', 'soda', 'newspapers', 'shopping bags'],
#  ['newspapers'],
#  ['sausage',
#   'beef',
#   'citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'butter milk',
#   'whipped/sour cream',
#   'beverages',
#   'hard cheese',
#   'rolls/buns',
#   'dish cleaner',
#   'cookware'],
#  ['misc. beverages', 'newspapers'],
#  ['white wine'],
#  ['sausage',
#   'sliced cheese',
#   'rolls/buns',
#   'soda',
#   'canned beer',
#   'shopping bags'],
#  ['meat', 'curd', 'bottled beer', 'cake bar'],
#  ['frankfurter',
#   'meat',
#   'tropical fruit',
#   'onions',
#   'oil',
#   'baking powder',
#   'tea',
#   'cling film/bags'],
#  ['ice cream', 'rolls/buns', 'canned beer'],
#  ['canned beer'],
#  ['tropical fruit',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'bottled water',
#   'shopping bags'],
#  ['meat',
#   'citrus fruit',
#   'other vegetables',
#   'curd',
#   'dessert',
#   'butter milk',
#   'beverages',
#   'cream cheese',
#   'rolls/buns',
#   'brown bread',
#   'tea',
#   'bottled water'],
#  ['whole milk', 'mustard', 'bottled water'],
#  ['sausage',
#   'beef',
#   'beverages',
#   'sliced cheese',
#   'rolls/buns',
#   'spices',
#   'house keeping products',
#   'flower (seeds)'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'butter',
#   'curd',
#   'sliced cheese',
#   'rolls/buns',
#   'salty snack',
#   'long life bakery product'],
#  ['meat', 'other vegetables', 'butter', 'rolls/buns'],
#  ['root vegetables',
#   'beverages',
#   'Instant food products',
#   'pickled vegetables',
#   'detergent'],
#  ['root vegetables',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'sliced cheese',
#   'rolls/buns'],
#  ['whole milk', 'whipped/sour cream', 'semi-finished bread', 'margarine'],
#  ['citrus fruit',
#   'whole milk',
#   'curd',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'frozen dessert',
#   'rolls/buns',
#   'salt',
#   'sugar',
#   'cereals',
#   'canned vegetables',
#   'canned fish',
#   'skin care',
#   'hygiene articles',
#   'napkins'],
#  ['citrus fruit',
#   'curd',
#   'pastry',
#   'margarine',
#   'sugar',
#   'candy',
#   'newspapers'],
#  ['other vegetables',
#   'whole milk',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'bottled beer',
#   'red/blush wine',
#   'napkins'],
#  ['citrus fruit', 'whole milk', 'rolls/buns'],
#  ['sausage', 'oil', 'hygiene articles', 'napkins'],
#  ['frankfurter',
#   'beef',
#   'hamburger meat',
#   'grapes',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'frozen dessert',
#   'potato products',
#   'bottled water',
#   'bottled beer'],
#  ['hard cheese', 'rolls/buns', 'bottled water', 'newspapers'],
#  ['cream cheese', 'rolls/buns', 'soda', 'chocolate'],
#  ['turkey', 'beef', 'frozen vegetables', 'dishes', 'photo/film'],
#  ['pork',
#   'other vegetables',
#   'whipped/sour cream',
#   'rolls/buns',
#   'soda',
#   'shopping bags'],
#  ['whole milk', 'beverages'],
#  ['rolls/buns', 'soda'],
#  ['sausage',
#   'pip fruit',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'bottled water',
#   'hygiene articles'],
#  ['ice cream'],
#  ['liquor'],
#  ['pip fruit', 'other vegetables', 'fruit/vegetable juice'],
#  ['root vegetables', 'other vegetables', 'yogurt'],
#  ['soda'],
#  ['soda'],
#  ['sausage',
#   'citrus fruit',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'chocolate',
#   'newspapers'],
#  ['root vegetables', 'whole milk', 'pet care', 'detergent'],
#  ['pork',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'pastry',
#   'specialty bar'],
#  ['pork'],
#  ['chocolate'],
#  ['fruit/vegetable juice'],
#  ['pickled vegetables', 'coffee'],
#  ['bottled water'],
#  ['frankfurter',
#   'sausage',
#   'butter',
#   'whipped/sour cream',
#   'rolls/buns',
#   'margarine',
#   'spices'],
#  ['tropical fruit',
#   'pip fruit',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'domestic eggs',
#   'sugar',
#   'soups',
#   'tea',
#   'soda',
#   'hygiene articles',
#   'napkins'],
#  ['canned beer'],
#  ['root vegetables'],
#  ['meat', 'citrus fruit', 'berries', 'root vegetables', 'whole milk', 'soda'],
#  ['frankfurter',
#   'rolls/buns',
#   'bottled water',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['tropical fruit', 'margarine', 'rum'],
#  ['tropical fruit',
#   'root vegetables',
#   'herbs',
#   'whole milk',
#   'butter milk',
#   'whipped/sour cream',
#   'flour',
#   'hygiene articles'],
#  ['citrus fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'cream cheese',
#   'domestic eggs',
#   'brown bread',
#   'margarine',
#   'baking powder',
#   'waffles'],
#  ['hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'semi-finished bread',
#   'margarine',
#   'bottled water',
#   'fruit/vegetable juice'],
#  ['chicken',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pasta',
#   'soda',
#   'waffles'],
#  ['chicken',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'frozen fish',
#   'rolls/buns'],
#  ['frankfurter',
#   'citrus fruit',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'rolls/buns',
#   'sugar',
#   'soda'],
#  ['canned beer'],
#  ['turkey', 'pip fruit', 'salad dressing', 'pastry'],
#  ['packaged fruit/vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'domestic eggs',
#   'brown bread',
#   'mustard',
#   'pickled vegetables',
#   'bottled water',
#   'misc. beverages'],
#  ['pasta'],
#  ['citrus fruit', 'tropical fruit'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'brown bread',
#   'potted plants'],
#  ['whole milk', 'frozen meals', 'pastry', 'fruit/vegetable juice', 'waffles'],
#  ['canned beer'],
#  ['citrus fruit', 'sugar', 'sauces'],
#  ['liquor (appetizer)'],
#  ['citrus fruit',
#   'other vegetables',
#   'rolls/buns',
#   'salty snack',
#   'shopping bags'],
#  ['sausage'],
#  ['chicken',
#   'other vegetables',
#   'whole milk',
#   'vinegar',
#   'oil',
#   'bottled water',
#   'canned beer',
#   'napkins',
#   'newspapers'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'specialty cheese',
#   'flour',
#   'margarine'],
#  ['sausage', 'pork', 'other vegetables', 'dessert', 'yogurt', 'oil', 'soda'],
#  ['beef',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'abrasive cleaner'],
#  ['citrus fruit', 'packaged fruit/vegetables', 'yogurt', 'bottled water'],
#  ['UHT-milk', 'coffee'],
#  ['candy'],
#  ['newspapers'],
#  ['beef', 'citrus fruit', 'other vegetables', 'yogurt'],
#  ['sausage', 'rolls/buns'],
#  ['frankfurter',
#   'beef',
#   'root vegetables',
#   'curd',
#   'dessert',
#   'yogurt',
#   'soft cheese',
#   'rolls/buns',
#   'mustard',
#   'pickled vegetables',
#   'canned beer',
#   'hygiene articles',
#   'napkins'],
#  ['canned beer'],
#  ['bottled beer'],
#  ['onions', 'soda', 'chewing gum', 'chocolate', 'newspapers'],
#  ['tropical fruit',
#   'packaged fruit/vegetables',
#   'cream cheese',
#   'white bread',
#   'candy'],
#  ['bottled water', 'white wine'],
#  ['beef', 'white bread', 'pastry', 'pasta', 'soap'],
#  ['sausage',
#   'chicken',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'candy',
#   'abrasive cleaner',
#   'cleaner'],
#  ['hair spray'],
#  ['chicken',
#   'whole milk',
#   'spices',
#   'long life bakery product',
#   'shopping bags'],
#  ['pork', 'citrus fruit', 'brown bread', 'pastry', 'sugar', 'cat food'],
#  ['ice cream'],
#  ['meat', 'hard cheese', 'bottled beer'],
#  ['other vegetables', 'yogurt', 'brown bread', 'instant coffee'],
#  ['bottled water', 'cake bar'],
#  ['tropical fruit', 'soda', 'salty snack'],
#  ['photo/film'],
#  ['sausage',
#   'citrus fruit',
#   'yogurt',
#   'coffee',
#   'soda',
#   'canned beer',
#   'dishes'],
#  ['grapes', 'root vegetables'],
#  ['domestic eggs', 'brown bread', 'photo/film'],
#  ['rolls/buns', 'canned fish', 'canned beer'],
#  ['tropical fruit', 'whole milk'],
#  ['chicken'],
#  ['frankfurter', 'other vegetables', 'yogurt', 'brown bread', 'bottled water'],
#  ['berries',
#   'root vegetables',
#   'other vegetables',
#   'curd',
#   'butter milk',
#   'cream cheese',
#   'roll products',
#   'margarine',
#   'misc. beverages',
#   'specialty chocolate',
#   'detergent'],
#  ['margarine', 'hygiene articles'],
#  ['tropical fruit', 'yogurt', 'rolls/buns', 'soda', 'shopping bags'],
#  ['ham',
#   'other vegetables',
#   'whipped/sour cream',
#   'hard cheese',
#   'rolls/buns',
#   'soda',
#   'misc. beverages',
#   'chocolate',
#   'candy'],
#  ['hamburger meat', 'white bread', 'salty snack'],
#  ['yogurt', 'mayonnaise', 'rolls/buns', 'soda', 'napkins'],
#  ['soda', 'specialty chocolate'],
#  ['yogurt'],
#  ['soda'],
#  ['bottled water'],
#  ['sausage', 'meat', 'hamburger meat', 'rubbing alcohol'],
#  ['citrus fruit',
#   'pip fruit',
#   'beverages',
#   'hard cheese',
#   'pet care',
#   'soda',
#   'fruit/vegetable juice',
#   'waffles'],
#  ['shopping bags'],
#  ['newspapers'],
#  ['frankfurter',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'frozen potato products',
#   'zwieback',
#   'specialty bar',
#   'dish cleaner'],
#  ['sausage', 'citrus fruit', 'whole milk', 'canned beer'],
#  ['frankfurter', 'rolls/buns'],
#  ['salt', 'salty snack', 'cookware'],
#  ['oil'],
#  ['curd',
#   'beverages',
#   'cream cheese',
#   'rolls/buns',
#   'pastry',
#   'soda',
#   'cake bar',
#   'chewing gum'],
#  ['other vegetables', 'butter', 'specialty chocolate'],
#  ['citrus fruit'],
#  ['frankfurter', 'whole milk', 'butter milk'],
#  ['root vegetables',
#   'whole milk',
#   'butter',
#   'processed cheese',
#   'mayonnaise',
#   'salty snack'],
#  ['tropical fruit', 'whole milk', 'frozen meals', 'bottled beer'],
#  ['beef', 'hamburger meat', 'pip fruit'],
#  ['berries', 'whipped/sour cream', 'cereals', 'waffles', 'shopping bags'],
#  ['canned beer'],
#  ['whipped/sour cream', 'canned beer', 'red/blush wine'],
#  ['root vegetables',
#   'domestic eggs',
#   'margarine',
#   'chocolate marshmallow',
#   'candy'],
#  ['whole milk', 'soda'],
#  ['beef'],
#  ['frozen vegetables'],
#  ['rolls/buns', 'bottled beer'],
#  ['whole milk', 'hygiene articles'],
#  ['whole milk'],
#  ['citrus fruit', 'whole milk', 'curd', 'soft cheese'],
#  ['pastry', 'fruit/vegetable juice'],
#  ['frankfurter',
#   'sausage',
#   'pork',
#   'pip fruit',
#   'butter',
#   'processed cheese',
#   'white bread',
#   'brown bread'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'domestic eggs'],
#  ['frankfurter',
#   'sausage',
#   'root vegetables',
#   'yogurt',
#   'whipped/sour cream',
#   'pastry',
#   'napkins'],
#  ['berries',
#   'root vegetables',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'curd',
#   'curd cheese',
#   'cat food',
#   'specialty bar',
#   'detergent'],
#  ['rolls/buns', 'brown bread', 'pastry', 'coffee', 'bottled beer'],
#  ['root vegetables',
#   'packaged fruit/vegetables',
#   'curd',
#   'dessert',
#   'frozen vegetables',
#   'specialty fat',
#   'coffee'],
#  ['yogurt'],
#  ['other vegetables', 'bottled water'],
#  ['berries', 'white bread'],
#  ['berries', 'coffee'],
#  ['other vegetables', 'butter milk', 'frozen meals', 'bottled water'],
#  ['rolls/buns', 'newspapers'],
#  ['ham',
#   'citrus fruit',
#   'whole milk',
#   'whipped/sour cream',
#   'rolls/buns',
#   'pastry',
#   'waffles',
#   'hygiene articles'],
#  ['whole milk', 'frozen dessert', 'salty snack', 'napkins'],
#  ['tropical fruit', 'butter milk', 'rolls/buns', 'bottled water'],
#  ['bottled water'],
#  ['butter milk', 'yogurt'],
#  ['newspapers'],
#  ['coffee'],
#  ['bottled beer', 'liquor'],
#  ['onions',
#   'butter',
#   'whipped/sour cream',
#   'hard cheese',
#   'frozen vegetables',
#   'pasta',
#   'specialty fat',
#   'syrup',
#   'candy',
#   'napkins',
#   'cling film/bags'],
#  ['hamburger meat',
#   'hard cheese',
#   'frozen meals',
#   'pasta',
#   'dog food',
#   'salty snack',
#   'shopping bags'],
#  ['sausage',
#   'liver loaf',
#   'other vegetables',
#   'cream cheese',
#   'pastry',
#   'soap',
#   'shopping bags'],
#  ['hard cheese', 'pastry', 'napkins'],
#  ['sausage', 'tropical fruit', 'condensed milk', 'rolls/buns'],
#  ['hamburger meat'],
#  ['onions', 'whole milk', 'beverages', 'frozen dessert'],
#  ['coffee'],
#  ['shopping bags'],
#  ['yogurt', 'rolls/buns', 'pastry', 'bottled water', 'soda', 'shopping bags'],
#  ['soda'],
#  ['sliced cheese'],
#  ['sausage', 'whole milk', 'coffee'],
#  ['yogurt', 'chocolate'],
#  ['domestic eggs', 'rolls/buns', 'dish cleaner', 'hygiene articles'],
#  ['whole milk'],
#  ['meat', 'other vegetables', 'whole milk', 'whipped/sour cream'],
#  ['dish cleaner', 'bathroom cleaner', 'hygiene articles', 'napkins'],
#  ['other vegetables', 'red/blush wine'],
#  ['whole milk',
#   'butter milk',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'sweet spreads',
#   'coffee',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'shopping bags'],
#  ['other vegetables', 'whole milk', 'rolls/buns', 'Instant food products'],
#  ['tropical fruit', 'other vegetables'],
#  ['baking powder', 'bottled water', 'salty snack', 'chewing gum'],
#  ['specialty bar'],
#  ['ice cream'],
#  ['frankfurter', 'yogurt'],
#  ['canned beer'],
#  ['bottled water'],
#  ['other vegetables',
#   'whole milk',
#   'rolls/buns',
#   'margarine',
#   'bottled water',
#   'bottled beer'],
#  ['citrus fruit',
#   'tropical fruit',
#   'onions',
#   'other vegetables',
#   'shopping bags'],
#  ['sausage',
#   'ham',
#   'hamburger meat',
#   'whole milk',
#   'soda',
#   'softener',
#   'newspapers'],
#  ['domestic eggs', 'rolls/buns', 'specialty bar', 'napkins'],
#  ['pork',
#   'citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'curd',
#   'hygiene articles'],
#  ['specialty cheese',
#   'frozen vegetables',
#   'coffee',
#   'soda',
#   'fruit/vegetable juice',
#   'salty snack'],
#  ['pork',
#   'citrus fruit',
#   'pip fruit',
#   'yogurt',
#   'fruit/vegetable juice',
#   'sparkling wine'],
#  ['beef', 'berries', 'whipped/sour cream', 'domestic eggs', 'rolls/buns'],
#  ['other vegetables', 'pet care'],
#  ['chicken', 'yogurt', 'sliced cheese', 'rolls/buns', 'chewing gum', 'dishes'],
#  ['soda', 'chewing gum'],
#  ['whole milk'],
#  ['rolls/buns'],
#  ['bottled beer'],
#  ['root vegetables', 'pastry', 'bottled water', 'male cosmetics'],
#  ['pastry'],
#  ['berries', 'pet care', 'cake bar', 'shopping bags'],
#  ['citrus fruit',
#   'tropical fruit',
#   'root vegetables',
#   'yogurt',
#   'canned vegetables',
#   'bottled water',
#   'soda',
#   'softener'],
#  ['whole milk', 'oil', 'canned fruit', 'fruit/vegetable juice'],
#  ['soda', 'misc. beverages'],
#  ['bottled water', 'soda'],
#  ['tropical fruit', 'other vegetables', 'rolls/buns'],
#  ['salty snack'],
#  ['bottled water', 'canned beer'],
#  ['chocolate'],
#  ['citrus fruit', 'UHT-milk', 'cream cheese', 'frozen vegetables'],
#  ['bottled water', 'canned beer', 'male cosmetics'],
#  ['onions', 'other vegetables', 'pastry', 'bottled water', 'soda', 'napkins'],
#  ['dessert', 'oil', 'cat food', 'soda'],
#  ['beef',
#   'other vegetables',
#   'whole milk',
#   'frozen potato products',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'coffee',
#   'dental care',
#   'hygiene articles',
#   'newspapers'],
#  ['rolls/buns',
#   'zwieback',
#   'bottled water',
#   'misc. beverages',
#   'bottled beer',
#   'canned beer',
#   'brandy'],
#  ['beef',
#   'tropical fruit',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'instant coffee',
#   'soda'],
#  ['soda'],
#  ['coffee', 'hygiene articles'],
#  ['rolls/buns', 'brown bread', 'bottled water'],
#  ['pork',
#   'beef',
#   'hamburger meat',
#   'other vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'margarine',
#   'shopping bags'],
#  ['soda',
#   'canned beer',
#   'liquor (appetizer)',
#   'hygiene articles',
#   'napkins',
#   'newspapers'],
#  ['sausage', 'ham', 'other vegetables', 'ice cream', 'white bread'],
#  ['beef', 'root vegetables', 'other vegetables', 'rolls/buns', 'sugar'],
#  ['whole milk', 'butter', 'bottled water', 'bottled beer'],
#  ['pork', 'ice cream', 'hygiene articles', 'house keeping products'],
#  ['berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'ice cream',
#   'fruit/vegetable juice',
#   'salty snack',
#   'specialty bar'],
#  ['sausage',
#   'other vegetables',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'rolls/buns',
#   'roll products'],
#  ['bottled water', 'misc. beverages', 'cling film/bags'],
#  ['tropical fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'hard cheese',
#   'frozen dessert',
#   'rice',
#   'bottled water'],
#  ['herbs', 'bottled water'],
#  ['yogurt', 'rolls/buns'],
#  ['Instant food products'],
#  ['specialty chocolate'],
#  ['coffee'],
#  ['bottled beer', 'liquor'],
#  ['beef', 'root vegetables'],
#  ['whole milk', 'honey', 'waffles'],
#  ['frankfurter', 'rolls/buns', 'pastry', 'snack products', 'specialty bar'],
#  ['frankfurter',
#   'sausage',
#   'liver loaf',
#   'root vegetables',
#   'curd',
#   'frozen vegetables',
#   'rolls/buns',
#   'semi-finished bread',
#   'hygiene articles',
#   'photo/film'],
#  ['other vegetables', 'whole milk', 'cream cheese'],
#  ['frankfurter',
#   'root vegetables',
#   'pickled vegetables',
#   'soda',
#   'seasonal products'],
#  ['whole milk', 'rolls/buns', 'newspapers'],
#  ['frankfurter', 'margarine', 'dental care'],
#  ['other vegetables', 'salty snack'],
#  ['bottled water', 'shopping bags'],
#  ['pork',
#   'onions',
#   'whole milk',
#   'butter',
#   'rolls/buns',
#   'pastry',
#   'rum',
#   'hygiene articles'],
#  ['bottled water'],
#  ['other vegetables',
#   'whipped/sour cream',
#   'specialty cheese',
#   'domestic eggs'],
#  ['hamburger meat', 'whole milk', 'curd', 'pasta', 'canned beer'],
#  ['hamburger meat', 'citrus fruit', 'other vegetables'],
#  ['shopping bags'],
#  ['whole milk', 'cream cheese', 'soda', 'fruit/vegetable juice'],
#  ['ice cream'],
#  ['pastry', 'bottled water'],
#  ['ham',
#   'pip fruit',
#   'whole milk',
#   'curd',
#   'dessert',
#   'butter milk',
#   'whipped/sour cream',
#   'sliced cheese',
#   'cream cheese',
#   'white bread',
#   'coffee',
#   'long life bakery product',
#   'chocolate',
#   'baby cosmetics'],
#  ['frankfurter', 'soda'],
#  ['sausage',
#   'turkey',
#   'beef',
#   'root vegetables',
#   'domestic eggs',
#   'rolls/buns',
#   'flour',
#   'rice',
#   'organic products',
#   'misc. beverages',
#   'napkins'],
#  ['bottled beer'],
#  ['bottled water', 'bottled beer', 'napkins'],
#  ['meat',
#   'other vegetables',
#   'hard cheese',
#   'frozen meals',
#   'bottled water',
#   'soda'],
#  ['dessert', 'candy'],
#  ['other vegetables',
#   'packaged fruit/vegetables',
#   'UHT-milk',
#   'bottled water'],
#  ['beverages', 'rolls/buns', 'soda'],
#  ['ham', 'mustard', 'canned fish'],
#  ['specialty bar'],
#  ['brown bread', 'soda', 'salty snack', 'shopping bags'],
#  ['whole milk', 'cream cheese', 'coffee'],
#  ['rolls/buns', 'pastry', 'red/blush wine'],
#  ['bottled beer', 'nut snack'],
#  ['pet care', 'bottled beer'],
#  ['citrus fruit', 'other vegetables', 'soda'],
#  ['pork', 'other vegetables', 'frozen vegetables', 'hygiene articles'],
#  ['other vegetables', 'shopping bags'],
#  ['white wine', 'detergent'],
#  ['whole milk', 'dessert', 'bottled water'],
#  ['pip fruit', 'white wine', 'shopping bags'],
#  ['sugar', 'soda', 'bottled beer'],
#  ['tropical fruit',
#   'pip fruit',
#   'rolls/buns',
#   'coffee',
#   'fruit/vegetable juice',
#   'candy'],
#  ['root vegetables',
#   'cream cheese',
#   'spread cheese',
#   'frozen dessert',
#   'white bread',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['soda', 'misc. beverages'],
#  ['whole milk', 'curd'],
#  ['tropical fruit',
#   'other vegetables',
#   'yogurt',
#   'bottled water',
#   'male cosmetics'],
#  ['white bread', 'brown bread'],
#  ['brown bread', 'sugar', 'hygiene articles'],
#  ['tropical fruit',
#   'root vegetables',
#   'coffee',
#   'bottled water',
#   'red/blush wine',
#   'candy',
#   'house keeping products',
#   'shopping bags'],
#  ['domestic eggs'],
#  ['coffee', 'detergent', 'hygiene articles', 'photo/film'],
#  ['soda'],
#  ['whole milk'],
#  ['bottled beer'],
#  ['pork',
#   'beef',
#   'berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'mayonnaise',
#   'frozen fish',
#   'frozen potato products',
#   'oil',
#   'mustard',
#   'cat food',
#   'coffee',
#   'soda',
#   'chocolate',
#   'dish cleaner',
#   'napkins',
#   'newspapers'],
#  ['other vegetables', 'yogurt'],
#  ['yogurt', 'bottled water', 'dishes'],
#  ['sparkling wine'],
#  ['bottled water', 'candy'],
#  ['citrus fruit',
#   'berries',
#   'other vegetables',
#   'butter milk',
#   'sugar',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'rolls/buns'],
#  ['packaged fruit/vegetables', 'seasonal products'],
#  ['other vegetables', 'margarine'],
#  ['soda'],
#  ['whole milk',
#   'yogurt',
#   'frozen potato products',
#   'margarine',
#   'bottled water',
#   'fruit/vegetable juice',
#   'salty snack'],
#  ['herbs', 'yogurt'],
#  ['citrus fruit', 'spread cheese', 'rolls/buns', 'soda'],
#  ['misc. beverages'],
#  ['female sanitary products'],
#  ['soda'],
#  ['tropical fruit',
#   'whole milk',
#   'beverages',
#   'white bread',
#   'pasta',
#   'shopping bags'],
#  ['soda', 'female sanitary products'],
#  ['white bread', 'bottled water', 'soda', 'waffles'],
#  ['coffee', 'chewing gum', 'chocolate marshmallow'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'honey',
#   'baking powder',
#   'coffee',
#   'red/blush wine',
#   'chocolate marshmallow'],
#  ['pork', 'pip fruit', 'whole milk', 'butter milk'],
#  ['citrus fruit', 'bottled water'],
#  ['frankfurter'],
#  ['frankfurter', 'rolls/buns'],
#  ['frankfurter',
#   'tropical fruit',
#   'pip fruit',
#   'curd',
#   'UHT-milk',
#   'hard cheese',
#   'domestic eggs',
#   'rolls/buns',
#   'hygiene articles',
#   'napkins',
#   'shopping bags'],
#  ['other vegetables'],
#  ['yogurt', 'fruit/vegetable juice', 'newspapers'],
#  ['sausage',
#   'whole milk',
#   'yogurt',
#   'brown bread',
#   'cereals',
#   'bottled water',
#   'soda'],
#  ['whole milk'],
#  ['pip fruit', 'whole milk', 'curd', 'pastry', 'bottled water'],
#  ['whole milk'],
#  ['root vegetables', 'other vegetables'],
#  ['onions', 'fruit/vegetable juice'],
#  ['specialty chocolate'],
#  ['hamburger meat', 'domestic eggs'],
#  ['photo/film'],
#  ['rolls/buns', 'soda', 'snack products', 'newspapers'],
#  ['canned beer'],
#  ['canned beer'],
#  ['other vegetables',
#   'curd',
#   'frozen meals',
#   'frozen potato products',
#   'soda',
#   'bottled beer',
#   'kitchen towels',
#   'candles'],
#  ['canned beer'],
#  ['curd', 'whipped/sour cream', 'rolls/buns', 'zwieback', 'spices'],
#  ['butter', 'fruit/vegetable juice', 'newspapers'],
#  ['other vegetables',
#   'whole milk',
#   'yogurt',
#   'domestic eggs',
#   'bottled water',
#   'soda'],
#  ['whole milk'],
#  ['beef',
#   'tropical fruit',
#   'herbs',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'sliced cheese'],
#  ['sausage', 'rolls/buns'],
#  ['soda'],
#  ['fruit/vegetable juice', 'long life bakery product'],
#  ['rolls/buns',
#   'coffee',
#   'long life bakery product',
#   'detergent',
#   'shopping bags'],
#  ['pip fruit', 'whole milk', 'bottled water', 'candy'],
#  ['frozen vegetables',
#   'bottled beer',
#   'liquor (appetizer)',
#   'chewing gum',
#   'napkins',
#   'newspapers'],
#  ['beverages'],
#  ['hamburger meat',
#   'root vegetables',
#   'other vegetables',
#   'domestic eggs',
#   'roll products',
#   'oil',
#   'margarine',
#   'hygiene articles'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'fruit/vegetable juice',
#   'white wine'],
#  ['canned beer'],
#  ['frozen vegetables', 'bottled beer'],
#  ['canned beer'],
#  ['newspapers'],
#  ['rolls/buns'],
#  ['hamburger meat', 'UHT-milk', 'salty snack'],
#  ['pip fruit', 'whole milk', 'curd', 'rum'],
#  ['canned beer'],
#  ['grapes',
#   'root vegetables',
#   'frozen vegetables',
#   'domestic eggs',
#   'white wine'],
#  ['root vegetables',
#   'packaged fruit/vegetables',
#   'butter',
#   'whipped/sour cream',
#   'rolls/buns'],
#  ['citrus fruit',
#   'frozen vegetables',
#   'rolls/buns',
#   'canned beer',
#   'salty snack'],
#  ['cling film/bags', 'potted plants'],
#  ['frankfurter',
#   'whole milk',
#   'rolls/buns',
#   'margarine',
#   'baking powder',
#   'bottled beer'],
#  ['whole milk', 'red/blush wine'],
#  ['pork',
#   'tropical fruit',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'hard cheese',
#   'frozen meals',
#   'frozen dessert',
#   'domestic eggs',
#   'cereals',
#   'baking powder',
#   'fruit/vegetable juice',
#   'soap'],
#  ['chicken', 'pastry'],
#  ['sausage', 'dish cleaner', 'dishes'],
#  ['specialty bar'],
#  ['whipped/sour cream', 'pastry', 'specialty bar'],
#  ['root vegetables', 'brown bread'],
#  ['rolls/buns', 'soda'],
#  ['other vegetables', 'bottled beer', 'red/blush wine'],
#  ['citrus fruit',
#   'tropical fruit',
#   'berries',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'bottled water',
#   'rubbing alcohol',
#   'hygiene articles',
#   'napkins'],
#  ['whole milk', 'processed cheese', 'brown bread', 'pastry', 'soda'],
#  ['frankfurter',
#   'sausage',
#   'tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'candy'],
#  ['coffee', 'long life bakery product'],
#  ['ham', 'rolls/buns', 'white wine'],
#  ['canned beer'],
#  ['canned beer'],
#  ['canned beer'],
#  ['pip fruit', 'whole milk', 'canned fish'],
#  ['pork',
#   'pip fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'white bread',
#   'sugar',
#   'bottled water',
#   'soda'],
#  ['soap'],
#  ['pip fruit', 'butter', 'frozen meals', 'pasta', 'bottled water'],
#  ['beef', 'hamburger meat', 'citrus fruit', 'whole milk', 'mustard', 'soap'],
#  ['sausage',
#   'meat',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'soda',
#   'bottled beer',
#   'chocolate',
#   'newspapers'],
#  ['frozen chicken'],
#  ['soda'],
#  ['tropical fruit',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'brown bread',
#   'bottled water',
#   'bottled beer',
#   'seasonal products'],
#  ['other vegetables'],
#  ['beef',
#   'citrus fruit',
#   'curd',
#   'rolls/buns',
#   'oil',
#   'margarine',
#   'specialty bar',
#   'detergent',
#   'newspapers'],
#  ['meat',
#   'pork',
#   'beef',
#   'citrus fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'pickled vegetables'],
#  ['meat',
#   'hamburger meat',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'butter',
#   'newspapers'],
#  ['bottled water',
#   'soda',
#   'red/blush wine',
#   'long life bakery product',
#   'newspapers'],
#  ['rolls/buns'],
#  ['pastry', 'canned beer'],
#  ['pork', 'whole milk', 'pastry', 'sauces'],
#  ['pip fruit',
#   'sliced cheese',
#   'pastry',
#   'white wine',
#   'light bulbs',
#   'newspapers'],
#  ['beef',
#   'citrus fruit',
#   'tropical fruit',
#   'yogurt',
#   'UHT-milk',
#   'frozen vegetables',
#   'rolls/buns',
#   'bottled water',
#   'skin care'],
#  ['beef',
#   'citrus fruit',
#   'berries',
#   'brown bread',
#   'sugar',
#   'coffee',
#   'kitchen towels'],
#  ['rolls/buns', 'spices'],
#  ['citrus fruit',
#   'tropical fruit',
#   'herbs',
#   'whole milk',
#   'butter',
#   'curd',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'canned vegetables',
#   'misc. beverages'],
#  ['meat',
#   'beef',
#   'herbs',
#   'whole milk',
#   'frozen dessert',
#   'rolls/buns',
#   'semi-finished bread',
#   'flour',
#   'oil',
#   'coffee',
#   'potted plants'],
#  ['beverages', 'pastry', 'bottled water'],
#  ['beef', 'citrus fruit', 'other vegetables', 'rolls/buns'],
#  ['ham', 'whole milk', 'white bread', 'margarine', 'hair spray'],
#  ['hamburger meat',
#   'whole milk',
#   'oil',
#   'ketchup',
#   'soups',
#   'Instant food products',
#   'canned fish',
#   'coffee',
#   'bottled beer',
#   'hygiene articles',
#   'newspapers'],
#  ['beef',
#   'citrus fruit',
#   'other vegetables',
#   'butter milk',
#   'sliced cheese',
#   'processed cheese',
#   'rolls/buns',
#   'margarine',
#   'bottled water',
#   'fruit/vegetable juice'],
#  ['beef',
#   'citrus fruit',
#   'whole milk',
#   'domestic eggs',
#   'rolls/buns',
#   'pastry',
#   'roll products',
#   'tea',
#   'fruit/vegetable juice'],
#  ['root vegetables', 'whole milk', 'detergent'],
#  ['citrus fruit',
#   'tropical fruit',
#   'grapes',
#   'other vegetables',
#   'frozen vegetables',
#   'pickled vegetables',
#   'fruit/vegetable juice',
#   'liquor',
#   'rum',
#   'liquor (appetizer)',
#   'candy',
#   'cling film/bags'],
#  ['yogurt', 'bottled water'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'whipped/sour cream',
#   'brown bread',
#   'canned fish',
#   'long life bakery product'],
#  ['frankfurter', 'root vegetables', 'newspapers'],
#  ['beef',
#   'other vegetables',
#   'whole milk',
#   'brown bread',
#   'pastry',
#   'salty snack',
#   'abrasive cleaner',
#   'shopping bags'],
#  ['shopping bags'],
#  ['canned beer'],
#  ['rolls/buns', 'canned beer'],
#  ['other vegetables',
#   'rolls/buns',
#   'meat spreads',
#   'bottled water',
#   'soda',
#   'misc. beverages',
#   'waffles',
#   'chocolate',
#   'candy'],
#  ['hamburger meat',
#   'other vegetables',
#   'yogurt',
#   'rolls/buns',
#   'bottled water'],
#  ['hamburger meat',
#   'citrus fruit',
#   'root vegetables',
#   'rolls/buns',
#   'Instant food products',
#   'canned fish',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'napkins'],
#  ['frankfurter',
#   'sausage',
#   'domestic eggs',
#   'soda',
#   'chewing gum',
#   'shopping bags'],
#  ['bottled beer'],
#  ['tropical fruit', 'domestic eggs', 'rolls/buns', 'pastry'],
#  ['soda'],
#  ['frankfurter',
#   'root vegetables',
#   'onions',
#   'other vegetables',
#   'white bread',
#   'canned beer'],
#  ['chicken',
#   'hamburger meat',
#   'herbs',
#   'whipped/sour cream',
#   'soups',
#   'soda',
#   'canned beer',
#   'dish cleaner',
#   'napkins',
#   'cling film/bags'],
#  ['coffee', 'soda'],
#  ['whole milk'],
#  ['margarine'],
#  ['tropical fruit', 'other vegetables'],
#  ['meat', 'other vegetables'],
#  ['cream cheese', 'bottled water', 'canned beer'],
#  ['newspapers'],
#  ['rolls/buns', 'pastry', 'newspapers'],
#  ['citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'potato products',
#   'fruit/vegetable juice',
#   'long life bakery product'],
#  ['whole milk', 'rolls/buns', 'detergent'],
#  ['frankfurter',
#   'citrus fruit',
#   'butter milk',
#   'UHT-milk',
#   'rolls/buns',
#   'female sanitary products',
#   'shopping bags'],
#  ['ham', 'other vegetables', 'butter', 'whipped/sour cream', 'sugar', 'soda'],
#  ['frankfurter', 'citrus fruit', 'bottled beer', 'salty snack'],
#  ['sausage', 'onions', 'curd', 'yogurt', 'domestic eggs', 'coffee'],
#  ['domestic eggs'],
#  ['whole milk', 'domestic eggs', 'rolls/buns', 'soda'],
#  ['rolls/buns', 'bottled beer', 'newspapers'],
#  ['whole milk', 'hard cheese', 'chocolate marshmallow'],
#  ['sausage', 'root vegetables', 'other vegetables', 'rolls/buns', 'soda'],
#  ['curd', 'butter milk', 'yogurt', 'beverages'],
#  ['bottled water'],
#  ['beef'],
#  ['frankfurter',
#   'hamburger meat',
#   'whole milk',
#   'rolls/buns',
#   'potato products',
#   'mustard',
#   'coffee',
#   'waffles',
#   'chocolate marshmallow',
#   'soap',
#   'newspapers'],
#  ['chicken', 'butter', 'newspapers'],
#  ['sausage',
#   'meat',
#   'tropical fruit',
#   'pip fruit',
#   'pastry',
#   'sugar',
#   'coffee',
#   'candles',
#   'potted plants'],
#  ['pork', 'whole milk', 'whipped/sour cream', 'beverages'],
#  ['yogurt', 'pastry', 'coffee'],
#  ['whole milk',
#   'sliced cheese',
#   'margarine',
#   'cat food',
#   'detergent',
#   'dishes',
#   'shopping bags'],
#  ['frankfurter',
#   'ham',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'vinegar',
#   'sugar',
#   'soda',
#   'fruit/vegetable juice',
#   'napkins'],
#  ['beef', 'whole milk', 'brown bread', 'specialty chocolate', 'newspapers'],
#  ['pip fruit',
#   'other vegetables',
#   'butter milk',
#   'cream cheese',
#   'rolls/buns'],
#  ['sausage', 'whole milk', 'rolls/buns', 'coffee', 'chocolate'],
#  ['pastry', 'coffee'],
#  ['chicken', 'beef', 'specialty chocolate'],
#  ['root vegetables',
#   'other vegetables',
#   'whole milk',
#   'sliced cheese',
#   'frozen vegetables',
#   'frozen fish',
#   'frozen dessert',
#   'chocolate'],
#  ['whole milk', 'frozen meals', 'rolls/buns'],
#  ['detergent'],
#  ['rolls/buns', 'canned fish'],
#  ['house keeping products'],
#  ['yogurt', 'salt', 'jam', 'sparkling wine', 'cleaner'],
#  ['tropical fruit', 'curd', 'sliced cheese', 'rolls/buns', 'soda'],
#  ['tropical fruit'],
#  ['curd', 'UHT-milk', 'artif. sweetener', 'dental care'],
#  ['beef', 'berries', 'onions', 'rolls/buns'],
#  ['whole milk',
#   'brown bread',
#   'pasta',
#   'margarine',
#   'bottled water',
#   'napkins',
#   'newspapers'],
#  ['pork', 'UHT-milk', 'bottled water', 'soda', 'canned beer'],
#  ['other vegetables',
#   'curd',
#   'yogurt',
#   'curd cheese',
#   'margarine',
#   'cleaner',
#   'hygiene articles'],
#  ['rolls/buns',
#   'soda',
#   'fruit/vegetable juice',
#   'canned beer',
#   'white wine',
#   'long life bakery product',
#   'shopping bags'],
#  ['frankfurter', 'pip fruit', 'whole milk', 'rolls/buns', 'roll products'],
#  ['yogurt', 'hygiene articles', 'newspapers', 'shopping bags'],
#  ['whole milk', 'curd', 'sliced cheese', 'cat food', 'coffee'],
#  ['bottled water', 'candy'],
#  ['frankfurter', 'beef', 'butter'],
#  ['rolls/buns', 'soda', 'snack products', 'shopping bags'],
#  ['whole milk', 'pastry', 'bottled water', 'hygiene articles'],
#  ['rolls/buns'],
#  ['chicken',
#   'onions',
#   'other vegetables',
#   'whole milk',
#   'brown bread',
#   'white wine',
#   'red/blush wine'],
#  ['tropical fruit', 'onions', 'whole milk', 'butter', 'dishes'],
#  ['sausage',
#   'turkey',
#   'other vegetables',
#   'yogurt',
#   'brown bread',
#   'oil',
#   'hygiene articles',
#   'shopping bags'],
#  ['sausage',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'hard cheese',
#   'soda',
#   'candy',
#   'newspapers'],
#  ['frankfurter',
#   'citrus fruit',
#   'pastry',
#   'margarine',
#   'ready soups',
#   'instant coffee',
#   'shopping bags'],
#  ['UHT-milk',
#   'frozen dessert',
#   'fruit/vegetable juice',
#   'decalcifier',
#   'newspapers'],
#  ['rolls/buns', 'newspapers'],
#  ['canned beer'],
#  ['yogurt', 'specialty bar'],
#  ['whipped/sour cream', 'specialty bar'],
#  ['rolls/buns', 'canned beer'],
#  ['rolls/buns'],
#  ['beverages', 'rolls/buns'],
#  ['rolls/buns'],
#  ['rolls/buns', 'shopping bags'],
#  ['bottled beer'],
#  ['citrus fruit',
#   'curd',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'oil',
#   'bottled water'],
#  ['bottled water', 'soda'],
#  ['pastry'],
#  ['domestic eggs', 'rolls/buns', 'pastry', 'coffee', 'candles'],
#  ['beef', 'pip fruit', 'root vegetables', 'rolls/buns', 'margarine'],
#  ['spread cheese', 'rolls/buns', 'bottled water', 'newspapers'],
#  ['tropical fruit', 'spread cheese', 'rolls/buns', 'soda'],
#  ['packaged fruit/vegetables', 'canned beer', 'candles'],
#  ['whole milk',
#   'yogurt',
#   'bottled beer',
#   'white wine',
#   'salty snack',
#   'napkins'],
#  ['meat',
#   'beef',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'domestic eggs',
#   'rolls/buns'],
#  ['onions',
#   'whole milk',
#   'bottled beer',
#   'liquor (appetizer)',
#   'detergent',
#   'dishes'],
#  ['frankfurter',
#   'grapes',
#   'other vegetables',
#   'butter milk',
#   'UHT-milk',
#   'brown bread',
#   'margarine',
#   'organic products',
#   'bottled water',
#   'soda'],
#  ['beef', 'rolls/buns', 'bottled beer'],
#  ['beef'],
#  ['sausage', 'bottled beer', 'liquor (appetizer)'],
#  ['chicken', 'onions', 'herbs', 'hygiene articles'],
#  ['canned beer'],
#  ['sausage',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'bottled beer',
#   'seasonal products'],
#  ['tropical fruit', 'whole milk', 'curd', 'yogurt', 'whipped/sour cream'],
#  ['frankfurter',
#   'rolls/buns',
#   'soda',
#   'abrasive cleaner',
#   'newspapers',
#   'flower (seeds)'],
#  ['sausage', 'tropical fruit', 'semi-finished bread'],
#  ['beef', 'tropical fruit', 'root vegetables', 'yogurt'],
#  ['tropical fruit', 'pastry', 'flour', 'rum'],
#  ['yogurt'],
#  ['frankfurter', 'rolls/buns', 'mustard'],
#  ['bottled beer'],
#  ['grapes', 'soda'],
#  ['beverages', 'rolls/buns'],
# ...
#   'coffee',
#   'female sanitary products',
#   'hygiene articles',
#   'shopping bags'],
#  ['root vegetables', 'dessert', 'yogurt', 'cream cheese', 'rice'],
#  ['tropical fruit', 'curd', 'rolls/buns', 'organic products', 'newspapers'],
#  ['beef',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'soft cheese',
#   'hard cheese',
#   'domestic eggs',
#   'pasta',
#   'coffee',
#   'candles'],
#  ['chicken', 'pork', 'whole milk', 'butter', 'white bread'],
#  ['citrus fruit',
#   'grapes',
#   'whole milk',
#   'rolls/buns',
#   'pastry',
#   'oil',
#   'margarine',
#   'candles',
#   'newspapers'],
#  ['meat',
#   'beef',
#   'tropical fruit',
#   'pip fruit',
#   'other vegetables',
#   'whipped/sour cream',
#   'soft cheese',
#   'frozen meals',
#   'margarine',
#   'coffee',
#   'fruit/vegetable juice',
#   'potted plants'],
#  ['cream cheese', 'spread cheese', 'rolls/buns'],
#  ['citrus fruit',
#   'herbs',
#   'whole milk',
#   'bottled water',
#   'bottled beer',
#   'potted plants'],
#  ['specialty bar'],
#  ['meat',
#   'other vegetables',
#   'whole milk',
#   'beverages',
#   'rolls/buns',
#   'margarine',
#   'chocolate',
#   'napkins',
#   'newspapers'],
#  ['citrus fruit', 'tropical fruit', 'pip fruit'],
#  ['frankfurter',
#   'beef',
#   'tropical fruit',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'frozen vegetables'],
#  ['citrus fruit', 'whole milk'],
#  ['turkey',
#   'root vegetables',
#   'other vegetables',
#   'curd',
#   'bottled beer',
#   'specialty chocolate'],
#  ['citrus fruit',
#   'onions',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'rolls/buns',
#   'pasta',
#   'mustard',
#   'dog food',
#   'canned beer'],
#  ['sausage', 'domestic eggs'],
#  ['newspapers'],
#  ['whole milk', 'yogurt'],
#  ['yogurt'],
#  ['yogurt'],
#  ['bottled water'],
#  ['berries', 'whole milk', 'whipped/sour cream', 'domestic eggs'],
#  ['packaged fruit/vegetables', 'whole milk', 'rolls/buns', 'pastry'],
#  ['frankfurter', 'soda'],
#  ['nuts/prunes',
#   'whole milk',
#   'semi-finished bread',
#   'jam',
#   'soda',
#   'potted plants',
#   'shopping bags'],
#  ['citrus fruit',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'butter',
#   'whipped/sour cream',
#   'flour',
#   'sugar',
#   'coffee',
#   'soda',
#   'sparkling wine',
#   'dishes'],
#  ['beef',
#   'citrus fruit',
#   'root vegetables',
#   'onions',
#   'curd',
#   'hard cheese',
#   'rolls/buns',
#   'fruit/vegetable juice'],
#  ['whole milk',
#   'yogurt',
#   'frozen vegetables',
#   'coffee',
#   'canned beer',
#   'napkins'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['beef', 'other vegetables'],
#  ['fish',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'spread cheese',
#   'coffee',
#   'white wine',
#   'red/blush wine'],
#  ['other vegetables',
#   'whole milk',
#   'curd',
#   'frozen vegetables',
#   'domestic eggs',
#   'sugar',
#   'instant coffee',
#   'newspapers'],
#  ['tropical fruit',
#   'berries',
#   'root vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'whipped/sour cream',
#   'sliced cheese',
#   'hard cheese',
#   'specialty chocolate',
#   'napkins'],
#  ['coffee'],
#  ['sausage',
#   'pork',
#   'other vegetables',
#   'frozen fish',
#   'rolls/buns',
#   'semi-finished bread',
#   'artif. sweetener',
#   'ready soups',
#   'bottled water',
#   'hygiene articles',
#   'newspapers'],
#  ['meat',
#   'root vegetables',
#   'whipped/sour cream',
#   'beverages',
#   'cream cheese',
#   'waffles',
#   'dishes'],
#  ['chicken',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'butter',
#   'rolls/buns',
#   'margarine',
#   'sugar',
#   'rum',
#   'long life bakery product',
#   'abrasive cleaner'],
#  ['berries',
#   'whole milk',
#   'whipped/sour cream',
#   'margarine',
#   'organic products',
#   'fruit/vegetable juice',
#   'shopping bags'],
#  ['frozen meals', 'misc. beverages'],
#  ['whipped/sour cream'],
#  ['beef', 'root vegetables', 'bottled beer', 'chocolate', 'shopping bags'],
#  ['chicken',
#   'pork',
#   'other vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'UHT-milk',
#   'domestic eggs',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'fruit/vegetable juice',
#   'bottled beer'],
#  ['chicken',
#   'pork',
#   'hamburger meat',
#   'pip fruit',
#   'nuts/prunes',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'spread cheese',
#   'frozen potato products',
#   'brown bread',
#   'Instant food products',
#   'soda',
#   'fruit/vegetable juice',
#   'shopping bags'],
#  ['beef',
#   'tropical fruit',
#   'root vegetables',
#   'herbs',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'hard cheese',
#   'rolls/buns',
#   'brown bread',
#   'bottled water',
#   'bottled beer',
#   'salty snack',
#   'shopping bags'],
#  ['packaged fruit/vegetables', 'pickled vegetables'],
#  ['sugar'],
#  ['frankfurter',
#   'sausage',
#   'beef',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'sliced cheese',
#   'ice cream',
#   'rolls/buns',
#   'soda'],
#  ['berries', 'frozen vegetables', 'pet care', 'instant coffee'],
#  ['bottled water', 'soda', 'chewing gum', 'napkins'],
#  ['sausage',
#   'chicken',
#   'citrus fruit',
#   'berries',
#   'root vegetables',
#   'curd',
#   'beverages',
#   'abrasive cleaner'],
#  ['whole milk',
#   'UHT-milk',
#   'domestic eggs',
#   'soda',
#   'fruit/vegetable juice',
#   'dishes',
#   'newspapers'],
#  ['ice cream', 'rolls/buns'],
#  ['frankfurter', 'citrus fruit', 'tropical fruit', 'rolls/buns'],
#  ['root vegetables',
#   'whole milk',
#   'white bread',
#   'brown bread',
#   'sweet spreads',
#   'dog food',
#   'brandy',
#   'shopping bags'],
#  ['sausage', 'rolls/buns', 'specialty chocolate'],
#  ['sausage',
#   'ham',
#   'citrus fruit',
#   'tropical fruit',
#   'berries',
#   'packaged fruit/vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'sliced cheese',
#   'pastry',
#   'sugar',
#   'baking powder'],
#  ['beef', 'root vegetables', 'whole milk', 'cream cheese'],
#  ['fruit/vegetable juice'],
#  ['sugar', 'hygiene articles'],
#  ['berries', 'whipped/sour cream'],
#  ['yogurt', 'beverages', 'coffee'],
#  ['pork', 'beef'],
#  ['bottled beer', 'shopping bags'],
#  ['curd', 'butter milk', 'yogurt', 'sliced cheese', 'coffee'],
#  ['beef', 'Instant food products', 'canned beer'],
#  ['pork',
#   'berries',
#   'whipped/sour cream',
#   'beverages',
#   'flour',
#   'oil',
#   'soda',
#   'chocolate',
#   'newspapers'],
#  ['white bread'],
#  ['grapes',
#   'whole milk',
#   'processed cheese',
#   'rolls/buns',
#   'white bread',
#   'fruit/vegetable juice'],
#  ['potato products', 'flower (seeds)'],
#  ['root vegetables',
#   'onions',
#   'yogurt',
#   'rolls/buns',
#   'coffee',
#   'bottled water',
#   'dishes'],
#  ['chicken',
#   'hamburger meat',
#   'UHT-milk',
#   'soda',
#   'canned beer',
#   'bathroom cleaner',
#   'newspapers'],
#  ['chicken', 'other vegetables', 'salt'],
#  ['fish', 'cream cheese', 'coffee'],
#  ['canned beer'],
#  ['other vegetables',
#   'whole milk',
#   'frozen meals',
#   'rolls/buns',
#   'brown bread',
#   'napkins'],
#  ['chicken',
#   'pork',
#   'whole milk',
#   'frozen vegetables',
#   'brown bread',
#   'vinegar',
#   'bottled beer',
#   'red/blush wine',
#   'newspapers'],
#  ['other vegetables', 'misc. beverages'],
#  ['tropical fruit', 'whole milk'],
#  ['whole milk', 'cake bar', 'newspapers'],
#  ['beef', 'hamburger meat', 'berries', 'pastry', 'hygiene articles'],
#  ['sausage', 'grapes', 'rolls/buns', 'soda', 'salty snack'],
#  ['whole milk', 'rolls/buns', 'chocolate'],
#  ['rolls/buns', 'soda'],
#  ['citrus fruit', 'tropical fruit', 'pip fruit', 'other vegetables'],
#  ['whole milk',
#   'sliced cheese',
#   'domestic eggs',
#   'artif. sweetener',
#   'bottled water',
#   'soda',
#   'shopping bags'],
#  ['pastry', 'soda', 'bottled beer'],
#  ['tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'soft cheese',
#   'hard cheese',
#   'spread cheese',
#   'curd cheese',
#   'frozen vegetables',
#   'ice cream',
#   'pastry',
#   'coffee',
#   'fruit/vegetable juice',
#   'hygiene articles'],
#  ['sliced cheese', 'pastry', 'newspapers'],
#  ['soda'],
#  ['ham',
#   'citrus fruit',
#   'whole milk',
#   'dessert',
#   'frozen meals',
#   'coffee',
#   'popcorn',
#   'shopping bags'],
#  ['salty snack'],
#  ['whole milk',
#   'curd',
#   'cream cheese',
#   'flour',
#   'coffee',
#   'bottled water',
#   'misc. beverages',
#   'newspapers'],
#  ['root vegetables', 'whipped/sour cream'],
#  ['soda', 'canned beer', 'shopping bags'],
#  ['curd',
#   'roll products',
#   'margarine',
#   'bottled water',
#   'canned beer',
#   'white wine',
#   'dish cleaner'],
#  ['bottled water', 'soda', 'fruit/vegetable juice', 'bottled beer', 'napkins'],
#  ['packaged fruit/vegetables', 'potted plants'],
#  ['tropical fruit',
#   'root vegetables',
#   'frozen vegetables',
#   'ice cream',
#   'bottled water',
#   'cling film/bags'],
#  ['ham',
#   'beef',
#   'grapes',
#   'yogurt',
#   'whipped/sour cream',
#   'domestic eggs',
#   'white bread',
#   'pastry',
#   'bottled water',
#   'fruit/vegetable juice',
#   'white wine',
#   'salty snack',
#   'chocolate',
#   'newspapers',
#   'shopping bags'],
#  ['pork',
#   'citrus fruit',
#   'UHT-milk',
#   'brown bread',
#   'soda',
#   'bottled beer',
#   'canned beer',
#   'long life bakery product'],
#  ['beverages', 'rolls/buns', 'soda', 'misc. beverages', 'liqueur', 'cake bar'],
#  ['sausage', 'rolls/buns', 'soda'],
#  ['sausage',
#   'citrus fruit',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'bottled water',
#   'soda',
#   'napkins'],
#  ['root vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'cream cheese',
#   'frozen fish',
#   'shopping bags'],
#  ['whole milk', 'cream cheese'],
#  ['frankfurter',
#   'turkey',
#   'root vegetables',
#   'other vegetables',
#   'yogurt',
#   'rolls/buns',
#   'pastry',
#   'ready soups'],
#  ['soda', 'shopping bags'],
#  ['soda', 'bottled beer'],
#  ['frankfurter', 'popcorn'],
#  ['berries',
#   'whole milk',
#   'whipped/sour cream',
#   'pickled vegetables',
#   'detergent',
#   'newspapers'],
#  ['canned beer'],
#  ['frankfurter', 'pork', 'white bread', 'canned vegetables', 'soda'],
#  ['frankfurter',
#   'hamburger meat',
#   'whole milk',
#   'butter',
#   'curd',
#   'flour',
#   'rice',
#   'oil',
#   'sugar',
#   'mustard',
#   'salty snack',
#   'chocolate',
#   'chocolate marshmallow',
#   'dish cleaner',
#   'dental care'],
#  ['berries',
#   'root vegetables',
#   'whole milk',
#   'beverages',
#   'sugar',
#   'soups',
#   'coffee',
#   'shopping bags'],
#  ['frankfurter', 'rolls/buns'],
#  ['newspapers'],
#  ['frozen fish', 'newspapers'],
#  ['tropical fruit', 'newspapers'],
#  ['beef',
#   'grapes',
#   'berries',
#   'whole milk',
#   'yogurt',
#   'rolls/buns',
#   'newspapers',
#   'potted plants'],
#  ['rolls/buns',
#   'coffee',
#   'instant coffee',
#   'salty snack',
#   'specialty chocolate'],
#  ['specialty chocolate', 'potted plants'],
#  ['sparkling wine', 'dish cleaner'],
#  ['citrus fruit', 'napkins', 'shopping bags'],
#  ['onions', 'herbs', 'bottled beer'],
#  ['whole milk', 'pastry', 'detergent', 'candles'],
#  ['photo/film'],
#  ['hamburger meat'],
#  ['other vegetables', 'whole milk', 'white bread', 'chewing gum'],
#  ['whole milk', 'rolls/buns', 'shopping bags'],
#  ['pork',
#   'tropical fruit',
#   'grapes',
#   'hard cheese',
#   'soda',
#   'napkins',
#   'shopping bags'],
#  ['tropical fruit',
#   'grapes',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'dessert',
#   'yogurt',
#   'whipped/sour cream',
#   'ice cream',
#   'pastry',
#   'salt',
#   'baking powder',
#   'bottled water',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'canned beer',
#   'specialty chocolate',
#   'potted plants'],
#  ['chicken',
#   'pork',
#   'citrus fruit',
#   'other vegetables',
#   'whipped/sour cream',
#   'white bread',
#   'chewing gum',
#   'potted plants'],
#  ['other vegetables', 'chewing gum'],
#  ['sausage', 'bottled water', 'red/blush wine'],
#  ['whole milk', 'whipped/sour cream', 'baking powder'],
#  ['rolls/buns', 'coffee'],
#  ['hygiene articles'],
#  ['ice cream', 'newspapers'],
#  ['curd',
#   'whipped/sour cream',
#   'domestic eggs',
#   'flour',
#   'misc. beverages',
#   'newspapers'],
#  ['whole milk', 'frozen meals', 'newspapers'],
#  ['onions',
#   'whole milk',
#   'dessert',
#   'domestic eggs',
#   'rolls/buns',
#   'white bread',
#   'coffee',
#   'bottled water'],
#  ['finished products',
#   'organic sausage',
#   'sliced cheese',
#   'white bread',
#   'fruit/vegetable juice'],
#  ['salt', 'dog food', 'long life bakery product'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'domestic eggs',
#   'white bread',
#   'brown bread',
#   'canned vegetables',
#   'soda',
#   'fruit/vegetable juice',
#   'rum'],
#  ['other vegetables', 'whole milk', 'yogurt'],
#  ['chocolate'],
#  ['ice cream'],
#  ['tropical fruit', 'oil', 'cat food'],
#  ['frankfurter',
#   'citrus fruit',
#   'whole milk',
#   'yogurt',
#   'sliced cheese',
#   'specialty cheese',
#   'pastry',
#   'fruit/vegetable juice'],
#  ['butter', 'pasta', 'canned fish', 'softener', 'flower (seeds)'],
#  ['other vegetables', 'butter milk', 'frozen fish', 'salty snack'],
#  ['tropical fruit', 'pastry', 'canned beer', 'chocolate'],
#  ['citrus fruit',
#   'root vegetables',
#   'packaged fruit/vegetables',
#   'yogurt',
#   'sliced cheese',
#   'rolls/buns',
#   'white bread',
#   'brown bread',
#   'zwieback'],
#  ['UHT-milk', 'salt', 'soda', 'specialty chocolate', 'shopping bags'],
#  ['beef'],
#  ['curd', 'yogurt', 'spread cheese', 'sugar', 'canned vegetables'],
#  ['citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'dessert',
#   'yogurt',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'salty snack'],
#  ['yogurt', 'brown bread', 'bottled beer', 'white wine'],
#  ['bottled beer', 'liquor', 'red/blush wine'],
#  ['grapes'],
#  ['pork', 'other vegetables', 'soda'],
#  ['sausage',
#   'citrus fruit',
#   'berries',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'whipped/sour cream',
#   'cream cheese',
#   'frozen vegetables',
#   'domestic eggs',
#   'pastry',
#   'margarine',
#   'soups',
#   'canned fish',
#   'chocolate',
#   'candy',
#   'napkins'],
#  ['frankfurter',
#   'chicken',
#   'pork',
#   'tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'yogurt',
#   'UHT-milk',
#   'mayonnaise',
#   'brown bread',
#   'pastry',
#   'flour',
#   'mustard',
#   'coffee',
#   'cocoa drinks',
#   'fruit/vegetable juice',
#   'salty snack',
#   'long life bakery product',
#   'chocolate',
#   'seasonal products'],
#  ['artif. sweetener', 'soda', 'photo/film'],
#  ['frankfurter',
#   'onions',
#   'butter',
#   'processed cheese',
#   'rolls/buns',
#   'coffee',
#   'bottled beer'],
#  ['pip fruit',
#   'root vegetables',
#   'dessert',
#   'yogurt',
#   'domestic eggs',
#   'shopping bags'],
#  ['frankfurter', 'whole milk', 'coffee', 'detergent'],
#  ['whole milk', 'newspapers'],
#  ['domestic eggs', 'hygiene articles', 'photo/film', 'flower soil/fertilizer'],
#  ['packaged fruit/vegetables',
#   'dessert',
#   'mayonnaise',
#   'oil',
#   'soda',
#   'waffles',
#   'chocolate',
#   'flower (seeds)',
#   'shopping bags'],
#  ['chicken',
#   'other vegetables',
#   'whipped/sour cream',
#   'frozen vegetables',
#   'bottled water',
#   'long life bakery product'],
#  ['pork',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'cream cheese',
#   'domestic eggs',
#   'white bread',
#   'sugar',
#   'baking powder',
#   'coffee',
#   'cocoa drinks',
#   'salty snack',
#   'waffles',
#   'candy',
#   'napkins'],
#  ['citrus fruit',
#   'other vegetables',
#   'whole milk',
#   'curd',
#   'yogurt',
#   'whipped/sour cream',
#   'cream cheese',
#   'pastry',
#   'vinegar',
#   'oil',
#   'coffee',
#   'long life bakery product',
#   'detergent',
#   'cleaner',
#   'napkins',
#   'newspapers'],
#  ['light bulbs'],
#  ['cream cheese', 'margarine', 'tea'],
#  ['sausage',
#   'curd',
#   'frozen meals',
#   'domestic eggs',
#   'cake bar',
#   'seasonal products',
#   'detergent',
#   'cleaner',
#   'house keeping products',
#   'potted plants',
#   'shopping bags'],
#  ['citrus fruit', 'onions'],
#  ['other vegetables', 'whipped/sour cream', 'roll products'],
#  ['chicken',
#   'tropical fruit',
#   'pip fruit',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'butter',
#   'yogurt',
#   'whipped/sour cream',
#   'hard cheese',
#   'frozen vegetables',
#   'frozen fish',
#   'domestic eggs',
#   'white bread',
#   'rice',
#   'specialty fat',
#   'dog food',
#   'bottled water',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'softener',
#   'napkins',
#   'cling film/bags'],
#  ['ice cream'],
#  ['pork', 'beef', 'ice cream', 'rolls/buns', 'newspapers'],
#  ['pork',
#   'tropical fruit',
#   'other vegetables',
#   'yogurt',
#   'semi-finished bread',
#   'flour',
#   'margarine',
#   'artif. sweetener',
#   'organic products',
#   'chocolate marshmallow'],
#  ...]

# %%
C1 = ap.createC1(dataSet)

# %%
C1
# Out:
# [frozenset({'Instant food products'}),
#  frozenset({'UHT-milk'}),
#  frozenset({'abrasive cleaner'}),
#  frozenset({'artif. sweetener'}),
#  frozenset({'baby cosmetics'}),
#  frozenset({'baby food'}),
#  frozenset({'bags'}),
#  frozenset({'baking powder'}),
#  frozenset({'bathroom cleaner'}),
#  frozenset({'beef'}),
#  frozenset({'berries'}),
#  frozenset({'beverages'}),
#  frozenset({'bottled beer'}),
#  frozenset({'bottled water'}),
#  frozenset({'brandy'}),
#  frozenset({'brown bread'}),
#  frozenset({'butter'}),
#  frozenset({'butter milk'}),
#  frozenset({'cake bar'}),
#  frozenset({'candles'}),
#  frozenset({'candy'}),
#  frozenset({'canned beer'}),
#  frozenset({'canned fish'}),
#  frozenset({'canned fruit'}),
#  frozenset({'canned vegetables'}),
#  frozenset({'cat food'}),
#  frozenset({'cereals'}),
#  frozenset({'chewing gum'}),
#  frozenset({'chicken'}),
#  frozenset({'chocolate'}),
#  frozenset({'chocolate marshmallow'}),
#  frozenset({'citrus fruit'}),
#  frozenset({'cleaner'}),
#  frozenset({'cling film/bags'}),
#  frozenset({'cocoa drinks'}),
#  frozenset({'coffee'}),
#  frozenset({'condensed milk'}),
#  frozenset({'cooking chocolate'}),
#  frozenset({'cookware'}),
#  frozenset({'cream'}),
#  frozenset({'cream cheese'}),
#  frozenset({'curd'}),
#  frozenset({'curd cheese'}),
#  frozenset({'decalcifier'}),
#  frozenset({'dental care'}),
#  frozenset({'dessert'}),
#  frozenset({'detergent'}),
#  frozenset({'dish cleaner'}),
#  frozenset({'dishes'}),
#  frozenset({'dog food'}),
#  frozenset({'domestic eggs'}),
#  frozenset({'female sanitary products'}),
#  frozenset({'finished products'}),
#  frozenset({'fish'}),
#  frozenset({'flour'}),
#  frozenset({'flower (seeds)'}),
#  frozenset({'flower soil/fertilizer'}),
#  frozenset({'frankfurter'}),
#  frozenset({'frozen chicken'}),
#  frozenset({'frozen dessert'}),
#  frozenset({'frozen fish'}),
#  frozenset({'frozen fruits'}),
#  frozenset({'frozen meals'}),
#  frozenset({'frozen potato products'}),
#  frozenset({'frozen vegetables'}),
#  frozenset({'fruit/vegetable juice'}),
#  frozenset({'grapes'}),
#  frozenset({'hair spray'}),
#  frozenset({'ham'}),
#  frozenset({'hamburger meat'}),
#  frozenset({'hard cheese'}),
#  frozenset({'herbs'}),
#  frozenset({'honey'}),
#  frozenset({'house keeping products'}),
#  frozenset({'hygiene articles'}),
#  frozenset({'ice cream'}),
#  frozenset({'instant coffee'}),
#  frozenset({'jam'}),
#  frozenset({'ketchup'}),
#  frozenset({'kitchen towels'}),
#  frozenset({'kitchen utensil'}),
#  frozenset({'light bulbs'}),
#  frozenset({'liqueur'}),
#  frozenset({'liquor'}),
#  frozenset({'liquor (appetizer)'}),
#  frozenset({'liver loaf'}),
#  frozenset({'long life bakery product'}),
#  frozenset({'make up remover'}),
#  frozenset({'male cosmetics'}),
#  frozenset({'margarine'}),
#  frozenset({'mayonnaise'}),
#  frozenset({'meat'}),
#  frozenset({'meat spreads'}),
#  frozenset({'misc. beverages'}),
#  frozenset({'mustard'}),
#  frozenset({'napkins'}),
#  frozenset({'newspapers'}),
#  frozenset({'nut snack'}),
#  frozenset({'nuts/prunes'}),
#  frozenset({'oil'}),
#  frozenset({'onions'}),
#  frozenset({'organic products'}),
#  frozenset({'organic sausage'}),
#  frozenset({'other vegetables'}),
#  frozenset({'packaged fruit/vegetables'}),
#  frozenset({'pasta'}),
#  frozenset({'pastry'}),
#  frozenset({'pet care'}),
#  frozenset({'photo/film'}),
#  frozenset({'pickled vegetables'}),
#  frozenset({'pip fruit'}),
#  frozenset({'popcorn'}),
#  frozenset({'pork'}),
#  frozenset({'potato products'}),
#  frozenset({'potted plants'}),
#  frozenset({'preservation products'}),
#  frozenset({'processed cheese'}),
#  frozenset({'prosecco'}),
#  frozenset({'pudding powder'}),
#  frozenset({'ready soups'}),
#  frozenset({'red/blush wine'}),
#  frozenset({'rice'}),
#  frozenset({'roll products'}),
#  frozenset({'rolls/buns'}),
#  frozenset({'root vegetables'}),
#  frozenset({'rubbing alcohol'}),
#  frozenset({'rum'}),
#  frozenset({'salad dressing'}),
#  frozenset({'salt'}),
#  frozenset({'salty snack'}),
#  frozenset({'sauces'}),
#  frozenset({'sausage'}),
#  frozenset({'seasonal products'}),
#  frozenset({'semi-finished bread'}),
#  frozenset({'shopping bags'}),
#  frozenset({'skin care'}),
#  frozenset({'sliced cheese'}),
#  frozenset({'snack products'}),
#  frozenset({'soap'}),
#  frozenset({'soda'}),
#  frozenset({'soft cheese'}),
#  frozenset({'softener'}),
#  frozenset({'sound storage medium'}),
#  frozenset({'soups'}),
#  frozenset({'sparkling wine'}),
#  frozenset({'specialty bar'}),
#  frozenset({'specialty cheese'}),
#  frozenset({'specialty chocolate'}),
#  frozenset({'specialty fat'}),
#  frozenset({'specialty vegetables'}),
#  frozenset({'spices'}),
#  frozenset({'spread cheese'}),
#  frozenset({'sugar'}),
#  frozenset({'sweet spreads'}),
#  frozenset({'syrup'}),
#  frozenset({'tea'}),
#  frozenset({'tidbits'}),
#  frozenset({'toilet cleaner'}),
#  frozenset({'tropical fruit'}),
#  frozenset({'turkey'}),
#  frozenset({'vinegar'}),
#  frozenset({'waffles'}),
#  frozenset({'whipped/sour cream'}),
#  frozenset({'whisky'}),
#  frozenset({'white bread'}),
#  frozenset({'white wine'}),
#  frozenset({'whole milk'}),
#  frozenset({'yogurt'}),
#  frozenset({'zwieback'})]

# %%
D = list(map(set, dataSet))

# %%
D
# Out:
# [{'citrus fruit', 'margarine', 'ready soups', 'semi-finished bread'},
#  {'coffee', 'tropical fruit', 'yogurt'},
#  {'whole milk'},
#  {'cream cheese', 'meat spreads', 'pip fruit', 'yogurt'},
#  {'condensed milk',
#   'long life bakery product',
#   'other vegetables',
#   'whole milk'},
#  {'abrasive cleaner', 'butter', 'rice', 'whole milk', 'yogurt'},
#  {'rolls/buns'},
#  {'UHT-milk',
#   'bottled beer',
#   'liquor (appetizer)',
#   'other vegetables',
#   'rolls/buns'},
#  {'potted plants'},
#  {'cereals', 'whole milk'},
#  {'bottled water',
#   'chocolate',
#   'other vegetables',
#   'tropical fruit',
#   'white bread'},
#  {'bottled water',
#   'butter',
#   'citrus fruit',
#   'curd',
#   'dishes',
#   'flour',
#   'tropical fruit',
#   'whole milk',
#   'yogurt'},
#  {'beef'},
#  {'frankfurter', 'rolls/buns', 'soda'},
#  {'chicken', 'tropical fruit'},
#  {'butter', 'fruit/vegetable juice', 'newspapers', 'sugar'},
#  {'fruit/vegetable juice'},
#  {'packaged fruit/vegetables'},
#  {'chocolate'},
#  {'specialty bar'},
#  {'other vegetables'},
#  {'butter milk', 'pastry'},
#  {'whole milk'},
#  {'cream cheese',
#   'detergent',
#   'newspapers',
#   'processed cheese',
#   'tropical fruit'},
#  {'bathroom cleaner',
#   'candy',
#   'flour',
#   'frozen dessert',
#   'other vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'salty snack',
#   'sweet spreads',
#   'tropical fruit',
#   'waffles'},
#  {'bottled water', 'canned beer'},
#  {'yogurt'},
#  {'chocolate', 'rolls/buns', 'sausage', 'soda'},
#  {'other vegetables'},
#  {'brown bread',
#   'canned beer',
#   'fruit/vegetable juice',
#   'newspapers',
#   'shopping bags',
#   'soda'},
#  {'beverages', 'bottled water', 'specialty bar', 'yogurt'},
#  {'bottled water',
#   'hamburger meat',
#   'hygiene articles',
#   'napkins',
#   'other vegetables',
#   'rolls/buns',
#   'spices'},
#  {'beverages', 'other vegetables', 'root vegetables', 'sugar', 'whole milk'},
#  {'abrasive cleaner',
#   'artif. sweetener',
#   'berries',
#   'other vegetables',
#   'pork',
#   'soda',
#   'whipped/sour cream',
#   'whole milk'},
#  {'beef', 'detergent', 'grapes'},
#  {'pastry', 'soda'},
#  {'fruit/vegetable juice'},
#  {'canned beer'},
#  {'dessert', 'other vegetables', 'root vegetables', 'whole milk'},
#  {'citrus fruit', 'newspapers', 'zwieback'},
#  {'canned beer',
#   'rolls/buns',
#   'sausage',
#   'shopping bags',
#   'soda',
#   'specialty bar'},
#  {'brown bread',
#   'candy',
#   'cereals',
#   'coffee',
#   'domestic eggs',
#   'pastry',
#   'root vegetables',
#   'soda',
#   'sugar',
#   'tropical fruit',
#   'waffles',
#   'whole milk',
#   'yogurt'},
#  {'berries', 'yogurt'},
#  {'canned beer'},
#  {'bottled water',
#   'butter milk',
#   'cream cheese',
#   'newspapers',
#   'rolls/buns',
#   'soda',
#   'spread cheese',
#   'yogurt'},
#  {'coffee'},
#  {'bottled water', 'pastry'},
#  {'rolls/buns'},
#  {'misc. beverages'},
#  {'UHT-milk',
#   'bottled water',
#   'butter',
#   'curd',
#   'hard cheese',
#   'long life bakery product',
#   'other vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'whipped/sour cream'},
#  {'cat food', 'newspapers', 'rolls/buns', 'sausage'},
#  {'canned beer'},
#  {'grapes', 'ham', 'other vegetables', 'whole milk'},
#  {'baking powder',
#   'brown bread',
#   'curd',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'margarine',
#   'other vegetables',
#   'semi-finished bread',
#   'tropical fruit',
#   'turkey'},
#  {'pickled vegetables', 'processed cheese', 'soda', 'whole milk', 'yogurt'},
#  {'curd', 'pastry', 'whole milk', 'yogurt'},
#  {'brown bread', 'canned beer', 'packaged fruit/vegetables'},
#  {'bottled water',
#   'chewing gum',
#   'chocolate marshmallow',
#   'hygiene articles',
#   'napkins',
#   'oil',
#   'rolls/buns'},
#  {'beef', 'cat food', 'ham', 'ice cream', 'rolls/buns', 'whipped/sour cream'},
#  {'pastry', 'rolls/buns', 'sugar'},
#  {'canned fish',
#   'detergent',
#   'frozen vegetables',
#   'other vegetables',
#   'salty snack',
#   'seasonal products',
#   'whole milk'},
#  {'pastry', 'sausage'},
#  {'beef', 'sausage', 'whole milk'},
#  {'brown bread', 'frankfurter', 'rolls/buns', 'sugar', 'tropical fruit'},
#  {'pastry', 'rolls/buns', 'soda'},
#  {'whole milk'},
#  {'coffee', 'curd cheese'},
#  {'newspapers', 'red/blush wine'},
#  {'curd', 'sausage', 'whole milk'},
#  {'berries',
#   'chocolate',
#   'frozen potato products',
#   'pickled vegetables',
#   'pip fruit',
#   'rolls/buns',
#   'tropical fruit',
#   'whole milk'},
#  {'red/blush wine'},
#  {'butter',
#   'candles',
#   'flower (seeds)',
#   'margarine',
#   'specialty chocolate',
#   'specialty fat',
#   'whole milk'},
#  {'citrus fruit',
#   'domestic eggs',
#   'frankfurter',
#   'newspapers',
#   'oil',
#   'sparkling wine',
#   'specialty chocolate',
#   'whole milk'},
#  {'meat spreads', 'soda', 'whole milk'},
#  {'frozen potato products'},
#  {'other vegetables', 'rolls/buns', 'sugar', 'whole milk'},
#  {'butter milk', 'citrus fruit', 'curd', 'pastry', 'whole milk'},
#  {'bottled beer', 'bottled water', 'flour', 'fruit/vegetable juice', 'salt'},
#  {'bottled beer', 'bottled water', 'soda', 'sugar'},
#  {'coffee', 'frozen meals'},
#  {'chocolate'},
#  {'bathroom cleaner',
#   'canned vegetables',
#   'domestic eggs',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'margarine',
#   'oil',
#   'rolls/buns',
#   'root vegetables',
#   'whole milk'},
#  {'frozen vegetables', 'hard cheese', 'onions', 'root vegetables'},
#  {'candles',
#   'condensed milk',
#   'frozen vegetables',
#   'herbs',
#   'oil',
#   'salt',
#   'white wine'},
#  {'bottled water'},
#  {'brandy',
#   'detergent',
#   'onions',
#   'rolls/buns',
#   'root vegetables',
#   'sausage',
#   'yogurt'},
#  {'coffee', 'newspapers'},
#  {'other vegetables', 'pork', 'whipped/sour cream'},
#  {'berries', 'yogurt'},
#  {'soda'},
#  {'berries'},
#  {'candles', 'fruit/vegetable juice', 'salty snack'},
#  {'butter milk', 'citrus fruit', 'cream cheese', 'yogurt'},
#  {'berries',
#   'chocolate',
#   'citrus fruit',
#   'coffee',
#   'hamburger meat',
#   'onions',
#   'pork',
#   'rice',
#   'whipped/sour cream'},
#  {'detergent'},
#  {'grapes', 'photo/film'},
#  {'brown bread',
#   'canned beer',
#   'fruit/vegetable juice',
#   'red/blush wine',
#   'rolls/buns',
#   'sausage',
#   'shopping bags',
#   'sliced cheese',
#   'waffles'},
#  {'butter',
#   'chicken',
#   'citrus fruit',
#   'detergent',
#   'hamburger meat',
#   'oil',
#   'other vegetables',
#   'pasta',
#   'root vegetables',
#   'tropical fruit'},
#  {'brown bread', 'whole milk', 'yogurt'},
#  {'citrus fruit', 'tropical fruit'},
#  {'misc. beverages', 'soda'},
#  {'bathroom cleaner',
#   'grapes',
#   'pastry',
#   'pork',
#   'rolls/buns',
#   'sausage',
#   'soda',
#   'specialty bar',
#   'whole milk'},
#  {'bottled water', 'frankfurter', 'rolls/buns'},
#  {'bottled beer',
#   'coffee',
#   'fruit/vegetable juice',
#   'napkins',
#   'photo/film',
#   'sausage',
#   'shopping bags',
#   'softener',
#   'whole milk',
#   'yogurt'},
#  {'soda'},
#  {'fruit/vegetable juice', 'rolls/buns'},
#  {'beef',
#   'berries',
#   'brown bread',
#   'citrus fruit',
#   'detergent',
#   'root vegetables'},
#  {'candy',
#   'cling film/bags',
#   'rolls/buns',
#   'soda',
#   'waffles',
#   'whipped/sour cream',
#   'whole milk'},
#  {'processed cheese'},
#  {'pip fruit', 'tropical fruit'},
#  {'bottled beer',
#   'chewing gum',
#   'dishes',
#   'frankfurter',
#   'oil',
#   'other vegetables',
#   'pickled vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'sausage'},
#  {'bottled water', 'packaged fruit/vegetables'},
#  {'bottled water',
#   'dessert',
#   'frozen vegetables',
#   'margarine',
#   'newspapers',
#   'red/blush wine',
#   'rolls/buns',
#   'whole milk'},
#  {'berries', 'whipped/sour cream'},
#  {'UHT-milk', 'berries', 'citrus fruit', 'processed cheese'},
#  {'tropical fruit', 'whole milk', 'yogurt'},
#  {'bottled beer',
#   'frozen vegetables',
#   'hamburger meat',
#   'rolls/buns',
#   'sparkling wine',
#   'whole milk'},
#  {'dishes',
#   'domestic eggs',
#   'frozen vegetables',
#   'hamburger meat',
#   'other vegetables',
#   'soda',
#   'whole milk'},
#  {'cream cheese', 'soda', 'whole milk'},
#  {'coffee',
#   'fish',
#   'long life bakery product',
#   'male cosmetics',
#   'margarine',
#   'other vegetables',
#   'pastry',
#   'shopping bags'},
#  {'frankfurter', 'long life bakery product', 'sausage', 'waffles'},
#  {'canned beer',
#   'dessert',
#   'packaged fruit/vegetables',
#   'semi-finished bread'},
#  {'pastry', 'soda'},
#  {'other vegetables', 'red/blush wine'},
#  {'misc. beverages'},
#  {'canned fruit',
#   'citrus fruit',
#   'cream cheese',
#   'domestic eggs',
#   'frankfurter',
#   'fruit/vegetable juice',
#   'hard cheese',
#   'hygiene articles',
#   'misc. beverages',
#   'pip fruit',
#   'rice',
#   'sausage',
#   'sugar',
#   'tropical fruit',
#   'whole milk'},
#  {'sparkling wine'},
#  {'specialty bar'},
#  {'butter milk', 'rolls/buns', 'sausage'},
#  {'curd cheese'},
#  {'dessert', 'frankfurter'},
#  {'beverages', 'brown bread', 'shopping bags', 'whole milk', 'yogurt'},
#  {'newspapers'},
#  {'berries', 'soda'},
#  {'curd', 'flour', 'liquor (appetizer)'},
#  {'coffee', 'other vegetables', 'tropical fruit'},
#  {'soda'},
#  {'Instant food products', 'rolls/buns'},
#  {'canned beer'},
#  {'canned beer'},
#  {'frankfurter', 'margarine', 'rolls/buns', 'sausage', 'whole milk'},
#  {'canned beer', 'misc. beverages', 'other vegetables'},
#  {'frozen vegetables', 'whole milk'},
#  {'whole milk'},
#  {'butter',
#   'citrus fruit',
#   'cream cheese',
#   'margarine',
#   'newspapers',
#   'oil',
#   'white bread'},
#  {'frankfurter', 'rolls/buns'},
#  {'baking powder',
#   'frankfurter',
#   'frozen vegetables',
#   'ham',
#   'other vegetables',
#   'pip fruit',
#   'rolls/buns',
#   'soft cheese',
#   'sugar',
#   'whole milk'},
#  {'butter milk', 'detergent', 'honey', 'soda', 'yogurt'},
#  {'bottled water',
#   'citrus fruit',
#   'dental care',
#   'hamburger meat',
#   'onions',
#   'rolls/buns'},
#  {'pasta', 'popcorn'},
#  {'cake bar',
#   'chocolate',
#   'meat spreads',
#   'other vegetables',
#   'shopping bags',
#   'whole milk'},
#  {'candles',
#   'citrus fruit',
#   'dessert',
#   'dishes',
#   'pork',
#   'sausage',
#   'white bread'},
#  {'rolls/buns'},
#  {'curd', 'dessert', 'grapes', 'napkins', 'other vegetables', 'yogurt'},
#  {'beverages',
#   'bottled beer',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'other vegetables',
#   'root vegetables',
#   'soft cheese',
#   'whole milk',
#   'yogurt'},
#  {'coffee', 'shopping bags'},
#  {'popcorn'},
#  {'bottled water', 'rolls/buns', 'soda', 'sugar', 'whole milk'},
#  {'other vegetables',
#   'packaged fruit/vegetables',
#   'snack products',
#   'tropical fruit',
#   'whole milk'},
#  {'beef', 'cling film/bags', 'flour', 'flower soil/fertilizer', 'herbs'},
#  {'butter', 'dessert', 'rolls/buns', 'whole milk'},
#  {'chewing gum', 'frankfurter', 'soda'},
#  {'bottled water', 'specialty cheese', 'tropical fruit'},
#  {'canned beer'},
#  {'bottled beer',
#   'finished products',
#   'frozen vegetables',
#   'other vegetables'},
#  {'beverages', 'soda'},
#  {'hamburger meat', 'root vegetables', 'whole milk'},
#  {'long life bakery product', 'pastry', 'whole milk'},
#  {'finished products', 'shopping bags', 'white wine'},
#  {'other vegetables'},
#  {'bottled beer',
#   'brown bread',
#   'fruit/vegetable juice',
#   'ham',
#   'other vegetables',
#   'tropical fruit',
#   'white bread',
#   'whole milk'},
#  {'other vegetables'},
#  {'butter milk', 'cocoa drinks', 'curd', 'popcorn', 'salty snack'},
#  {'bottled beer'},
#  {'cake bar',
#   'chocolate',
#   'curd',
#   'dessert',
#   'salty snack',
#   'shopping bags',
#   'soda',
#   'waffles'},
#  {'cereals', 'cream cheese', 'dog food', 'whole milk'},
#  {'salt', 'whole milk'},
#  {'dessert', 'ice cream'},
#  {'coffee', 'sausage', 'soft cheese'},
#  {'bottled water', 'dishes', 'other vegetables', 'shopping bags', 'waffles'},
#  {'ham', 'rolls/buns', 'whole milk'},
#  {'ice cream', 'other vegetables'},
#  {'bottled water', 'other vegetables'},
#  {'bottled beer', 'prosecco', 'soda', 'white wine'},
#  {'candy', 'herbs'},
#  {'bottled beer',
#   'butter',
#   'cereals',
#   'cream cheese',
#   'curd',
#   'domestic eggs',
#   'frankfurter',
#   'frozen fish',
#   'frozen meals',
#   'fruit/vegetable juice',
#   'ham',
#   'other vegetables',
#   'pip fruit',
#   'root vegetables',
#   'sliced cheese',
#   'soft cheese',
#   'sugar',
#   'tropical fruit',
#   'waffles',
#   'whipped/sour cream',
#   'white bread',
#   'whole milk',
#   'yogurt'},
#  {'canned beer', 'rolls/buns'},
#  {'cake bar',
#   'cream cheese',
#   'curd',
#   'semi-finished bread',
#   'shopping bags',
#   'specialty bar',
#   'zwieback'},
#  {'frankfurter',
#   'margarine',
#   'shopping bags',
#   'spread cheese',
#   'tropical fruit',
#   'whole milk'},
#  {'other vegetables'},
#  {'dog food'},
#  {'specialty bar'},
#  {'curd', 'detergent', 'liquor (appetizer)', 'salt', 'shopping bags'},
#  {'frankfurter', 'rolls/buns'},
#  {'soda'},
#  {'beef',
#   'berries',
#   'brown bread',
#   'dessert',
#   'root vegetables',
#   'spread cheese',
#   'whole milk'},
#  {'canned beer'},
#  {'beef', 'herbs', 'pip fruit', 'pork', 'spices'},
#  {'UHT-milk', 'citrus fruit', 'frankfurter', 'margarine', 'sugar'},
#  {'bottled beer', 'liquor (appetizer)', 'sausage'},
#  {'canned beer'},
#  {'specialty chocolate'},
#  {'curd', 'rolls/buns'},
#  {'canned beer'},
#  {'bottled water', 'newspapers', 'whole milk'},
#  {'chewing gum', 'rolls/buns'},
#  {'dishes', 'other vegetables', 'pork', 'root vegetables', 'whole milk'},
#  {'citrus fruit', 'pastry'},
#  {'potted plants'},
#  {'pastry', 'rolls/buns', 'soda'},
#  {'bottled water',
#   'butter',
#   'hygiene articles',
#   'make up remover',
#   'soda',
#   'yogurt'},
#  {'coffee', 'condensed milk', 'shopping bags', 'sugar'},
#  {'other vegetables', 'sausage', 'shopping bags', 'soda', 'yogurt'},
#  {'UHT-milk', 'beverages', 'soda', 'whole milk'},
#  {'beef', 'margarine', 'pork', 'rolls/buns', 'sausage', 'whole milk'},
#  {'beverages'},
#  {'beverages', 'specialty bar'},
#  {'bottled water', 'fruit/vegetable juice'},
#  {'newspapers'},
#  {'cleaner', 'female sanitary products'},
#  {'newspapers', 'sausage', 'shopping bags', 'soda'},
#  {'newspapers'},
#  {'beef',
#   'beverages',
#   'butter milk',
#   'citrus fruit',
#   'cookware',
#   'dish cleaner',
#   'hard cheese',
#   'other vegetables',
#   'rolls/buns',
#   'sausage',
#   'whipped/sour cream',
#   'whole milk'},
#  {'misc. beverages', 'newspapers'},
#  {'white wine'},
#  {'canned beer',
#   'rolls/buns',
#   'sausage',
#   'shopping bags',
#   'sliced cheese',
#   'soda'},
#  {'bottled beer', 'cake bar', 'curd', 'meat'},
#  {'baking powder',
#   'cling film/bags',
#   'frankfurter',
#   'meat',
#   'oil',
#   'onions',
#   'tea',
#   'tropical fruit'},
#  {'canned beer', 'ice cream', 'rolls/buns'},
#  {'canned beer'},
#  {'berries',
#   'bottled water',
#   'other vegetables',
#   'root vegetables',
#   'shopping bags',
#   'tropical fruit'},
#  {'beverages',
#   'bottled water',
#   'brown bread',
#   'butter milk',
#   'citrus fruit',
#   'cream cheese',
#   'curd',
#   'dessert',
#   'meat',
#   'other vegetables',
#   'rolls/buns',
#   'tea'},
#  {'bottled water', 'mustard', 'whole milk'},
#  {'beef',
#   'beverages',
#   'flower (seeds)',
#   'house keeping products',
#   'rolls/buns',
#   'sausage',
#   'sliced cheese',
#   'spices'},
#  {'butter',
#   'curd',
#   'frankfurter',
#   'long life bakery product',
#   'rolls/buns',
#   'root vegetables',
#   'salty snack',
#   'sausage',
#   'sliced cheese'},
#  {'butter', 'meat', 'other vegetables', 'rolls/buns'},
#  {'Instant food products',
#   'beverages',
#   'detergent',
#   'pickled vegetables',
#   'root vegetables'},
#  {'herbs',
#   'other vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'sliced cheese',
#   'whole milk'},
#  {'margarine', 'semi-finished bread', 'whipped/sour cream', 'whole milk'},
#  {'canned fish',
#   'canned vegetables',
#   'cereals',
#   'citrus fruit',
#   'curd',
#   'dessert',
#   'frozen dessert',
#   'hygiene articles',
#   'napkins',
#   'rolls/buns',
#   'salt',
#   'skin care',
#   'sugar',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'candy',
#   'citrus fruit',
#   'curd',
#   'margarine',
#   'newspapers',
#   'pastry',
#   'sugar'},
#  {'bottled beer',
#   'bottled water',
#   'misc. beverages',
#   'napkins',
#   'other vegetables',
#   'red/blush wine',
#   'soda',
#   'whole milk'},
#  {'citrus fruit', 'rolls/buns', 'whole milk'},
#  {'hygiene articles', 'napkins', 'oil', 'sausage'},
#  {'beef',
#   'bottled beer',
#   'bottled water',
#   'butter',
#   'frankfurter',
#   'frozen dessert',
#   'grapes',
#   'hamburger meat',
#   'potato products',
#   'root vegetables',
#   'whole milk'},
#  {'bottled water', 'hard cheese', 'newspapers', 'rolls/buns'},
#  {'chocolate', 'cream cheese', 'rolls/buns', 'soda'},
#  {'beef', 'dishes', 'frozen vegetables', 'photo/film', 'turkey'},
#  {'other vegetables',
#   'pork',
#   'rolls/buns',
#   'shopping bags',
#   'soda',
#   'whipped/sour cream'},
#  {'beverages', 'whole milk'},
#  {'rolls/buns', 'soda'},
#  {'bottled water',
#   'curd',
#   'hygiene articles',
#   'pip fruit',
#   'rolls/buns',
#   'sausage',
#   'sliced cheese',
#   'whole milk',
#   'yogurt'},
#  {'ice cream'},
#  {'liquor'},
#  {'fruit/vegetable juice', 'other vegetables', 'pip fruit'},
#  {'other vegetables', 'root vegetables', 'yogurt'},
#  {'soda'},
#  {'soda'},
#  {'bottled water',
#   'chocolate',
#   'citrus fruit',
#   'newspapers',
#   'other vegetables',
#   'rolls/buns',
#   'sausage',
#   'soda',
#   'tropical fruit',
#   'whole milk',
#   'yogurt'},
#  {'detergent', 'pet care', 'root vegetables', 'whole milk'},
#  {'berries',
#   'other vegetables',
#   'pastry',
#   'pork',
#   'root vegetables',
#   'specialty bar'},
#  {'pork'},
#  {'chocolate'},
#  {'fruit/vegetable juice'},
#  {'coffee', 'pickled vegetables'},
#  {'bottled water'},
#  {'butter',
#   'frankfurter',
#   'margarine',
#   'rolls/buns',
#   'sausage',
#   'spices',
#   'whipped/sour cream'},
#  {'domestic eggs',
#   'hygiene articles',
#   'napkins',
#   'onions',
#   'other vegetables',
#   'pip fruit',
#   'soda',
#   'soups',
#   'sugar',
#   'tea',
#   'tropical fruit',
#   'whole milk'},
#  {'canned beer'},
#  {'root vegetables'},
#  {'berries', 'citrus fruit', 'meat', 'root vegetables', 'soda', 'whole milk'},
#  {'bottled water',
#   'frankfurter',
#   'fruit/vegetable juice',
#   'hygiene articles',
#   'rolls/buns'},
#  {'margarine', 'rum', 'tropical fruit'},
#  {'butter milk',
#   'flour',
#   'herbs',
#   'hygiene articles',
#   'root vegetables',
#   'tropical fruit',
#   'whipped/sour cream',
#   'whole milk'},
#  {'baking powder',
#   'brown bread',
#   'citrus fruit',
#   'cream cheese',
#   'domestic eggs',
#   'margarine',
#   'other vegetables',
#   'pip fruit',
#   'root vegetables',
#   'waffles',
#   'whole milk'},
#  {'bottled water',
#   'curd',
#   'fruit/vegetable juice',
#   'hamburger meat',
#   'margarine',
#   'other vegetables',
#   'pastry',
#   'rolls/buns',
#   'semi-finished bread',
#   'whole milk',
#   'yogurt'},
#  {'chicken',
#   'dessert',
#   'other vegetables',
#   'pasta',
#   'pip fruit',
#   'rolls/buns',
#   'soda',
#   'waffles',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'chicken',
#   'citrus fruit',
#   'frozen fish',
#   'rolls/buns',
#   'root vegetables',
#   'tropical fruit',
#   'whole milk'},
#  {'citrus fruit',
#   'frankfurter',
#   'onions',
#   'other vegetables',
#   'rolls/buns',
#   'soda',
#   'sugar',
#   'whole milk'},
#  {'canned beer'},
#  {'pastry', 'pip fruit', 'salad dressing', 'turkey'},
#  {'bottled water',
#   'brown bread',
#   'curd',
#   'domestic eggs',
#   'misc. beverages',
#   'mustard',
#   'packaged fruit/vegetables',
#   'pickled vegetables',
#   'whole milk',
#   'yogurt'},
#  {'pasta'},
#  {'citrus fruit', 'tropical fruit'},
#  {'brown bread',
#   'potted plants',
#   'rolls/buns',
#   'sausage',
#   'whole milk',
#   'yogurt'},
#  {'frozen meals', 'fruit/vegetable juice', 'pastry', 'waffles', 'whole milk'},
#  {'canned beer'},
#  {'citrus fruit', 'sauces', 'sugar'},
#  {'liquor (appetizer)'},
#  {'citrus fruit',
#   'other vegetables',
#   'rolls/buns',
#   'salty snack',
#   'shopping bags'},
#  {'sausage'},
#  {'bottled water',
#   'canned beer',
#   'chicken',
#   'napkins',
#   'newspapers',
#   'oil',
#   'other vegetables',
#   'vinegar',
#   'whole milk'},
#  {'flour',
#   'hamburger meat',
#   'margarine',
#   'other vegetables',
#   'root vegetables',
#   'specialty cheese',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'dessert', 'oil', 'other vegetables', 'pork', 'sausage', 'soda', 'yogurt'},
#  {'abrasive cleaner',
#   'beef',
#   'berries',
#   'root vegetables',
#   'whipped/sour cream',
#   'whole milk'},
#  {'bottled water', 'citrus fruit', 'packaged fruit/vegetables', 'yogurt'},
#  {'UHT-milk', 'coffee'},
#  {'candy'},
#  {'newspapers'},
#  {'beef', 'citrus fruit', 'other vegetables', 'yogurt'},
#  {'rolls/buns', 'sausage'},
#  {'beef',
#   'canned beer',
#   'curd',
#   'dessert',
#   'frankfurter',
#   'hygiene articles',
#   'mustard',
#   'napkins',
#   'pickled vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'soft cheese',
#   'yogurt'},
#  {'canned beer'},
#  {'bottled beer'},
#  {'chewing gum', 'chocolate', 'newspapers', 'onions', 'soda'},
#  {'candy',
#   'cream cheese',
#   'packaged fruit/vegetables',
#   'tropical fruit',
#   'white bread'},
#  {'bottled water', 'white wine'},
#  {'beef', 'pasta', 'pastry', 'soap', 'white bread'},
#  {'abrasive cleaner',
#   'candy',
#   'chicken',
#   'cleaner',
#   'root vegetables',
#   'sausage',
#   'tropical fruit',
#   'whole milk',
#   'yogurt'},
#  {'hair spray'},
#  {'chicken',
#   'long life bakery product',
#   'shopping bags',
#   'spices',
#   'whole milk'},
#  {'brown bread', 'cat food', 'citrus fruit', 'pastry', 'pork', 'sugar'},
#  {'ice cream'},
#  {'bottled beer', 'hard cheese', 'meat'},
#  {'brown bread', 'instant coffee', 'other vegetables', 'yogurt'},
#  {'bottled water', 'cake bar'},
#  {'salty snack', 'soda', 'tropical fruit'},
#  {'photo/film'},
#  {'canned beer',
#   'citrus fruit',
#   'coffee',
#   'dishes',
#   'sausage',
#   'soda',
#   'yogurt'},
#  {'grapes', 'root vegetables'},
#  {'brown bread', 'domestic eggs', 'photo/film'},
#  {'canned beer', 'canned fish', 'rolls/buns'},
#  {'tropical fruit', 'whole milk'},
#  {'chicken'},
#  {'bottled water', 'brown bread', 'frankfurter', 'other vegetables', 'yogurt'},
#  {'berries',
#   'butter milk',
#   'cream cheese',
#   'curd',
#   'detergent',
#   'margarine',
#   'misc. beverages',
#   'other vegetables',
#   'roll products',
#   'root vegetables',
#   'specialty chocolate'},
#  {'hygiene articles', 'margarine'},
#  {'rolls/buns', 'shopping bags', 'soda', 'tropical fruit', 'yogurt'},
#  {'candy',
#   'chocolate',
#   'ham',
#   'hard cheese',
#   'misc. beverages',
#   'other vegetables',
#   'rolls/buns',
#   'soda',
#   'whipped/sour cream'},
#  {'hamburger meat', 'salty snack', 'white bread'},
#  {'mayonnaise', 'napkins', 'rolls/buns', 'soda', 'yogurt'},
#  {'soda', 'specialty chocolate'},
#  {'yogurt'},
#  {'soda'},
#  {'bottled water'},
#  {'hamburger meat', 'meat', 'rubbing alcohol', 'sausage'},
#  {'beverages',
#   'citrus fruit',
#   'fruit/vegetable juice',
#   'hard cheese',
#   'pet care',
#   'pip fruit',
#   'soda',
#   'waffles'},
#  {'shopping bags'},
#  {'newspapers'},
#  {'curd',
#   'dish cleaner',
#   'frankfurter',
#   'frozen potato products',
#   'other vegetables',
#   'specialty bar',
#   'whole milk',
#   'zwieback'},
#  {'canned beer', 'citrus fruit', 'sausage', 'whole milk'},
#  {'frankfurter', 'rolls/buns'},
#  {'cookware', 'salt', 'salty snack'},
#  {'oil'},
#  {'beverages',
#   'cake bar',
#   'chewing gum',
#   'cream cheese',
#   'curd',
#   'pastry',
#   'rolls/buns',
#   'soda'},
#  {'butter', 'other vegetables', 'specialty chocolate'},
#  {'citrus fruit'},
#  {'butter milk', 'frankfurter', 'whole milk'},
#  {'butter',
#   'mayonnaise',
#   'processed cheese',
#   'root vegetables',
#   'salty snack',
#   'whole milk'},
#  {'bottled beer', 'frozen meals', 'tropical fruit', 'whole milk'},
#  {'beef', 'hamburger meat', 'pip fruit'},
#  {'berries', 'cereals', 'shopping bags', 'waffles', 'whipped/sour cream'},
#  {'canned beer'},
#  {'canned beer', 'red/blush wine', 'whipped/sour cream'},
#  {'candy',
#   'chocolate marshmallow',
#   'domestic eggs',
#   'margarine',
#   'root vegetables'},
#  {'soda', 'whole milk'},
#  {'beef'},
#  {'frozen vegetables'},
#  {'bottled beer', 'rolls/buns'},
#  {'hygiene articles', 'whole milk'},
#  {'whole milk'},
#  {'citrus fruit', 'curd', 'soft cheese', 'whole milk'},
#  {'fruit/vegetable juice', 'pastry'},
#  {'brown bread',
#   'butter',
#   'frankfurter',
#   'pip fruit',
#   'pork',
#   'processed cheese',
#   'sausage',
#   'white bread'},
#  {'domestic eggs',
#   'root vegetables',
#   'tropical fruit',
#   'whipped/sour cream',
#   'whole milk'},
#  {'frankfurter',
#   'napkins',
#   'pastry',
#   'root vegetables',
#   'sausage',
#   'whipped/sour cream',
#   'yogurt'},
#  {'berries',
#   'cat food',
#   'curd',
#   'curd cheese',
#   'detergent',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'root vegetables',
#   'specialty bar',
#   'whole milk'},
#  {'bottled beer', 'brown bread', 'coffee', 'pastry', 'rolls/buns'},
#  {'coffee',
#   'curd',
#   'dessert',
#   'frozen vegetables',
#   'packaged fruit/vegetables',
#   'root vegetables',
#   'specialty fat'},
#  {'yogurt'},
#  {'bottled water', 'other vegetables'},
#  {'berries', 'white bread'},
#  {'berries', 'coffee'},
#  {'bottled water', 'butter milk', 'frozen meals', 'other vegetables'},
#  {'newspapers', 'rolls/buns'},
#  {'citrus fruit',
#   'ham',
#   'hygiene articles',
#   'pastry',
#   'rolls/buns',
#   'waffles',
#   'whipped/sour cream',
#   'whole milk'},
#  {'frozen dessert', 'napkins', 'salty snack', 'whole milk'},
#  {'bottled water', 'butter milk', 'rolls/buns', 'tropical fruit'},
#  {'bottled water'},
#  {'butter milk', 'yogurt'},
#  {'newspapers'},
#  {'coffee'},
#  {'bottled beer', 'liquor'},
#  {'butter',
#   'candy',
#   'cling film/bags',
#   'frozen vegetables',
#   'hard cheese',
#   'napkins',
#   'onions',
#   'pasta',
#   'specialty fat',
#   'syrup',
#   'whipped/sour cream'},
#  {'dog food',
#   'frozen meals',
#   'hamburger meat',
#   'hard cheese',
#   'pasta',
#   'salty snack',
#   'shopping bags'},
#  {'cream cheese',
#   'liver loaf',
#   'other vegetables',
#   'pastry',
#   'sausage',
#   'shopping bags',
#   'soap'},
#  {'hard cheese', 'napkins', 'pastry'},
#  {'condensed milk', 'rolls/buns', 'sausage', 'tropical fruit'},
#  {'hamburger meat'},
#  {'beverages', 'frozen dessert', 'onions', 'whole milk'},
#  {'coffee'},
#  {'shopping bags'},
#  {'bottled water', 'pastry', 'rolls/buns', 'shopping bags', 'soda', 'yogurt'},
#  {'soda'},
#  {'sliced cheese'},
#  {'coffee', 'sausage', 'whole milk'},
#  {'chocolate', 'yogurt'},
#  {'dish cleaner', 'domestic eggs', 'hygiene articles', 'rolls/buns'},
#  {'whole milk'},
#  {'meat', 'other vegetables', 'whipped/sour cream', 'whole milk'},
#  {'bathroom cleaner', 'dish cleaner', 'hygiene articles', 'napkins'},
#  {'other vegetables', 'red/blush wine'},
#  {'butter milk',
#   'coffee',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'rolls/buns',
#   'shopping bags',
#   'sliced cheese',
#   'sweet spreads',
#   'whole milk',
#   'yogurt'},
#  {'Instant food products', 'other vegetables', 'rolls/buns', 'whole milk'},
#  {'other vegetables', 'tropical fruit'},
#  {'baking powder', 'bottled water', 'chewing gum', 'salty snack'},
#  {'specialty bar'},
#  {'ice cream'},
#  {'frankfurter', 'yogurt'},
#  {'canned beer'},
#  {'bottled water'},
#  {'bottled beer',
#   'bottled water',
#   'margarine',
#   'other vegetables',
#   'rolls/buns',
#   'whole milk'},
#  {'citrus fruit',
#   'onions',
#   'other vegetables',
#   'shopping bags',
#   'tropical fruit'},
#  {'ham',
#   'hamburger meat',
#   'newspapers',
#   'sausage',
#   'soda',
#   'softener',
#   'whole milk'},
#  {'domestic eggs', 'napkins', 'rolls/buns', 'specialty bar'},
#  {'citrus fruit',
#   'curd',
#   'hygiene articles',
#   'other vegetables',
#   'pork',
#   'root vegetables',
#   'tropical fruit'},
#  {'coffee',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'salty snack',
#   'soda',
#   'specialty cheese'},
#  {'citrus fruit',
#   'fruit/vegetable juice',
#   'pip fruit',
#   'pork',
#   'sparkling wine',
#   'yogurt'},
#  {'beef', 'berries', 'domestic eggs', 'rolls/buns', 'whipped/sour cream'},
#  {'other vegetables', 'pet care'},
#  {'chewing gum', 'chicken', 'dishes', 'rolls/buns', 'sliced cheese', 'yogurt'},
#  {'chewing gum', 'soda'},
#  {'whole milk'},
#  {'rolls/buns'},
#  {'bottled beer'},
#  {'bottled water', 'male cosmetics', 'pastry', 'root vegetables'},
#  {'pastry'},
#  {'berries', 'cake bar', 'pet care', 'shopping bags'},
#  {'bottled water',
#   'canned vegetables',
#   'citrus fruit',
#   'root vegetables',
#   'soda',
#   'softener',
#   'tropical fruit',
#   'yogurt'},
#  {'canned fruit', 'fruit/vegetable juice', 'oil', 'whole milk'},
#  {'misc. beverages', 'soda'},
#  {'bottled water', 'soda'},
#  {'other vegetables', 'rolls/buns', 'tropical fruit'},
#  {'salty snack'},
#  {'bottled water', 'canned beer'},
#  {'chocolate'},
#  {'UHT-milk', 'citrus fruit', 'cream cheese', 'frozen vegetables'},
#  {'bottled water', 'canned beer', 'male cosmetics'},
#  {'bottled water', 'napkins', 'onions', 'other vegetables', 'pastry', 'soda'},
#  {'cat food', 'dessert', 'oil', 'soda'},
#  {'beef',
#   'coffee',
#   'dental care',
#   'frozen potato products',
#   'hygiene articles',
#   'margarine',
#   'newspapers',
#   'oil',
#   'other vegetables',
#   'rolls/buns',
#   'whole milk'},
#  {'bottled beer',
#   'bottled water',
#   'brandy',
#   'canned beer',
#   'misc. beverages',
#   'rolls/buns',
#   'zwieback'},
#  {'beef',
#   'instant coffee',
#   'onions',
#   'other vegetables',
#   'root vegetables',
#   'soda',
#   'tropical fruit'},
#  {'soda'},
#  {'coffee', 'hygiene articles'},
#  {'bottled water', 'brown bread', 'rolls/buns'},
#  {'beef',
#   'frozen vegetables',
#   'hamburger meat',
#   'margarine',
#   'other vegetables',
#   'pork',
#   'rolls/buns',
#   'shopping bags',
#   'whole milk'},
#  {'canned beer',
#   'hygiene articles',
#   'liquor (appetizer)',
#   'napkins',
#   'newspapers',
#   'soda'},
#  {'ham', 'ice cream', 'other vegetables', 'sausage', 'white bread'},
#  {'beef', 'other vegetables', 'rolls/buns', 'root vegetables', 'sugar'},
#  {'bottled beer', 'bottled water', 'butter', 'whole milk'},
#  {'house keeping products', 'hygiene articles', 'ice cream', 'pork'},
#  {'berries',
#   'fruit/vegetable juice',
#   'ice cream',
#   'packaged fruit/vegetables',
#   'salty snack',
#   'specialty bar',
#   'whole milk'},
#  {'curd',
#   'frozen vegetables',
#   'other vegetables',
#   'roll products',
#   'rolls/buns',
#   'sausage',
#   'whipped/sour cream',
#   'yogurt'},
#  {'bottled water', 'cling film/bags', 'misc. beverages'},
#  {'bottled water',
#   'frozen dessert',
#   'hard cheese',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'rice',
#   'tropical fruit',
#   'whole milk'},
#  {'bottled water', 'herbs'},
#  {'rolls/buns', 'yogurt'},
#  {'Instant food products'},
#  {'specialty chocolate'},
#  {'coffee'},
#  {'bottled beer', 'liquor'},
#  {'beef', 'root vegetables'},
#  {'honey', 'waffles', 'whole milk'},
#  {'frankfurter', 'pastry', 'rolls/buns', 'snack products', 'specialty bar'},
#  {'curd',
#   'frankfurter',
#   'frozen vegetables',
#   'hygiene articles',
#   'liver loaf',
#   'photo/film',
#   'rolls/buns',
#   'root vegetables',
#   'sausage',
#   'semi-finished bread'},
#  {'cream cheese', 'other vegetables', 'whole milk'},
#  {'frankfurter',
#   'pickled vegetables',
#   'root vegetables',
#   'seasonal products',
#   'soda'},
#  {'newspapers', 'rolls/buns', 'whole milk'},
#  {'dental care', 'frankfurter', 'margarine'},
#  {'other vegetables', 'salty snack'},
#  {'bottled water', 'shopping bags'},
#  {'butter',
#   'hygiene articles',
#   'onions',
#   'pastry',
#   'pork',
#   'rolls/buns',
#   'rum',
#   'whole milk'},
#  {'bottled water'},
#  {'domestic eggs',
#   'other vegetables',
#   'specialty cheese',
#   'whipped/sour cream'},
#  {'canned beer', 'curd', 'hamburger meat', 'pasta', 'whole milk'},
#  {'citrus fruit', 'hamburger meat', 'other vegetables'},
#  {'shopping bags'},
#  {'cream cheese', 'fruit/vegetable juice', 'soda', 'whole milk'},
#  {'ice cream'},
#  {'bottled water', 'pastry'},
#  {'baby cosmetics',
#   'butter milk',
#   'chocolate',
#   'coffee',
#   'cream cheese',
#   'curd',
#   'dessert',
#   'ham',
#   'long life bakery product',
#   'pip fruit',
#   'sliced cheese',
#   'whipped/sour cream',
#   'white bread',
#   'whole milk'},
#  {'frankfurter', 'soda'},
#  {'beef',
#   'domestic eggs',
#   'flour',
#   'misc. beverages',
#   'napkins',
#   'organic products',
#   'rice',
#   'rolls/buns',
#   'root vegetables',
#   'sausage',
#   'turkey'},
#  {'bottled beer'},
#  {'bottled beer', 'bottled water', 'napkins'},
#  {'bottled water',
#   'frozen meals',
#   'hard cheese',
#   'meat',
#   'other vegetables',
#   'soda'},
#  {'candy', 'dessert'},
#  {'UHT-milk',
#   'bottled water',
#   'other vegetables',
#   'packaged fruit/vegetables'},
#  {'beverages', 'rolls/buns', 'soda'},
#  {'canned fish', 'ham', 'mustard'},
#  {'specialty bar'},
#  {'brown bread', 'salty snack', 'shopping bags', 'soda'},
#  {'coffee', 'cream cheese', 'whole milk'},
#  {'pastry', 'red/blush wine', 'rolls/buns'},
#  {'bottled beer', 'nut snack'},
#  {'bottled beer', 'pet care'},
#  {'citrus fruit', 'other vegetables', 'soda'},
#  {'frozen vegetables', 'hygiene articles', 'other vegetables', 'pork'},
#  {'other vegetables', 'shopping bags'},
#  {'detergent', 'white wine'},
#  {'bottled water', 'dessert', 'whole milk'},
#  {'pip fruit', 'shopping bags', 'white wine'},
#  {'bottled beer', 'soda', 'sugar'},
#  {'candy',
#   'coffee',
#   'fruit/vegetable juice',
#   'pip fruit',
#   'rolls/buns',
#   'tropical fruit'},
#  {'bottled beer',
#   'bottled water',
#   'cream cheese',
#   'frozen dessert',
#   'fruit/vegetable juice',
#   'misc. beverages',
#   'root vegetables',
#   'soda',
#   'spread cheese',
#   'white bread'},
#  {'misc. beverages', 'soda'},
#  {'curd', 'whole milk'},
#  {'bottled water',
#   'male cosmetics',
#   'other vegetables',
#   'tropical fruit',
#   'yogurt'},
#  {'brown bread', 'white bread'},
#  {'brown bread', 'hygiene articles', 'sugar'},
#  {'bottled water',
#   'candy',
#   'coffee',
#   'house keeping products',
#   'red/blush wine',
#   'root vegetables',
#   'shopping bags',
#   'tropical fruit'},
#  {'domestic eggs'},
#  {'coffee', 'detergent', 'hygiene articles', 'photo/film'},
#  {'soda'},
#  {'whole milk'},
#  {'bottled beer'},
#  {'beef',
#   'berries',
#   'cat food',
#   'chocolate',
#   'coffee',
#   'dish cleaner',
#   'frozen fish',
#   'frozen potato products',
#   'mayonnaise',
#   'mustard',
#   'napkins',
#   'newspapers',
#   'oil',
#   'packaged fruit/vegetables',
#   'pork',
#   'soda',
#   'whole milk'},
#  {'other vegetables', 'yogurt'},
#  {'bottled water', 'dishes', 'yogurt'},
#  {'sparkling wine'},
#  {'bottled water', 'candy'},
#  {'berries',
#   'butter milk',
#   'citrus fruit',
#   'fruit/vegetable juice',
#   'hygiene articles',
#   'other vegetables',
#   'sugar'},
#  {'hamburger meat',
#   'other vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'whole milk'},
#  {'packaged fruit/vegetables', 'seasonal products'},
#  {'margarine', 'other vegetables'},
#  {'soda'},
#  {'bottled water',
#   'frozen potato products',
#   'fruit/vegetable juice',
#   'margarine',
#   'salty snack',
#   'whole milk',
#   'yogurt'},
#  {'herbs', 'yogurt'},
#  {'citrus fruit', 'rolls/buns', 'soda', 'spread cheese'},
#  {'misc. beverages'},
#  {'female sanitary products'},
#  {'soda'},
#  {'beverages',
#   'pasta',
#   'shopping bags',
#   'tropical fruit',
#   'white bread',
#   'whole milk'},
#  {'female sanitary products', 'soda'},
#  {'bottled water', 'soda', 'waffles', 'white bread'},
#  {'chewing gum', 'chocolate marshmallow', 'coffee'},
#  {'baking powder',
#   'chocolate marshmallow',
#   'coffee',
#   'frozen vegetables',
#   'honey',
#   'red/blush wine',
#   'root vegetables',
#   'tropical fruit',
#   'whole milk'},
#  {'butter milk', 'pip fruit', 'pork', 'whole milk'},
#  {'bottled water', 'citrus fruit'},
#  {'frankfurter'},
#  {'frankfurter', 'rolls/buns'},
#  {'UHT-milk',
#   'curd',
#   'domestic eggs',
#   'frankfurter',
#   'hard cheese',
#   'hygiene articles',
#   'napkins',
#   'pip fruit',
#   'rolls/buns',
#   'shopping bags',
#   'tropical fruit'},
#  {'other vegetables'},
#  {'fruit/vegetable juice', 'newspapers', 'yogurt'},
#  {'bottled water',
#   'brown bread',
#   'cereals',
#   'sausage',
#   'soda',
#   'whole milk',
#   'yogurt'},
#  {'whole milk'},
#  {'bottled water', 'curd', 'pastry', 'pip fruit', 'whole milk'},
#  {'whole milk'},
#  {'other vegetables', 'root vegetables'},
#  {'fruit/vegetable juice', 'onions'},
#  {'specialty chocolate'},
#  {'domestic eggs', 'hamburger meat'},
#  {'photo/film'},
#  {'newspapers', 'rolls/buns', 'snack products', 'soda'},
#  {'canned beer'},
#  {'canned beer'},
#  {'bottled beer',
#   'candles',
#   'curd',
#   'frozen meals',
#   'frozen potato products',
#   'kitchen towels',
#   'other vegetables',
#   'soda'},
#  {'canned beer'},
#  {'curd', 'rolls/buns', 'spices', 'whipped/sour cream', 'zwieback'},
#  {'butter', 'fruit/vegetable juice', 'newspapers'},
#  {'bottled water',
#   'domestic eggs',
#   'other vegetables',
#   'soda',
#   'whole milk',
#   'yogurt'},
#  {'whole milk'},
#  {'beef',
#   'curd',
#   'herbs',
#   'sliced cheese',
#   'tropical fruit',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'rolls/buns', 'sausage'},
#  {'soda'},
#  {'fruit/vegetable juice', 'long life bakery product'},
#  {'coffee',
#   'detergent',
#   'long life bakery product',
#   'rolls/buns',
#   'shopping bags'},
#  {'bottled water', 'candy', 'pip fruit', 'whole milk'},
#  {'bottled beer',
#   'chewing gum',
#   'frozen vegetables',
#   'liquor (appetizer)',
#   'napkins',
#   'newspapers'},
#  {'beverages'},
#  {'domestic eggs',
#   'hamburger meat',
#   'hygiene articles',
#   'margarine',
#   'oil',
#   'other vegetables',
#   'roll products',
#   'root vegetables'},
#  {'fruit/vegetable juice',
#   'other vegetables',
#   'root vegetables',
#   'white wine',
#   'whole milk',
#   'yogurt'},
#  {'canned beer'},
#  {'bottled beer', 'frozen vegetables'},
#  {'canned beer'},
#  {'newspapers'},
#  {'rolls/buns'},
#  {'UHT-milk', 'hamburger meat', 'salty snack'},
#  {'curd', 'pip fruit', 'rum', 'whole milk'},
#  {'canned beer'},
#  {'domestic eggs',
#   'frozen vegetables',
#   'grapes',
#   'root vegetables',
#   'white wine'},
#  {'butter',
#   'packaged fruit/vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'whipped/sour cream'},
#  {'canned beer',
#   'citrus fruit',
#   'frozen vegetables',
#   'rolls/buns',
#   'salty snack'},
#  {'cling film/bags', 'potted plants'},
#  {'baking powder',
#   'bottled beer',
#   'frankfurter',
#   'margarine',
#   'rolls/buns',
#   'whole milk'},
#  {'red/blush wine', 'whole milk'},
#  {'baking powder',
#   'cereals',
#   'curd',
#   'domestic eggs',
#   'frozen dessert',
#   'frozen meals',
#   'fruit/vegetable juice',
#   'hard cheese',
#   'pork',
#   'soap',
#   'tropical fruit',
#   'whole milk',
#   'yogurt'},
#  {'chicken', 'pastry'},
#  {'dish cleaner', 'dishes', 'sausage'},
#  {'specialty bar'},
#  {'pastry', 'specialty bar', 'whipped/sour cream'},
#  {'brown bread', 'root vegetables'},
#  {'rolls/buns', 'soda'},
#  {'bottled beer', 'other vegetables', 'red/blush wine'},
#  {'berries',
#   'bottled water',
#   'butter',
#   'citrus fruit',
#   'hygiene articles',
#   'napkins',
#   'other vegetables',
#   'root vegetables',
#   'rubbing alcohol',
#   'tropical fruit',
#   'whole milk'},
#  {'brown bread', 'pastry', 'processed cheese', 'soda', 'whole milk'},
#  {'candy',
#   'frankfurter',
#   'pastry',
#   'rolls/buns',
#   'root vegetables',
#   'sausage',
#   'tropical fruit',
#   'whole milk',
#   'yogurt'},
#  {'coffee', 'long life bakery product'},
#  {'ham', 'rolls/buns', 'white wine'},
#  {'canned beer'},
#  {'canned beer'},
#  {'canned beer'},
#  {'canned fish', 'pip fruit', 'whole milk'},
#  {'bottled water',
#   'curd',
#   'other vegetables',
#   'pip fruit',
#   'pork',
#   'soda',
#   'sugar',
#   'white bread',
#   'whole milk'},
#  {'soap'},
#  {'bottled water', 'butter', 'frozen meals', 'pasta', 'pip fruit'},
#  {'beef', 'citrus fruit', 'hamburger meat', 'mustard', 'soap', 'whole milk'},
#  {'bottled beer',
#   'chocolate',
#   'meat',
#   'newspapers',
#   'other vegetables',
#   'rolls/buns',
#   'sausage',
#   'soda',
#   'whole milk',
#   'yogurt'},
#  {'frozen chicken'},
#  {'soda'},
#  {'bottled beer',
#   'bottled water',
#   'brown bread',
#   'curd',
#   'rolls/buns',
#   'seasonal products',
#   'tropical fruit',
#   'yogurt'},
#  {'other vegetables'},
#  {'beef',
#   'citrus fruit',
#   'curd',
#   'detergent',
#   'margarine',
#   'newspapers',
#   'oil',
#   'rolls/buns',
#   'specialty bar'},
#  {'beef',
#   'citrus fruit',
#   'meat',
#   'other vegetables',
#   'pickled vegetables',
#   'pork',
#   'root vegetables',
#   'whole milk'},
#  {'butter',
#   'hamburger meat',
#   'meat',
#   'newspapers',
#   'packaged fruit/vegetables',
#   'root vegetables',
#   'whole milk'},
#  {'bottled water',
#   'long life bakery product',
#   'newspapers',
#   'red/blush wine',
#   'soda'},
#  {'rolls/buns'},
#  {'canned beer', 'pastry'},
#  {'pastry', 'pork', 'sauces', 'whole milk'},
#  {'light bulbs',
#   'newspapers',
#   'pastry',
#   'pip fruit',
#   'sliced cheese',
#   'white wine'},
#  {'UHT-milk',
#   'beef',
#   'bottled water',
#   'citrus fruit',
#   'frozen vegetables',
#   'rolls/buns',
#   'skin care',
#   'tropical fruit',
#   'yogurt'},
#  {'beef',
#   'berries',
#   'brown bread',
#   'citrus fruit',
#   'coffee',
#   'kitchen towels',
#   'sugar'},
#  {'rolls/buns', 'spices'},
#  {'butter',
#   'canned vegetables',
#   'citrus fruit',
#   'curd',
#   'frozen vegetables',
#   'herbs',
#   'misc. beverages',
#   'tropical fruit',
#   'whipped/sour cream',
#   'whole milk'},
#  {'beef',
#   'coffee',
#   'flour',
#   'frozen dessert',
#   'herbs',
#   'meat',
#   'oil',
#   'potted plants',
#   'rolls/buns',
#   'semi-finished bread',
#   'whole milk'},
#  {'beverages', 'bottled water', 'pastry'},
#  {'beef', 'citrus fruit', 'other vegetables', 'rolls/buns'},
#  {'hair spray', 'ham', 'margarine', 'white bread', 'whole milk'},
#  {'Instant food products',
#   'bottled beer',
#   'canned fish',
#   'coffee',
#   'hamburger meat',
#   'hygiene articles',
#   'ketchup',
#   'newspapers',
#   'oil',
#   'soups',
#   'whole milk'},
#  {'beef',
#   'bottled water',
#   'butter milk',
#   'citrus fruit',
#   'fruit/vegetable juice',
#   'margarine',
#   'other vegetables',
#   'processed cheese',
#   'rolls/buns',
#   'sliced cheese'},
#  {'beef',
#   'citrus fruit',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'pastry',
#   'roll products',
#   'rolls/buns',
#   'tea',
#   'whole milk'},
#  {'detergent', 'root vegetables', 'whole milk'},
#  {'candy',
#   'citrus fruit',
#   'cling film/bags',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'grapes',
#   'liquor',
#   'liquor (appetizer)',
#   'other vegetables',
#   'pickled vegetables',
#   'rum',
#   'tropical fruit'},
#  {'bottled water', 'yogurt'},
#  {'brown bread',
#   'canned fish',
#   'long life bakery product',
#   'other vegetables',
#   'root vegetables',
#   'tropical fruit',
#   'whipped/sour cream'},
#  {'frankfurter', 'newspapers', 'root vegetables'},
#  {'abrasive cleaner',
#   'beef',
#   'brown bread',
#   'other vegetables',
#   'pastry',
#   'salty snack',
#   'shopping bags',
#   'whole milk'},
#  {'shopping bags'},
#  {'canned beer'},
#  {'canned beer', 'rolls/buns'},
#  {'bottled water',
#   'candy',
#   'chocolate',
#   'meat spreads',
#   'misc. beverages',
#   'other vegetables',
#   'rolls/buns',
#   'soda',
#   'waffles'},
#  {'bottled water',
#   'hamburger meat',
#   'other vegetables',
#   'rolls/buns',
#   'yogurt'},
#  {'Instant food products',
#   'bottled water',
#   'canned fish',
#   'citrus fruit',
#   'fruit/vegetable juice',
#   'hamburger meat',
#   'napkins',
#   'rolls/buns',
#   'root vegetables',
#   'soda'},
#  {'chewing gum',
#   'domestic eggs',
#   'frankfurter',
#   'sausage',
#   'shopping bags',
#   'soda'},
#  {'bottled beer'},
#  {'domestic eggs', 'pastry', 'rolls/buns', 'tropical fruit'},
#  {'soda'},
#  {'canned beer',
#   'frankfurter',
#   'onions',
#   'other vegetables',
#   'root vegetables',
#   'white bread'},
#  {'canned beer',
#   'chicken',
#   'cling film/bags',
#   'dish cleaner',
#   'hamburger meat',
#   'herbs',
#   'napkins',
#   'soda',
#   'soups',
#   'whipped/sour cream'},
#  {'coffee', 'soda'},
#  {'whole milk'},
#  {'margarine'},
#  {'other vegetables', 'tropical fruit'},
#  {'meat', 'other vegetables'},
#  {'bottled water', 'canned beer', 'cream cheese'},
#  {'newspapers'},
#  {'newspapers', 'pastry', 'rolls/buns'},
#  {'citrus fruit',
#   'curd',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'other vegetables',
#   'potato products',
#   'whole milk',
#   'yogurt'},
#  {'detergent', 'rolls/buns', 'whole milk'},
#  {'UHT-milk',
#   'butter milk',
#   'citrus fruit',
#   'female sanitary products',
#   'frankfurter',
#   'rolls/buns',
#   'shopping bags'},
#  {'butter', 'ham', 'other vegetables', 'soda', 'sugar', 'whipped/sour cream'},
#  {'bottled beer', 'citrus fruit', 'frankfurter', 'salty snack'},
#  {'coffee', 'curd', 'domestic eggs', 'onions', 'sausage', 'yogurt'},
#  {'domestic eggs'},
#  {'domestic eggs', 'rolls/buns', 'soda', 'whole milk'},
#  {'bottled beer', 'newspapers', 'rolls/buns'},
#  {'chocolate marshmallow', 'hard cheese', 'whole milk'},
#  {'other vegetables', 'rolls/buns', 'root vegetables', 'sausage', 'soda'},
#  {'beverages', 'butter milk', 'curd', 'yogurt'},
#  {'bottled water'},
#  {'beef'},
#  {'chocolate marshmallow',
#   'coffee',
#   'frankfurter',
#   'hamburger meat',
#   'mustard',
#   'newspapers',
#   'potato products',
#   'rolls/buns',
#   'soap',
#   'waffles',
#   'whole milk'},
#  {'butter', 'chicken', 'newspapers'},
#  {'candles',
#   'coffee',
#   'meat',
#   'pastry',
#   'pip fruit',
#   'potted plants',
#   'sausage',
#   'sugar',
#   'tropical fruit'},
#  {'beverages', 'pork', 'whipped/sour cream', 'whole milk'},
#  {'coffee', 'pastry', 'yogurt'},
#  {'cat food',
#   'detergent',
#   'dishes',
#   'margarine',
#   'shopping bags',
#   'sliced cheese',
#   'whole milk'},
#  {'frankfurter',
#   'fruit/vegetable juice',
#   'ham',
#   'napkins',
#   'pastry',
#   'rolls/buns',
#   'soda',
#   'sugar',
#   'vinegar',
#   'whole milk',
#   'yogurt'},
#  {'beef', 'brown bread', 'newspapers', 'specialty chocolate', 'whole milk'},
#  {'butter milk',
#   'cream cheese',
#   'other vegetables',
#   'pip fruit',
#   'rolls/buns'},
#  {'chocolate', 'coffee', 'rolls/buns', 'sausage', 'whole milk'},
#  {'coffee', 'pastry'},
#  {'beef', 'chicken', 'specialty chocolate'},
#  {'chocolate',
#   'frozen dessert',
#   'frozen fish',
#   'frozen vegetables',
#   'other vegetables',
#   'root vegetables',
#   'sliced cheese',
#   'whole milk'},
#  {'frozen meals', 'rolls/buns', 'whole milk'},
#  {'detergent'},
#  {'canned fish', 'rolls/buns'},
#  {'house keeping products'},
#  {'cleaner', 'jam', 'salt', 'sparkling wine', 'yogurt'},
#  {'curd', 'rolls/buns', 'sliced cheese', 'soda', 'tropical fruit'},
#  {'tropical fruit'},
#  {'UHT-milk', 'artif. sweetener', 'curd', 'dental care'},
#  {'beef', 'berries', 'onions', 'rolls/buns'},
#  {'bottled water',
#   'brown bread',
#   'margarine',
#   'napkins',
#   'newspapers',
#   'pasta',
#   'whole milk'},
#  {'UHT-milk', 'bottled water', 'canned beer', 'pork', 'soda'},
#  {'cleaner',
#   'curd',
#   'curd cheese',
#   'hygiene articles',
#   'margarine',
#   'other vegetables',
#   'yogurt'},
#  {'canned beer',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'rolls/buns',
#   'shopping bags',
#   'soda',
#   'white wine'},
#  {'frankfurter', 'pip fruit', 'roll products', 'rolls/buns', 'whole milk'},
#  {'hygiene articles', 'newspapers', 'shopping bags', 'yogurt'},
#  {'cat food', 'coffee', 'curd', 'sliced cheese', 'whole milk'},
#  {'bottled water', 'candy'},
#  {'beef', 'butter', 'frankfurter'},
#  {'rolls/buns', 'shopping bags', 'snack products', 'soda'},
#  {'bottled water', 'hygiene articles', 'pastry', 'whole milk'},
#  {'rolls/buns'},
#  {'brown bread',
#   'chicken',
#   'onions',
#   'other vegetables',
#   'red/blush wine',
#   'white wine',
#   'whole milk'},
#  {'butter', 'dishes', 'onions', 'tropical fruit', 'whole milk'},
#  {'brown bread',
#   'hygiene articles',
#   'oil',
#   'other vegetables',
#   'sausage',
#   'shopping bags',
#   'turkey',
#   'yogurt'},
#  {'candy',
#   'curd',
#   'hard cheese',
#   'newspapers',
#   'other vegetables',
#   'sausage',
#   'soda',
#   'whole milk'},
#  {'citrus fruit',
#   'frankfurter',
#   'instant coffee',
#   'margarine',
#   'pastry',
#   'ready soups',
#   'shopping bags'},
#  {'UHT-milk',
#   'decalcifier',
#   'frozen dessert',
#   'fruit/vegetable juice',
#   'newspapers'},
#  {'newspapers', 'rolls/buns'},
#  {'canned beer'},
#  {'specialty bar', 'yogurt'},
#  {'specialty bar', 'whipped/sour cream'},
#  {'canned beer', 'rolls/buns'},
#  {'rolls/buns'},
#  {'beverages', 'rolls/buns'},
#  {'rolls/buns'},
#  {'rolls/buns', 'shopping bags'},
#  {'bottled beer'},
#  {'bottled water',
#   'citrus fruit',
#   'curd',
#   'oil',
#   'rolls/buns',
#   'sliced cheese',
#   'yogurt'},
#  {'bottled water', 'soda'},
#  {'pastry'},
#  {'candles', 'coffee', 'domestic eggs', 'pastry', 'rolls/buns'},
#  {'beef', 'margarine', 'pip fruit', 'rolls/buns', 'root vegetables'},
#  {'bottled water', 'newspapers', 'rolls/buns', 'spread cheese'},
#  {'rolls/buns', 'soda', 'spread cheese', 'tropical fruit'},
#  {'candles', 'canned beer', 'packaged fruit/vegetables'},
#  {'bottled beer',
#   'napkins',
#   'salty snack',
#   'white wine',
#   'whole milk',
#   'yogurt'},
#  {'beef',
#   'butter',
#   'domestic eggs',
#   'meat',
#   'other vegetables',
#   'rolls/buns',
#   'whole milk'},
#  {'bottled beer',
#   'detergent',
#   'dishes',
#   'liquor (appetizer)',
#   'onions',
#   'whole milk'},
#  {'UHT-milk',
#   'bottled water',
#   'brown bread',
#   'butter milk',
#   'frankfurter',
#   'grapes',
#   'margarine',
#   'organic products',
#   'other vegetables',
#   'soda'},
#  {'beef', 'bottled beer', 'rolls/buns'},
#  {'beef'},
#  {'bottled beer', 'liquor (appetizer)', 'sausage'},
#  {'chicken', 'herbs', 'hygiene articles', 'onions'},
#  {'canned beer'},
#  {'bottled beer',
#   'other vegetables',
#   'root vegetables',
#   'sausage',
#   'seasonal products',
#   'whole milk'},
#  {'curd', 'tropical fruit', 'whipped/sour cream', 'whole milk', 'yogurt'},
#  {'abrasive cleaner',
#   'flower (seeds)',
#   'frankfurter',
#   'newspapers',
#   'rolls/buns',
#   'soda'},
#  {'sausage', 'semi-finished bread', 'tropical fruit'},
#  {'beef', 'root vegetables', 'tropical fruit', 'yogurt'},
#  {'flour', 'pastry', 'rum', 'tropical fruit'},
#  {'yogurt'},
#  {'frankfurter', 'mustard', 'rolls/buns'},
#  {'bottled beer'},
#  {'grapes', 'soda'},
#  {'beverages', 'rolls/buns'},
# ...
#   'hygiene articles',
#   'other vegetables',
#   'pip fruit',
#   'shopping bags',
#   'whole milk'},
#  {'cream cheese', 'dessert', 'rice', 'root vegetables', 'yogurt'},
#  {'curd', 'newspapers', 'organic products', 'rolls/buns', 'tropical fruit'},
#  {'beef',
#   'butter',
#   'candles',
#   'coffee',
#   'domestic eggs',
#   'hard cheese',
#   'other vegetables',
#   'pasta',
#   'root vegetables',
#   'soft cheese',
#   'whole milk'},
#  {'butter', 'chicken', 'pork', 'white bread', 'whole milk'},
#  {'candles',
#   'citrus fruit',
#   'grapes',
#   'margarine',
#   'newspapers',
#   'oil',
#   'pastry',
#   'rolls/buns',
#   'whole milk'},
#  {'beef',
#   'coffee',
#   'frozen meals',
#   'fruit/vegetable juice',
#   'margarine',
#   'meat',
#   'other vegetables',
#   'pip fruit',
#   'potted plants',
#   'soft cheese',
#   'tropical fruit',
#   'whipped/sour cream'},
#  {'cream cheese', 'rolls/buns', 'spread cheese'},
#  {'bottled beer',
#   'bottled water',
#   'citrus fruit',
#   'herbs',
#   'potted plants',
#   'whole milk'},
#  {'specialty bar'},
#  {'beverages',
#   'chocolate',
#   'margarine',
#   'meat',
#   'napkins',
#   'newspapers',
#   'other vegetables',
#   'rolls/buns',
#   'whole milk'},
#  {'citrus fruit', 'pip fruit', 'tropical fruit'},
#  {'beef',
#   'frankfurter',
#   'frozen vegetables',
#   'packaged fruit/vegetables',
#   'root vegetables',
#   'tropical fruit',
#   'whole milk'},
#  {'citrus fruit', 'whole milk'},
#  {'bottled beer',
#   'curd',
#   'other vegetables',
#   'root vegetables',
#   'specialty chocolate',
#   'turkey'},
#  {'canned beer',
#   'citrus fruit',
#   'curd',
#   'dog food',
#   'mustard',
#   'onions',
#   'pasta',
#   'rolls/buns',
#   'whole milk',
#   'yogurt'},
#  {'domestic eggs', 'sausage'},
#  {'newspapers'},
#  {'whole milk', 'yogurt'},
#  {'yogurt'},
#  {'yogurt'},
#  {'bottled water'},
#  {'berries', 'domestic eggs', 'whipped/sour cream', 'whole milk'},
#  {'packaged fruit/vegetables', 'pastry', 'rolls/buns', 'whole milk'},
#  {'frankfurter', 'soda'},
#  {'jam',
#   'nuts/prunes',
#   'potted plants',
#   'semi-finished bread',
#   'shopping bags',
#   'soda',
#   'whole milk'},
#  {'butter',
#   'citrus fruit',
#   'coffee',
#   'dishes',
#   'flour',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'soda',
#   'sparkling wine',
#   'sugar',
#   'whipped/sour cream',
#   'whole milk'},
#  {'beef',
#   'citrus fruit',
#   'curd',
#   'fruit/vegetable juice',
#   'hard cheese',
#   'onions',
#   'rolls/buns',
#   'root vegetables'},
#  {'canned beer',
#   'coffee',
#   'frozen vegetables',
#   'napkins',
#   'whole milk',
#   'yogurt'},
#  {'other vegetables', 'whipped/sour cream'},
#  {'beef', 'other vegetables'},
#  {'berries',
#   'coffee',
#   'dessert',
#   'fish',
#   'other vegetables',
#   'red/blush wine',
#   'spread cheese',
#   'white wine',
#   'whole milk',
#   'yogurt'},
#  {'curd',
#   'domestic eggs',
#   'frozen vegetables',
#   'instant coffee',
#   'newspapers',
#   'other vegetables',
#   'sugar',
#   'whole milk'},
#  {'berries',
#   'butter',
#   'hard cheese',
#   'napkins',
#   'root vegetables',
#   'sliced cheese',
#   'specialty chocolate',
#   'tropical fruit',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'coffee'},
#  {'artif. sweetener',
#   'bottled water',
#   'frozen fish',
#   'hygiene articles',
#   'newspapers',
#   'other vegetables',
#   'pork',
#   'ready soups',
#   'rolls/buns',
#   'sausage',
#   'semi-finished bread'},
#  {'beverages',
#   'cream cheese',
#   'dishes',
#   'meat',
#   'root vegetables',
#   'waffles',
#   'whipped/sour cream'},
#  {'abrasive cleaner',
#   'butter',
#   'chicken',
#   'long life bakery product',
#   'margarine',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'pip fruit',
#   'rolls/buns',
#   'root vegetables',
#   'rum',
#   'sugar',
#   'tropical fruit'},
#  {'berries',
#   'fruit/vegetable juice',
#   'margarine',
#   'organic products',
#   'shopping bags',
#   'whipped/sour cream',
#   'whole milk'},
#  {'frozen meals', 'misc. beverages'},
#  {'whipped/sour cream'},
#  {'beef', 'bottled beer', 'chocolate', 'root vegetables', 'shopping bags'},
#  {'UHT-milk',
#   'bottled beer',
#   'bottled water',
#   'chicken',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'other vegetables',
#   'pork',
#   'rolls/buns',
#   'soda',
#   'whipped/sour cream',
#   'whole milk'},
#  {'Instant food products',
#   'brown bread',
#   'chicken',
#   'frozen potato products',
#   'fruit/vegetable juice',
#   'hamburger meat',
#   'nuts/prunes',
#   'other vegetables',
#   'pip fruit',
#   'pork',
#   'root vegetables',
#   'shopping bags',
#   'soda',
#   'spread cheese',
#   'whole milk'},
#  {'beef',
#   'bottled beer',
#   'bottled water',
#   'brown bread',
#   'hard cheese',
#   'herbs',
#   'other vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'salty snack',
#   'shopping bags',
#   'tropical fruit',
#   'whole milk',
#   'yogurt'},
#  {'packaged fruit/vegetables', 'pickled vegetables'},
#  {'sugar'},
#  {'beef',
#   'dessert',
#   'frankfurter',
#   'ice cream',
#   'packaged fruit/vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'sausage',
#   'sliced cheese',
#   'soda',
#   'whole milk',
#   'yogurt'},
#  {'berries', 'frozen vegetables', 'instant coffee', 'pet care'},
#  {'bottled water', 'chewing gum', 'napkins', 'soda'},
#  {'abrasive cleaner',
#   'berries',
#   'beverages',
#   'chicken',
#   'citrus fruit',
#   'curd',
#   'root vegetables',
#   'sausage'},
#  {'UHT-milk',
#   'dishes',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'newspapers',
#   'soda',
#   'whole milk'},
#  {'ice cream', 'rolls/buns'},
#  {'citrus fruit', 'frankfurter', 'rolls/buns', 'tropical fruit'},
#  {'brandy',
#   'brown bread',
#   'dog food',
#   'root vegetables',
#   'shopping bags',
#   'sweet spreads',
#   'white bread',
#   'whole milk'},
#  {'rolls/buns', 'sausage', 'specialty chocolate'},
#  {'baking powder',
#   'berries',
#   'citrus fruit',
#   'ham',
#   'packaged fruit/vegetables',
#   'pastry',
#   'sausage',
#   'sliced cheese',
#   'sugar',
#   'tropical fruit',
#   'whipped/sour cream',
#   'whole milk'},
#  {'beef', 'cream cheese', 'root vegetables', 'whole milk'},
#  {'fruit/vegetable juice'},
#  {'hygiene articles', 'sugar'},
#  {'berries', 'whipped/sour cream'},
#  {'beverages', 'coffee', 'yogurt'},
#  {'beef', 'pork'},
#  {'bottled beer', 'shopping bags'},
#  {'butter milk', 'coffee', 'curd', 'sliced cheese', 'yogurt'},
#  {'Instant food products', 'beef', 'canned beer'},
#  {'berries',
#   'beverages',
#   'chocolate',
#   'flour',
#   'newspapers',
#   'oil',
#   'pork',
#   'soda',
#   'whipped/sour cream'},
#  {'white bread'},
#  {'fruit/vegetable juice',
#   'grapes',
#   'processed cheese',
#   'rolls/buns',
#   'white bread',
#   'whole milk'},
#  {'flower (seeds)', 'potato products'},
#  {'bottled water',
#   'coffee',
#   'dishes',
#   'onions',
#   'rolls/buns',
#   'root vegetables',
#   'yogurt'},
#  {'UHT-milk',
#   'bathroom cleaner',
#   'canned beer',
#   'chicken',
#   'hamburger meat',
#   'newspapers',
#   'soda'},
#  {'chicken', 'other vegetables', 'salt'},
#  {'coffee', 'cream cheese', 'fish'},
#  {'canned beer'},
#  {'brown bread',
#   'frozen meals',
#   'napkins',
#   'other vegetables',
#   'rolls/buns',
#   'whole milk'},
#  {'bottled beer',
#   'brown bread',
#   'chicken',
#   'frozen vegetables',
#   'newspapers',
#   'pork',
#   'red/blush wine',
#   'vinegar',
#   'whole milk'},
#  {'misc. beverages', 'other vegetables'},
#  {'tropical fruit', 'whole milk'},
#  {'cake bar', 'newspapers', 'whole milk'},
#  {'beef', 'berries', 'hamburger meat', 'hygiene articles', 'pastry'},
#  {'grapes', 'rolls/buns', 'salty snack', 'sausage', 'soda'},
#  {'chocolate', 'rolls/buns', 'whole milk'},
#  {'rolls/buns', 'soda'},
#  {'citrus fruit', 'other vegetables', 'pip fruit', 'tropical fruit'},
#  {'artif. sweetener',
#   'bottled water',
#   'domestic eggs',
#   'shopping bags',
#   'sliced cheese',
#   'soda',
#   'whole milk'},
#  {'bottled beer', 'pastry', 'soda'},
#  {'coffee',
#   'curd cheese',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'hard cheese',
#   'hygiene articles',
#   'ice cream',
#   'other vegetables',
#   'pastry',
#   'soft cheese',
#   'spread cheese',
#   'tropical fruit',
#   'whole milk',
#   'yogurt'},
#  {'newspapers', 'pastry', 'sliced cheese'},
#  {'soda'},
#  {'citrus fruit',
#   'coffee',
#   'dessert',
#   'frozen meals',
#   'ham',
#   'popcorn',
#   'shopping bags',
#   'whole milk'},
#  {'salty snack'},
#  {'bottled water',
#   'coffee',
#   'cream cheese',
#   'curd',
#   'flour',
#   'misc. beverages',
#   'newspapers',
#   'whole milk'},
#  {'root vegetables', 'whipped/sour cream'},
#  {'canned beer', 'shopping bags', 'soda'},
#  {'bottled water',
#   'canned beer',
#   'curd',
#   'dish cleaner',
#   'margarine',
#   'roll products',
#   'white wine'},
#  {'bottled beer', 'bottled water', 'fruit/vegetable juice', 'napkins', 'soda'},
#  {'packaged fruit/vegetables', 'potted plants'},
#  {'bottled water',
#   'cling film/bags',
#   'frozen vegetables',
#   'ice cream',
#   'root vegetables',
#   'tropical fruit'},
#  {'beef',
#   'bottled water',
#   'chocolate',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'grapes',
#   'ham',
#   'newspapers',
#   'pastry',
#   'salty snack',
#   'shopping bags',
#   'whipped/sour cream',
#   'white bread',
#   'white wine',
#   'yogurt'},
#  {'UHT-milk',
#   'bottled beer',
#   'brown bread',
#   'canned beer',
#   'citrus fruit',
#   'long life bakery product',
#   'pork',
#   'soda'},
#  {'beverages', 'cake bar', 'liqueur', 'misc. beverages', 'rolls/buns', 'soda'},
#  {'rolls/buns', 'sausage', 'soda'},
#  {'bottled water',
#   'citrus fruit',
#   'napkins',
#   'rolls/buns',
#   'sausage',
#   'soda',
#   'whole milk',
#   'yogurt'},
#  {'butter',
#   'cream cheese',
#   'frozen fish',
#   'root vegetables',
#   'shopping bags',
#   'whole milk',
#   'yogurt'},
#  {'cream cheese', 'whole milk'},
#  {'frankfurter',
#   'other vegetables',
#   'pastry',
#   'ready soups',
#   'rolls/buns',
#   'root vegetables',
#   'turkey',
#   'yogurt'},
#  {'shopping bags', 'soda'},
#  {'bottled beer', 'soda'},
#  {'frankfurter', 'popcorn'},
#  {'berries',
#   'detergent',
#   'newspapers',
#   'pickled vegetables',
#   'whipped/sour cream',
#   'whole milk'},
#  {'canned beer'},
#  {'canned vegetables', 'frankfurter', 'pork', 'soda', 'white bread'},
#  {'butter',
#   'chocolate',
#   'chocolate marshmallow',
#   'curd',
#   'dental care',
#   'dish cleaner',
#   'flour',
#   'frankfurter',
#   'hamburger meat',
#   'mustard',
#   'oil',
#   'rice',
#   'salty snack',
#   'sugar',
#   'whole milk'},
#  {'berries',
#   'beverages',
#   'coffee',
#   'root vegetables',
#   'shopping bags',
#   'soups',
#   'sugar',
#   'whole milk'},
#  {'frankfurter', 'rolls/buns'},
#  {'newspapers'},
#  {'frozen fish', 'newspapers'},
#  {'newspapers', 'tropical fruit'},
#  {'beef',
#   'berries',
#   'grapes',
#   'newspapers',
#   'potted plants',
#   'rolls/buns',
#   'whole milk',
#   'yogurt'},
#  {'coffee',
#   'instant coffee',
#   'rolls/buns',
#   'salty snack',
#   'specialty chocolate'},
#  {'potted plants', 'specialty chocolate'},
#  {'dish cleaner', 'sparkling wine'},
#  {'citrus fruit', 'napkins', 'shopping bags'},
#  {'bottled beer', 'herbs', 'onions'},
#  {'candles', 'detergent', 'pastry', 'whole milk'},
#  {'photo/film'},
#  {'hamburger meat'},
#  {'chewing gum', 'other vegetables', 'white bread', 'whole milk'},
#  {'rolls/buns', 'shopping bags', 'whole milk'},
#  {'grapes',
#   'hard cheese',
#   'napkins',
#   'pork',
#   'shopping bags',
#   'soda',
#   'tropical fruit'},
#  {'baking powder',
#   'berries',
#   'bottled water',
#   'butter',
#   'canned beer',
#   'dessert',
#   'fruit/vegetable juice',
#   'grapes',
#   'ice cream',
#   'misc. beverages',
#   'other vegetables',
#   'pastry',
#   'potted plants',
#   'salt',
#   'specialty chocolate',
#   'tropical fruit',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'chewing gum',
#   'chicken',
#   'citrus fruit',
#   'other vegetables',
#   'pork',
#   'potted plants',
#   'whipped/sour cream',
#   'white bread'},
#  {'chewing gum', 'other vegetables'},
#  {'bottled water', 'red/blush wine', 'sausage'},
#  {'baking powder', 'whipped/sour cream', 'whole milk'},
#  {'coffee', 'rolls/buns'},
#  {'hygiene articles'},
#  {'ice cream', 'newspapers'},
#  {'curd',
#   'domestic eggs',
#   'flour',
#   'misc. beverages',
#   'newspapers',
#   'whipped/sour cream'},
#  {'frozen meals', 'newspapers', 'whole milk'},
#  {'bottled water',
#   'coffee',
#   'dessert',
#   'domestic eggs',
#   'onions',
#   'rolls/buns',
#   'white bread',
#   'whole milk'},
#  {'finished products',
#   'fruit/vegetable juice',
#   'organic sausage',
#   'sliced cheese',
#   'white bread'},
#  {'dog food', 'long life bakery product', 'salt'},
#  {'brown bread',
#   'canned vegetables',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'other vegetables',
#   'root vegetables',
#   'rum',
#   'soda',
#   'tropical fruit',
#   'white bread'},
#  {'other vegetables', 'whole milk', 'yogurt'},
#  {'chocolate'},
#  {'ice cream'},
#  {'cat food', 'oil', 'tropical fruit'},
#  {'citrus fruit',
#   'frankfurter',
#   'fruit/vegetable juice',
#   'pastry',
#   'sliced cheese',
#   'specialty cheese',
#   'whole milk',
#   'yogurt'},
#  {'butter', 'canned fish', 'flower (seeds)', 'pasta', 'softener'},
#  {'butter milk', 'frozen fish', 'other vegetables', 'salty snack'},
#  {'canned beer', 'chocolate', 'pastry', 'tropical fruit'},
#  {'brown bread',
#   'citrus fruit',
#   'packaged fruit/vegetables',
#   'rolls/buns',
#   'root vegetables',
#   'sliced cheese',
#   'white bread',
#   'yogurt',
#   'zwieback'},
#  {'UHT-milk', 'salt', 'shopping bags', 'soda', 'specialty chocolate'},
#  {'beef'},
#  {'canned vegetables', 'curd', 'spread cheese', 'sugar', 'yogurt'},
#  {'bottled beer',
#   'citrus fruit',
#   'dessert',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'other vegetables',
#   'salty snack',
#   'whole milk',
#   'yogurt'},
#  {'bottled beer', 'brown bread', 'white wine', 'yogurt'},
#  {'bottled beer', 'liquor', 'red/blush wine'},
#  {'grapes'},
#  {'other vegetables', 'pork', 'soda'},
#  {'berries',
#   'candy',
#   'canned fish',
#   'chocolate',
#   'citrus fruit',
#   'cream cheese',
#   'domestic eggs',
#   'frozen vegetables',
#   'margarine',
#   'napkins',
#   'other vegetables',
#   'pastry',
#   'sausage',
#   'soups',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'UHT-milk',
#   'brown bread',
#   'chicken',
#   'chocolate',
#   'cocoa drinks',
#   'coffee',
#   'flour',
#   'frankfurter',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'mayonnaise',
#   'mustard',
#   'other vegetables',
#   'pastry',
#   'pork',
#   'root vegetables',
#   'salty snack',
#   'seasonal products',
#   'tropical fruit',
#   'yogurt'},
#  {'artif. sweetener', 'photo/film', 'soda'},
#  {'bottled beer',
#   'butter',
#   'coffee',
#   'frankfurter',
#   'onions',
#   'processed cheese',
#   'rolls/buns'},
#  {'dessert',
#   'domestic eggs',
#   'pip fruit',
#   'root vegetables',
#   'shopping bags',
#   'yogurt'},
#  {'coffee', 'detergent', 'frankfurter', 'whole milk'},
#  {'newspapers', 'whole milk'},
#  {'domestic eggs', 'flower soil/fertilizer', 'hygiene articles', 'photo/film'},
#  {'chocolate',
#   'dessert',
#   'flower (seeds)',
#   'mayonnaise',
#   'oil',
#   'packaged fruit/vegetables',
#   'shopping bags',
#   'soda',
#   'waffles'},
#  {'bottled water',
#   'chicken',
#   'frozen vegetables',
#   'long life bakery product',
#   'other vegetables',
#   'whipped/sour cream'},
#  {'baking powder',
#   'candy',
#   'cocoa drinks',
#   'coffee',
#   'cream cheese',
#   'curd',
#   'domestic eggs',
#   'napkins',
#   'pork',
#   'salty snack',
#   'sugar',
#   'waffles',
#   'whipped/sour cream',
#   'white bread',
#   'whole milk',
#   'yogurt'},
#  {'citrus fruit',
#   'cleaner',
#   'coffee',
#   'cream cheese',
#   'curd',
#   'detergent',
#   'long life bakery product',
#   'napkins',
#   'newspapers',
#   'oil',
#   'other vegetables',
#   'pastry',
#   'vinegar',
#   'whipped/sour cream',
#   'whole milk',
#   'yogurt'},
#  {'light bulbs'},
#  {'cream cheese', 'margarine', 'tea'},
#  {'cake bar',
#   'cleaner',
#   'curd',
#   'detergent',
#   'domestic eggs',
#   'frozen meals',
#   'house keeping products',
#   'potted plants',
#   'sausage',
#   'seasonal products',
#   'shopping bags'},
#  {'citrus fruit', 'onions'},
#  {'other vegetables', 'roll products', 'whipped/sour cream'},
#  {'bottled water',
#   'butter',
#   'chicken',
#   'cling film/bags',
#   'dog food',
#   'domestic eggs',
#   'frozen fish',
#   'frozen vegetables',
#   'fruit/vegetable juice',
#   'hard cheese',
#   'long life bakery product',
#   'napkins',
#   'other vegetables',
#   'pip fruit',
#   'rice',
#   'root vegetables',
#   'softener',
#   'specialty fat',
#   'tropical fruit',
#   'whipped/sour cream',
#   'white bread',
#   'whole milk',
#   'yogurt'},
#  {'ice cream'},
#  {'beef', 'ice cream', 'newspapers', 'pork', 'rolls/buns'},
#  {'artif. sweetener',
#   'chocolate marshmallow',
#   'flour',
#   'margarine',
#   'organic products',
#   'other vegetables',
#   'pork',
#   'semi-finished bread',
#   'tropical fruit',
#   'yogurt'},
#  ...]

# %%
L1, suppData0 = ap.scanD(D, C1, 0.08)

# %%
L1
# Out:
# [frozenset({'shopping bags'}),
#  frozenset({'sausage'}),
#  frozenset({'root vegetables'}),
#  frozenset({'pastry'}),
#  frozenset({'soda'}),
#  frozenset({'bottled water'}),
#  frozenset({'bottled beer'}),
#  frozenset({'rolls/buns'}),
#  frozenset({'other vegetables'}),
#  frozenset({'whole milk'}),
#  frozenset({'yogurt'}),
#  frozenset({'tropical fruit'}),
#  frozenset({'citrus fruit'})]

# %%
L, suppData = ap.apriori(dataSet, minSupport = 0.02)

# %%
L
# Out:
# [[frozenset({'meat'}),
#   frozenset({'sliced cheese'}),
#   frozenset({'onions'}),
#   frozenset({'frozen meals'}),
#   frozenset({'specialty chocolate'}),
#   frozenset({'frozen vegetables'}),
#   frozenset({'ice cream'}),
#   frozenset({'oil'}),
#   frozenset({'chewing gum'}),
#   frozenset({'ham'}),
#   frozenset({'cat food'}),
#   frozenset({'hard cheese'}),
#   frozenset({'misc. beverages'}),
#   frozenset({'domestic eggs'}),
#   frozenset({'dessert'}),
#   frozenset({'grapes'}),
#   frozenset({'whipped/sour cream'}),
#   frozenset({'pork'}),
#   frozenset({'berries'}),
#   frozenset({'napkins'}),
#   frozenset({'hygiene articles'}),
#   frozenset({'hamburger meat'}),
#   frozenset({'beverages'}),
#   frozenset({'shopping bags'}),
#   frozenset({'brown bread'}),
#   frozenset({'sausage'}),
#   frozenset({'canned beer'}),
#   frozenset({'waffles'}),
#   frozenset({'salty snack'}),
#   frozenset({'root vegetables'}),
#   frozenset({'candy'}),
#   frozenset({'pastry'}),
#   frozenset({'butter milk'}),
#   frozenset({'specialty bar'}),
#   frozenset({'sugar'}),
#   frozenset({'newspapers'}),
#   frozenset({'fruit/vegetable juice'}),
#   frozenset({'chicken'}),
#   frozenset({'soda'}),
#   frozenset({'frankfurter'}),
#   frozenset({'beef'}),
#   frozenset({'curd'}),
#   frozenset({'white bread'}),
#   frozenset({'chocolate'}),
#   frozenset({'bottled water'}),
#   frozenset({'bottled beer'}),
#   frozenset({'UHT-milk'}),
#   frozenset({'rolls/buns'}),
#   frozenset({'butter'}),
#   frozenset({'other vegetables'}),
#   frozenset({'long life bakery product'}),
#   frozenset({'pip fruit'}),
#   frozenset({'cream cheese'}),
#   frozenset({'whole milk'}),
#   frozenset({'yogurt'}),
#   frozenset({'tropical fruit'}),
#   frozenset({'coffee'}),
#   frozenset({'margarine'}),
#   frozenset({'citrus fruit'})],
#  [frozenset({'whipped/sour cream', 'yogurt'}),
#   frozenset({'other vegetables', 'yogurt'}),
#   frozenset({'other vegetables', 'pip fruit'}),
#   frozenset({'other vegetables', 'pastry'}),
#   frozenset({'other vegetables', 'shopping bags'}),
#   frozenset({'other vegetables', 'sausage'}),
#   frozenset({'bottled beer', 'whole milk'}),
#   frozenset({'shopping bags', 'whole milk'}),
#   frozenset({'citrus fruit', 'other vegetables'}),
#   frozenset({'fruit/vegetable juice', 'whole milk'}),
#   frozenset({'frankfurter', 'whole milk'}),
#   frozenset({'newspapers', 'whole milk'}),
#   frozenset({'margarine', 'whole milk'}),
#   frozenset({'pip fruit', 'tropical fruit'}),
#   frozenset({'pip fruit', 'whole milk'}),
#   frozenset({'rolls/buns', 'whole milk'}),
#   frozenset({'beef', 'whole milk'}),
#   frozenset({'sausage', 'whole milk'}),
#   frozenset({'frozen vegetables', 'whole milk'}),
#   frozenset({'pastry', 'rolls/buns'}),
#   frozenset({'fruit/vegetable juice', 'other vegetables'}),
#   frozenset({'domestic eggs', 'other vegetables'}),
#   frozenset({'butter', 'other vegetables'}),
#   frozenset({'rolls/buns', 'yogurt'}),
#   frozenset({'bottled water', 'soda'}),
#   frozenset({'soda', 'tropical fruit'}),
#   frozenset({'soda', 'yogurt'}),
#   frozenset({'pastry', 'whole milk'}),
#   frozenset({'root vegetables', 'yogurt'}),
#   frozenset({'brown bread', 'whole milk'}),
#   frozenset({'domestic eggs', 'whole milk'}),
#   frozenset({'pastry', 'soda'}),
#   frozenset({'soda', 'whole milk'}),
#   frozenset({'other vegetables', 'soda'}),
#   frozenset({'pork', 'whole milk'}),
#   frozenset({'other vegetables', 'pork'}),
#   frozenset({'whipped/sour cream', 'whole milk'}),
#   frozenset({'other vegetables', 'whipped/sour cream'}),
#   frozenset({'root vegetables', 'whole milk'}),
#   frozenset({'bottled water', 'rolls/buns'}),
#   frozenset({'shopping bags', 'soda'}),
#   frozenset({'rolls/buns', 'sausage'}),
#   frozenset({'sausage', 'soda'}),
#   frozenset({'rolls/buns', 'tropical fruit'}),
#   frozenset({'root vegetables', 'tropical fruit'}),
#   frozenset({'other vegetables', 'root vegetables'}),
#   frozenset({'rolls/buns', 'root vegetables'}),
#   frozenset({'rolls/buns', 'soda'}),
#   frozenset({'citrus fruit', 'yogurt'}),
#   frozenset({'citrus fruit', 'whole milk'}),
#   frozenset({'tropical fruit', 'whole milk'}),
#   frozenset({'bottled water', 'yogurt'}),
#   frozenset({'bottled water', 'whole milk'}),
#   frozenset({'curd', 'whole milk'}),
#   frozenset({'other vegetables', 'tropical fruit'}),
#   frozenset({'bottled water', 'other vegetables'}),
#   frozenset({'other vegetables', 'rolls/buns'}),
#   frozenset({'whole milk', 'yogurt'}),
#   frozenset({'butter', 'whole milk'}),
#   frozenset({'other vegetables', 'whole milk'}),
#   frozenset({'tropical fruit', 'yogurt'})],
#  [frozenset({'other vegetables', 'whole milk', 'yogurt'}),
#   frozenset({'other vegetables', 'root vegetables', 'whole milk'})],
#  []]

# %%
L[0]
# Out:
# [frozenset({'meat'}),
#  frozenset({'sliced cheese'}),
#  frozenset({'onions'}),
#  frozenset({'frozen meals'}),
#  frozenset({'specialty chocolate'}),
#  frozenset({'frozen vegetables'}),
#  frozenset({'ice cream'}),
#  frozenset({'oil'}),
#  frozenset({'chewing gum'}),
#  frozenset({'ham'}),
#  frozenset({'cat food'}),
#  frozenset({'hard cheese'}),
#  frozenset({'misc. beverages'}),
#  frozenset({'domestic eggs'}),
#  frozenset({'dessert'}),
#  frozenset({'grapes'}),
#  frozenset({'whipped/sour cream'}),
#  frozenset({'pork'}),
#  frozenset({'berries'}),
#  frozenset({'napkins'}),
#  frozenset({'hygiene articles'}),
#  frozenset({'hamburger meat'}),
#  frozenset({'beverages'}),
#  frozenset({'shopping bags'}),
#  frozenset({'brown bread'}),
#  frozenset({'sausage'}),
#  frozenset({'canned beer'}),
#  frozenset({'waffles'}),
#  frozenset({'salty snack'}),
#  frozenset({'root vegetables'}),
#  frozenset({'candy'}),
#  frozenset({'pastry'}),
#  frozenset({'butter milk'}),
#  frozenset({'specialty bar'}),
#  frozenset({'sugar'}),
#  frozenset({'newspapers'}),
#  frozenset({'fruit/vegetable juice'}),
#  frozenset({'chicken'}),
#  frozenset({'soda'}),
#  frozenset({'frankfurter'}),
#  frozenset({'beef'}),
#  frozenset({'curd'}),
#  frozenset({'white bread'}),
#  frozenset({'chocolate'}),
#  frozenset({'bottled water'}),
#  frozenset({'bottled beer'}),
#  frozenset({'UHT-milk'}),
#  frozenset({'rolls/buns'}),
#  frozenset({'butter'}),
#  frozenset({'other vegetables'}),
#  frozenset({'long life bakery product'}),
#  frozenset({'pip fruit'}),
#  frozenset({'cream cheese'}),
#  frozenset({'whole milk'}),
#  frozenset({'yogurt'}),
#  frozenset({'tropical fruit'}),
#  frozenset({'coffee'}),
#  frozenset({'margarine'}),
#  frozenset({'citrus fruit'})]

# %%
L[1]
# Out:
# [frozenset({'whipped/sour cream', 'yogurt'}),
#  frozenset({'other vegetables', 'yogurt'}),
#  frozenset({'other vegetables', 'pip fruit'}),
#  frozenset({'other vegetables', 'pastry'}),
#  frozenset({'other vegetables', 'shopping bags'}),
#  frozenset({'other vegetables', 'sausage'}),
#  frozenset({'bottled beer', 'whole milk'}),
#  frozenset({'shopping bags', 'whole milk'}),
#  frozenset({'citrus fruit', 'other vegetables'}),
#  frozenset({'fruit/vegetable juice', 'whole milk'}),
#  frozenset({'frankfurter', 'whole milk'}),
#  frozenset({'newspapers', 'whole milk'}),
#  frozenset({'margarine', 'whole milk'}),
#  frozenset({'pip fruit', 'tropical fruit'}),
#  frozenset({'pip fruit', 'whole milk'}),
#  frozenset({'rolls/buns', 'whole milk'}),
#  frozenset({'beef', 'whole milk'}),
#  frozenset({'sausage', 'whole milk'}),
#  frozenset({'frozen vegetables', 'whole milk'}),
#  frozenset({'pastry', 'rolls/buns'}),
#  frozenset({'fruit/vegetable juice', 'other vegetables'}),
#  frozenset({'domestic eggs', 'other vegetables'}),
#  frozenset({'butter', 'other vegetables'}),
#  frozenset({'rolls/buns', 'yogurt'}),
#  frozenset({'bottled water', 'soda'}),
#  frozenset({'soda', 'tropical fruit'}),
#  frozenset({'soda', 'yogurt'}),
#  frozenset({'pastry', 'whole milk'}),
#  frozenset({'root vegetables', 'yogurt'}),
#  frozenset({'brown bread', 'whole milk'}),
#  frozenset({'domestic eggs', 'whole milk'}),
#  frozenset({'pastry', 'soda'}),
#  frozenset({'soda', 'whole milk'}),
#  frozenset({'other vegetables', 'soda'}),
#  frozenset({'pork', 'whole milk'}),
#  frozenset({'other vegetables', 'pork'}),
#  frozenset({'whipped/sour cream', 'whole milk'}),
#  frozenset({'other vegetables', 'whipped/sour cream'}),
#  frozenset({'root vegetables', 'whole milk'}),
#  frozenset({'bottled water', 'rolls/buns'}),
#  frozenset({'shopping bags', 'soda'}),
#  frozenset({'rolls/buns', 'sausage'}),
#  frozenset({'sausage', 'soda'}),
#  frozenset({'rolls/buns', 'tropical fruit'}),
#  frozenset({'root vegetables', 'tropical fruit'}),
#  frozenset({'other vegetables', 'root vegetables'}),
#  frozenset({'rolls/buns', 'root vegetables'}),
#  frozenset({'rolls/buns', 'soda'}),
#  frozenset({'citrus fruit', 'yogurt'}),
#  frozenset({'citrus fruit', 'whole milk'}),
#  frozenset({'tropical fruit', 'whole milk'}),
#  frozenset({'bottled water', 'yogurt'}),
#  frozenset({'bottled water', 'whole milk'}),
#  frozenset({'curd', 'whole milk'}),
#  frozenset({'other vegetables', 'tropical fruit'}),
#  frozenset({'bottled water', 'other vegetables'}),
#  frozenset({'other vegetables', 'rolls/buns'}),
#  frozenset({'whole milk', 'yogurt'}),
#  frozenset({'butter', 'whole milk'}),
#  frozenset({'other vegetables', 'whole milk'}),
#  frozenset({'tropical fruit', 'yogurt'})]

# %%
L[2]
# Out:
# [frozenset({'other vegetables', 'whole milk', 'yogurt'}),
#  frozenset({'other vegetables', 'root vegetables', 'whole milk'})]

# %%
L[3]
# Out:
# []

# %%
ap.aprioriGen(L[0], 2)
# Out:
# [frozenset({'meat', 'sliced cheese'}),
#  frozenset({'meat', 'onions'}),
#  frozenset({'frozen meals', 'meat'}),
#  frozenset({'meat', 'specialty chocolate'}),
#  frozenset({'frozen vegetables', 'meat'}),
#  frozenset({'ice cream', 'meat'}),
#  frozenset({'meat', 'oil'}),
#  frozenset({'chewing gum', 'meat'}),
#  frozenset({'ham', 'meat'}),
#  frozenset({'cat food', 'meat'}),
#  frozenset({'hard cheese', 'meat'}),
#  frozenset({'meat', 'misc. beverages'}),
#  frozenset({'domestic eggs', 'meat'}),
#  frozenset({'dessert', 'meat'}),
#  frozenset({'grapes', 'meat'}),
#  frozenset({'meat', 'whipped/sour cream'}),
#  frozenset({'meat', 'pork'}),
#  frozenset({'berries', 'meat'}),
#  frozenset({'meat', 'napkins'}),
#  frozenset({'hygiene articles', 'meat'}),
#  frozenset({'hamburger meat', 'meat'}),
#  frozenset({'beverages', 'meat'}),
#  frozenset({'meat', 'shopping bags'}),
#  frozenset({'brown bread', 'meat'}),
#  frozenset({'meat', 'sausage'}),
#  frozenset({'canned beer', 'meat'}),
#  frozenset({'meat', 'waffles'}),
#  frozenset({'meat', 'salty snack'}),
#  frozenset({'meat', 'root vegetables'}),
#  frozenset({'candy', 'meat'}),
#  frozenset({'meat', 'pastry'}),
#  frozenset({'butter milk', 'meat'}),
#  frozenset({'meat', 'specialty bar'}),
#  frozenset({'meat', 'sugar'}),
#  frozenset({'meat', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'meat'}),
#  frozenset({'chicken', 'meat'}),
#  frozenset({'meat', 'soda'}),
#  frozenset({'frankfurter', 'meat'}),
#  frozenset({'beef', 'meat'}),
#  frozenset({'curd', 'meat'}),
#  frozenset({'meat', 'white bread'}),
#  frozenset({'chocolate', 'meat'}),
#  frozenset({'bottled water', 'meat'}),
#  frozenset({'bottled beer', 'meat'}),
#  frozenset({'UHT-milk', 'meat'}),
#  frozenset({'meat', 'rolls/buns'}),
#  frozenset({'butter', 'meat'}),
#  frozenset({'meat', 'other vegetables'}),
#  frozenset({'long life bakery product', 'meat'}),
#  frozenset({'meat', 'pip fruit'}),
#  frozenset({'cream cheese', 'meat'}),
#  frozenset({'meat', 'whole milk'}),
#  frozenset({'meat', 'yogurt'}),
#  frozenset({'meat', 'tropical fruit'}),
#  frozenset({'coffee', 'meat'}),
#  frozenset({'margarine', 'meat'}),
#  frozenset({'citrus fruit', 'meat'}),
#  frozenset({'onions', 'sliced cheese'}),
#  frozenset({'frozen meals', 'sliced cheese'}),
#  frozenset({'sliced cheese', 'specialty chocolate'}),
#  frozenset({'frozen vegetables', 'sliced cheese'}),
#  frozenset({'ice cream', 'sliced cheese'}),
#  frozenset({'oil', 'sliced cheese'}),
#  frozenset({'chewing gum', 'sliced cheese'}),
#  frozenset({'ham', 'sliced cheese'}),
#  frozenset({'cat food', 'sliced cheese'}),
#  frozenset({'hard cheese', 'sliced cheese'}),
#  frozenset({'misc. beverages', 'sliced cheese'}),
#  frozenset({'domestic eggs', 'sliced cheese'}),
#  frozenset({'dessert', 'sliced cheese'}),
#  frozenset({'grapes', 'sliced cheese'}),
#  frozenset({'sliced cheese', 'whipped/sour cream'}),
#  frozenset({'pork', 'sliced cheese'}),
#  frozenset({'berries', 'sliced cheese'}),
#  frozenset({'napkins', 'sliced cheese'}),
#  frozenset({'hygiene articles', 'sliced cheese'}),
#  frozenset({'hamburger meat', 'sliced cheese'}),
#  frozenset({'beverages', 'sliced cheese'}),
#  frozenset({'shopping bags', 'sliced cheese'}),
#  frozenset({'brown bread', 'sliced cheese'}),
#  frozenset({'sausage', 'sliced cheese'}),
#  frozenset({'canned beer', 'sliced cheese'}),
#  frozenset({'sliced cheese', 'waffles'}),
#  frozenset({'salty snack', 'sliced cheese'}),
#  frozenset({'root vegetables', 'sliced cheese'}),
#  frozenset({'candy', 'sliced cheese'}),
#  frozenset({'pastry', 'sliced cheese'}),
#  frozenset({'butter milk', 'sliced cheese'}),
#  frozenset({'sliced cheese', 'specialty bar'}),
#  frozenset({'sliced cheese', 'sugar'}),
#  frozenset({'newspapers', 'sliced cheese'}),
#  frozenset({'fruit/vegetable juice', 'sliced cheese'}),
#  frozenset({'chicken', 'sliced cheese'}),
#  frozenset({'sliced cheese', 'soda'}),
#  frozenset({'frankfurter', 'sliced cheese'}),
#  frozenset({'beef', 'sliced cheese'}),
#  frozenset({'curd', 'sliced cheese'}),
#  frozenset({'sliced cheese', 'white bread'}),
#  frozenset({'chocolate', 'sliced cheese'}),
#  frozenset({'bottled water', 'sliced cheese'}),
#  frozenset({'bottled beer', 'sliced cheese'}),
#  frozenset({'UHT-milk', 'sliced cheese'}),
#  frozenset({'rolls/buns', 'sliced cheese'}),
#  frozenset({'butter', 'sliced cheese'}),
#  frozenset({'other vegetables', 'sliced cheese'}),
#  frozenset({'long life bakery product', 'sliced cheese'}),
#  frozenset({'pip fruit', 'sliced cheese'}),
#  frozenset({'cream cheese', 'sliced cheese'}),
#  frozenset({'sliced cheese', 'whole milk'}),
#  frozenset({'sliced cheese', 'yogurt'}),
#  frozenset({'sliced cheese', 'tropical fruit'}),
#  frozenset({'coffee', 'sliced cheese'}),
#  frozenset({'margarine', 'sliced cheese'}),
#  frozenset({'citrus fruit', 'sliced cheese'}),
#  frozenset({'frozen meals', 'onions'}),
#  frozenset({'onions', 'specialty chocolate'}),
#  frozenset({'frozen vegetables', 'onions'}),
#  frozenset({'ice cream', 'onions'}),
#  frozenset({'oil', 'onions'}),
#  frozenset({'chewing gum', 'onions'}),
#  frozenset({'ham', 'onions'}),
#  frozenset({'cat food', 'onions'}),
#  frozenset({'hard cheese', 'onions'}),
#  frozenset({'misc. beverages', 'onions'}),
#  frozenset({'domestic eggs', 'onions'}),
#  frozenset({'dessert', 'onions'}),
#  frozenset({'grapes', 'onions'}),
#  frozenset({'onions', 'whipped/sour cream'}),
#  frozenset({'onions', 'pork'}),
#  frozenset({'berries', 'onions'}),
#  frozenset({'napkins', 'onions'}),
#  frozenset({'hygiene articles', 'onions'}),
#  frozenset({'hamburger meat', 'onions'}),
#  frozenset({'beverages', 'onions'}),
#  frozenset({'onions', 'shopping bags'}),
#  frozenset({'brown bread', 'onions'}),
#  frozenset({'onions', 'sausage'}),
#  frozenset({'canned beer', 'onions'}),
#  frozenset({'onions', 'waffles'}),
#  frozenset({'onions', 'salty snack'}),
#  frozenset({'onions', 'root vegetables'}),
#  frozenset({'candy', 'onions'}),
#  frozenset({'onions', 'pastry'}),
#  frozenset({'butter milk', 'onions'}),
#  frozenset({'onions', 'specialty bar'}),
#  frozenset({'onions', 'sugar'}),
#  frozenset({'newspapers', 'onions'}),
#  frozenset({'fruit/vegetable juice', 'onions'}),
#  frozenset({'chicken', 'onions'}),
#  frozenset({'onions', 'soda'}),
#  frozenset({'frankfurter', 'onions'}),
#  frozenset({'beef', 'onions'}),
#  frozenset({'curd', 'onions'}),
#  frozenset({'onions', 'white bread'}),
#  frozenset({'chocolate', 'onions'}),
#  frozenset({'bottled water', 'onions'}),
#  frozenset({'bottled beer', 'onions'}),
#  frozenset({'UHT-milk', 'onions'}),
#  frozenset({'onions', 'rolls/buns'}),
#  frozenset({'butter', 'onions'}),
#  frozenset({'onions', 'other vegetables'}),
#  frozenset({'long life bakery product', 'onions'}),
#  frozenset({'onions', 'pip fruit'}),
#  frozenset({'cream cheese', 'onions'}),
#  frozenset({'onions', 'whole milk'}),
#  frozenset({'onions', 'yogurt'}),
#  frozenset({'onions', 'tropical fruit'}),
#  frozenset({'coffee', 'onions'}),
#  frozenset({'margarine', 'onions'}),
#  frozenset({'citrus fruit', 'onions'}),
#  frozenset({'frozen meals', 'specialty chocolate'}),
#  frozenset({'frozen meals', 'frozen vegetables'}),
#  frozenset({'frozen meals', 'ice cream'}),
#  frozenset({'frozen meals', 'oil'}),
#  frozenset({'chewing gum', 'frozen meals'}),
#  frozenset({'frozen meals', 'ham'}),
#  frozenset({'cat food', 'frozen meals'}),
#  frozenset({'frozen meals', 'hard cheese'}),
#  frozenset({'frozen meals', 'misc. beverages'}),
#  frozenset({'domestic eggs', 'frozen meals'}),
#  frozenset({'dessert', 'frozen meals'}),
#  frozenset({'frozen meals', 'grapes'}),
#  frozenset({'frozen meals', 'whipped/sour cream'}),
#  frozenset({'frozen meals', 'pork'}),
#  frozenset({'berries', 'frozen meals'}),
#  frozenset({'frozen meals', 'napkins'}),
#  frozenset({'frozen meals', 'hygiene articles'}),
#  frozenset({'frozen meals', 'hamburger meat'}),
#  frozenset({'beverages', 'frozen meals'}),
#  frozenset({'frozen meals', 'shopping bags'}),
#  frozenset({'brown bread', 'frozen meals'}),
#  frozenset({'frozen meals', 'sausage'}),
#  frozenset({'canned beer', 'frozen meals'}),
#  frozenset({'frozen meals', 'waffles'}),
#  frozenset({'frozen meals', 'salty snack'}),
#  frozenset({'frozen meals', 'root vegetables'}),
#  frozenset({'candy', 'frozen meals'}),
#  frozenset({'frozen meals', 'pastry'}),
#  frozenset({'butter milk', 'frozen meals'}),
#  frozenset({'frozen meals', 'specialty bar'}),
#  frozenset({'frozen meals', 'sugar'}),
#  frozenset({'frozen meals', 'newspapers'}),
#  frozenset({'frozen meals', 'fruit/vegetable juice'}),
#  frozenset({'chicken', 'frozen meals'}),
#  frozenset({'frozen meals', 'soda'}),
#  frozenset({'frankfurter', 'frozen meals'}),
#  frozenset({'beef', 'frozen meals'}),
#  frozenset({'curd', 'frozen meals'}),
#  frozenset({'frozen meals', 'white bread'}),
#  frozenset({'chocolate', 'frozen meals'}),
#  frozenset({'bottled water', 'frozen meals'}),
#  frozenset({'bottled beer', 'frozen meals'}),
#  frozenset({'UHT-milk', 'frozen meals'}),
#  frozenset({'frozen meals', 'rolls/buns'}),
#  frozenset({'butter', 'frozen meals'}),
#  frozenset({'frozen meals', 'other vegetables'}),
#  frozenset({'frozen meals', 'long life bakery product'}),
#  frozenset({'frozen meals', 'pip fruit'}),
#  frozenset({'cream cheese', 'frozen meals'}),
#  frozenset({'frozen meals', 'whole milk'}),
#  frozenset({'frozen meals', 'yogurt'}),
#  frozenset({'frozen meals', 'tropical fruit'}),
#  frozenset({'coffee', 'frozen meals'}),
#  frozenset({'frozen meals', 'margarine'}),
#  frozenset({'citrus fruit', 'frozen meals'}),
#  frozenset({'frozen vegetables', 'specialty chocolate'}),
#  frozenset({'ice cream', 'specialty chocolate'}),
#  frozenset({'oil', 'specialty chocolate'}),
#  frozenset({'chewing gum', 'specialty chocolate'}),
#  frozenset({'ham', 'specialty chocolate'}),
#  frozenset({'cat food', 'specialty chocolate'}),
#  frozenset({'hard cheese', 'specialty chocolate'}),
#  frozenset({'misc. beverages', 'specialty chocolate'}),
#  frozenset({'domestic eggs', 'specialty chocolate'}),
#  frozenset({'dessert', 'specialty chocolate'}),
#  frozenset({'grapes', 'specialty chocolate'}),
#  frozenset({'specialty chocolate', 'whipped/sour cream'}),
#  frozenset({'pork', 'specialty chocolate'}),
#  frozenset({'berries', 'specialty chocolate'}),
#  frozenset({'napkins', 'specialty chocolate'}),
#  frozenset({'hygiene articles', 'specialty chocolate'}),
#  frozenset({'hamburger meat', 'specialty chocolate'}),
#  frozenset({'beverages', 'specialty chocolate'}),
#  frozenset({'shopping bags', 'specialty chocolate'}),
#  frozenset({'brown bread', 'specialty chocolate'}),
#  frozenset({'sausage', 'specialty chocolate'}),
#  frozenset({'canned beer', 'specialty chocolate'}),
#  frozenset({'specialty chocolate', 'waffles'}),
#  frozenset({'salty snack', 'specialty chocolate'}),
#  frozenset({'root vegetables', 'specialty chocolate'}),
#  frozenset({'candy', 'specialty chocolate'}),
#  frozenset({'pastry', 'specialty chocolate'}),
#  frozenset({'butter milk', 'specialty chocolate'}),
#  frozenset({'specialty bar', 'specialty chocolate'}),
#  frozenset({'specialty chocolate', 'sugar'}),
#  frozenset({'newspapers', 'specialty chocolate'}),
#  frozenset({'fruit/vegetable juice', 'specialty chocolate'}),
#  frozenset({'chicken', 'specialty chocolate'}),
#  frozenset({'soda', 'specialty chocolate'}),
#  frozenset({'frankfurter', 'specialty chocolate'}),
#  frozenset({'beef', 'specialty chocolate'}),
#  frozenset({'curd', 'specialty chocolate'}),
#  frozenset({'specialty chocolate', 'white bread'}),
#  frozenset({'chocolate', 'specialty chocolate'}),
#  frozenset({'bottled water', 'specialty chocolate'}),
#  frozenset({'bottled beer', 'specialty chocolate'}),
#  frozenset({'UHT-milk', 'specialty chocolate'}),
#  frozenset({'rolls/buns', 'specialty chocolate'}),
#  frozenset({'butter', 'specialty chocolate'}),
#  frozenset({'other vegetables', 'specialty chocolate'}),
#  frozenset({'long life bakery product', 'specialty chocolate'}),
#  frozenset({'pip fruit', 'specialty chocolate'}),
#  frozenset({'cream cheese', 'specialty chocolate'}),
#  frozenset({'specialty chocolate', 'whole milk'}),
#  frozenset({'specialty chocolate', 'yogurt'}),
#  frozenset({'specialty chocolate', 'tropical fruit'}),
#  frozenset({'coffee', 'specialty chocolate'}),
#  frozenset({'margarine', 'specialty chocolate'}),
#  frozenset({'citrus fruit', 'specialty chocolate'}),
#  frozenset({'frozen vegetables', 'ice cream'}),
#  frozenset({'frozen vegetables', 'oil'}),
#  frozenset({'chewing gum', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'ham'}),
#  frozenset({'cat food', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'hard cheese'}),
#  frozenset({'frozen vegetables', 'misc. beverages'}),
#  frozenset({'domestic eggs', 'frozen vegetables'}),
#  frozenset({'dessert', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'grapes'}),
#  frozenset({'frozen vegetables', 'whipped/sour cream'}),
#  frozenset({'frozen vegetables', 'pork'}),
#  frozenset({'berries', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'napkins'}),
#  frozenset({'frozen vegetables', 'hygiene articles'}),
#  frozenset({'frozen vegetables', 'hamburger meat'}),
#  frozenset({'beverages', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'shopping bags'}),
#  frozenset({'brown bread', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'sausage'}),
#  frozenset({'canned beer', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'waffles'}),
#  frozenset({'frozen vegetables', 'salty snack'}),
#  frozenset({'frozen vegetables', 'root vegetables'}),
#  frozenset({'candy', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'pastry'}),
#  frozenset({'butter milk', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'specialty bar'}),
#  frozenset({'frozen vegetables', 'sugar'}),
#  frozenset({'frozen vegetables', 'newspapers'}),
#  frozenset({'frozen vegetables', 'fruit/vegetable juice'}),
#  frozenset({'chicken', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'soda'}),
#  frozenset({'frankfurter', 'frozen vegetables'}),
#  frozenset({'beef', 'frozen vegetables'}),
#  frozenset({'curd', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'white bread'}),
#  frozenset({'chocolate', 'frozen vegetables'}),
#  frozenset({'bottled water', 'frozen vegetables'}),
#  frozenset({'bottled beer', 'frozen vegetables'}),
#  frozenset({'UHT-milk', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'rolls/buns'}),
#  frozenset({'butter', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'other vegetables'}),
#  frozenset({'frozen vegetables', 'long life bakery product'}),
#  frozenset({'frozen vegetables', 'pip fruit'}),
#  frozenset({'cream cheese', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'whole milk'}),
#  frozenset({'frozen vegetables', 'yogurt'}),
#  frozenset({'frozen vegetables', 'tropical fruit'}),
#  frozenset({'coffee', 'frozen vegetables'}),
#  frozenset({'frozen vegetables', 'margarine'}),
#  frozenset({'citrus fruit', 'frozen vegetables'}),
#  frozenset({'ice cream', 'oil'}),
#  frozenset({'chewing gum', 'ice cream'}),
#  frozenset({'ham', 'ice cream'}),
#  frozenset({'cat food', 'ice cream'}),
#  frozenset({'hard cheese', 'ice cream'}),
#  frozenset({'ice cream', 'misc. beverages'}),
#  frozenset({'domestic eggs', 'ice cream'}),
#  frozenset({'dessert', 'ice cream'}),
#  frozenset({'grapes', 'ice cream'}),
#  frozenset({'ice cream', 'whipped/sour cream'}),
#  frozenset({'ice cream', 'pork'}),
#  frozenset({'berries', 'ice cream'}),
#  frozenset({'ice cream', 'napkins'}),
#  frozenset({'hygiene articles', 'ice cream'}),
#  frozenset({'hamburger meat', 'ice cream'}),
#  frozenset({'beverages', 'ice cream'}),
#  frozenset({'ice cream', 'shopping bags'}),
#  frozenset({'brown bread', 'ice cream'}),
#  frozenset({'ice cream', 'sausage'}),
#  frozenset({'canned beer', 'ice cream'}),
#  frozenset({'ice cream', 'waffles'}),
#  frozenset({'ice cream', 'salty snack'}),
#  frozenset({'ice cream', 'root vegetables'}),
#  frozenset({'candy', 'ice cream'}),
#  frozenset({'ice cream', 'pastry'}),
#  frozenset({'butter milk', 'ice cream'}),
#  frozenset({'ice cream', 'specialty bar'}),
#  frozenset({'ice cream', 'sugar'}),
#  frozenset({'ice cream', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'ice cream'}),
#  frozenset({'chicken', 'ice cream'}),
#  frozenset({'ice cream', 'soda'}),
#  frozenset({'frankfurter', 'ice cream'}),
#  frozenset({'beef', 'ice cream'}),
#  frozenset({'curd', 'ice cream'}),
#  frozenset({'ice cream', 'white bread'}),
#  frozenset({'chocolate', 'ice cream'}),
#  frozenset({'bottled water', 'ice cream'}),
#  frozenset({'bottled beer', 'ice cream'}),
#  frozenset({'UHT-milk', 'ice cream'}),
#  frozenset({'ice cream', 'rolls/buns'}),
#  frozenset({'butter', 'ice cream'}),
#  frozenset({'ice cream', 'other vegetables'}),
#  frozenset({'ice cream', 'long life bakery product'}),
#  frozenset({'ice cream', 'pip fruit'}),
#  frozenset({'cream cheese', 'ice cream'}),
#  frozenset({'ice cream', 'whole milk'}),
#  frozenset({'ice cream', 'yogurt'}),
#  frozenset({'ice cream', 'tropical fruit'}),
#  frozenset({'coffee', 'ice cream'}),
#  frozenset({'ice cream', 'margarine'}),
#  frozenset({'citrus fruit', 'ice cream'}),
#  frozenset({'chewing gum', 'oil'}),
#  frozenset({'ham', 'oil'}),
#  frozenset({'cat food', 'oil'}),
#  frozenset({'hard cheese', 'oil'}),
#  frozenset({'misc. beverages', 'oil'}),
#  frozenset({'domestic eggs', 'oil'}),
#  frozenset({'dessert', 'oil'}),
#  frozenset({'grapes', 'oil'}),
#  frozenset({'oil', 'whipped/sour cream'}),
#  frozenset({'oil', 'pork'}),
#  frozenset({'berries', 'oil'}),
#  frozenset({'napkins', 'oil'}),
#  frozenset({'hygiene articles', 'oil'}),
#  frozenset({'hamburger meat', 'oil'}),
#  frozenset({'beverages', 'oil'}),
#  frozenset({'oil', 'shopping bags'}),
#  frozenset({'brown bread', 'oil'}),
#  frozenset({'oil', 'sausage'}),
#  frozenset({'canned beer', 'oil'}),
#  frozenset({'oil', 'waffles'}),
#  frozenset({'oil', 'salty snack'}),
#  frozenset({'oil', 'root vegetables'}),
#  frozenset({'candy', 'oil'}),
#  frozenset({'oil', 'pastry'}),
#  frozenset({'butter milk', 'oil'}),
#  frozenset({'oil', 'specialty bar'}),
#  frozenset({'oil', 'sugar'}),
#  frozenset({'newspapers', 'oil'}),
#  frozenset({'fruit/vegetable juice', 'oil'}),
#  frozenset({'chicken', 'oil'}),
#  frozenset({'oil', 'soda'}),
#  frozenset({'frankfurter', 'oil'}),
#  frozenset({'beef', 'oil'}),
#  frozenset({'curd', 'oil'}),
#  frozenset({'oil', 'white bread'}),
#  frozenset({'chocolate', 'oil'}),
#  frozenset({'bottled water', 'oil'}),
#  frozenset({'bottled beer', 'oil'}),
#  frozenset({'UHT-milk', 'oil'}),
#  frozenset({'oil', 'rolls/buns'}),
#  frozenset({'butter', 'oil'}),
#  frozenset({'oil', 'other vegetables'}),
#  frozenset({'long life bakery product', 'oil'}),
#  frozenset({'oil', 'pip fruit'}),
#  frozenset({'cream cheese', 'oil'}),
#  frozenset({'oil', 'whole milk'}),
#  frozenset({'oil', 'yogurt'}),
#  frozenset({'oil', 'tropical fruit'}),
#  frozenset({'coffee', 'oil'}),
#  frozenset({'margarine', 'oil'}),
#  frozenset({'citrus fruit', 'oil'}),
#  frozenset({'chewing gum', 'ham'}),
#  frozenset({'cat food', 'chewing gum'}),
#  frozenset({'chewing gum', 'hard cheese'}),
#  frozenset({'chewing gum', 'misc. beverages'}),
#  frozenset({'chewing gum', 'domestic eggs'}),
#  frozenset({'chewing gum', 'dessert'}),
#  frozenset({'chewing gum', 'grapes'}),
#  frozenset({'chewing gum', 'whipped/sour cream'}),
#  frozenset({'chewing gum', 'pork'}),
#  frozenset({'berries', 'chewing gum'}),
#  frozenset({'chewing gum', 'napkins'}),
#  frozenset({'chewing gum', 'hygiene articles'}),
#  frozenset({'chewing gum', 'hamburger meat'}),
#  frozenset({'beverages', 'chewing gum'}),
#  frozenset({'chewing gum', 'shopping bags'}),
#  frozenset({'brown bread', 'chewing gum'}),
#  frozenset({'chewing gum', 'sausage'}),
#  frozenset({'canned beer', 'chewing gum'}),
#  frozenset({'chewing gum', 'waffles'}),
#  frozenset({'chewing gum', 'salty snack'}),
#  frozenset({'chewing gum', 'root vegetables'}),
#  frozenset({'candy', 'chewing gum'}),
#  frozenset({'chewing gum', 'pastry'}),
#  frozenset({'butter milk', 'chewing gum'}),
#  frozenset({'chewing gum', 'specialty bar'}),
#  frozenset({'chewing gum', 'sugar'}),
#  frozenset({'chewing gum', 'newspapers'}),
#  frozenset({'chewing gum', 'fruit/vegetable juice'}),
#  frozenset({'chewing gum', 'chicken'}),
#  frozenset({'chewing gum', 'soda'}),
#  frozenset({'chewing gum', 'frankfurter'}),
#  frozenset({'beef', 'chewing gum'}),
#  frozenset({'chewing gum', 'curd'}),
#  frozenset({'chewing gum', 'white bread'}),
#  frozenset({'chewing gum', 'chocolate'}),
#  frozenset({'bottled water', 'chewing gum'}),
#  frozenset({'bottled beer', 'chewing gum'}),
#  frozenset({'UHT-milk', 'chewing gum'}),
#  frozenset({'chewing gum', 'rolls/buns'}),
#  frozenset({'butter', 'chewing gum'}),
#  frozenset({'chewing gum', 'other vegetables'}),
#  frozenset({'chewing gum', 'long life bakery product'}),
#  frozenset({'chewing gum', 'pip fruit'}),
#  frozenset({'chewing gum', 'cream cheese'}),
#  frozenset({'chewing gum', 'whole milk'}),
#  frozenset({'chewing gum', 'yogurt'}),
#  frozenset({'chewing gum', 'tropical fruit'}),
#  frozenset({'chewing gum', 'coffee'}),
#  frozenset({'chewing gum', 'margarine'}),
#  frozenset({'chewing gum', 'citrus fruit'}),
#  frozenset({'cat food', 'ham'}),
#  frozenset({'ham', 'hard cheese'}),
#  frozenset({'ham', 'misc. beverages'}),
#  frozenset({'domestic eggs', 'ham'}),
#  frozenset({'dessert', 'ham'}),
#  frozenset({'grapes', 'ham'}),
#  frozenset({'ham', 'whipped/sour cream'}),
#  frozenset({'ham', 'pork'}),
#  frozenset({'berries', 'ham'}),
#  frozenset({'ham', 'napkins'}),
#  frozenset({'ham', 'hygiene articles'}),
#  frozenset({'ham', 'hamburger meat'}),
#  frozenset({'beverages', 'ham'}),
#  frozenset({'ham', 'shopping bags'}),
#  frozenset({'brown bread', 'ham'}),
#  frozenset({'ham', 'sausage'}),
#  frozenset({'canned beer', 'ham'}),
#  frozenset({'ham', 'waffles'}),
#  frozenset({'ham', 'salty snack'}),
#  frozenset({'ham', 'root vegetables'}),
#  frozenset({'candy', 'ham'}),
#  frozenset({'ham', 'pastry'}),
#  frozenset({'butter milk', 'ham'}),
#  frozenset({'ham', 'specialty bar'}),
#  frozenset({'ham', 'sugar'}),
#  frozenset({'ham', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'ham'}),
#  frozenset({'chicken', 'ham'}),
#  frozenset({'ham', 'soda'}),
#  frozenset({'frankfurter', 'ham'}),
#  frozenset({'beef', 'ham'}),
#  frozenset({'curd', 'ham'}),
#  frozenset({'ham', 'white bread'}),
#  frozenset({'chocolate', 'ham'}),
#  frozenset({'bottled water', 'ham'}),
#  frozenset({'bottled beer', 'ham'}),
#  frozenset({'UHT-milk', 'ham'}),
#  frozenset({'ham', 'rolls/buns'}),
#  frozenset({'butter', 'ham'}),
#  frozenset({'ham', 'other vegetables'}),
#  frozenset({'ham', 'long life bakery product'}),
#  frozenset({'ham', 'pip fruit'}),
#  frozenset({'cream cheese', 'ham'}),
#  frozenset({'ham', 'whole milk'}),
#  frozenset({'ham', 'yogurt'}),
#  frozenset({'ham', 'tropical fruit'}),
#  frozenset({'coffee', 'ham'}),
#  frozenset({'ham', 'margarine'}),
#  frozenset({'citrus fruit', 'ham'}),
#  frozenset({'cat food', 'hard cheese'}),
#  frozenset({'cat food', 'misc. beverages'}),
#  frozenset({'cat food', 'domestic eggs'}),
#  frozenset({'cat food', 'dessert'}),
#  frozenset({'cat food', 'grapes'}),
#  frozenset({'cat food', 'whipped/sour cream'}),
#  frozenset({'cat food', 'pork'}),
#  frozenset({'berries', 'cat food'}),
#  frozenset({'cat food', 'napkins'}),
#  frozenset({'cat food', 'hygiene articles'}),
#  frozenset({'cat food', 'hamburger meat'}),
#  frozenset({'beverages', 'cat food'}),
#  frozenset({'cat food', 'shopping bags'}),
#  frozenset({'brown bread', 'cat food'}),
#  frozenset({'cat food', 'sausage'}),
#  frozenset({'canned beer', 'cat food'}),
#  frozenset({'cat food', 'waffles'}),
#  frozenset({'cat food', 'salty snack'}),
#  frozenset({'cat food', 'root vegetables'}),
#  frozenset({'candy', 'cat food'}),
#  frozenset({'cat food', 'pastry'}),
#  frozenset({'butter milk', 'cat food'}),
#  frozenset({'cat food', 'specialty bar'}),
#  frozenset({'cat food', 'sugar'}),
#  frozenset({'cat food', 'newspapers'}),
#  frozenset({'cat food', 'fruit/vegetable juice'}),
#  frozenset({'cat food', 'chicken'}),
#  frozenset({'cat food', 'soda'}),
#  frozenset({'cat food', 'frankfurter'}),
#  frozenset({'beef', 'cat food'}),
#  frozenset({'cat food', 'curd'}),
#  frozenset({'cat food', 'white bread'}),
#  frozenset({'cat food', 'chocolate'}),
#  frozenset({'bottled water', 'cat food'}),
#  frozenset({'bottled beer', 'cat food'}),
#  frozenset({'UHT-milk', 'cat food'}),
#  frozenset({'cat food', 'rolls/buns'}),
#  frozenset({'butter', 'cat food'}),
#  frozenset({'cat food', 'other vegetables'}),
#  frozenset({'cat food', 'long life bakery product'}),
#  frozenset({'cat food', 'pip fruit'}),
#  frozenset({'cat food', 'cream cheese'}),
#  frozenset({'cat food', 'whole milk'}),
#  frozenset({'cat food', 'yogurt'}),
#  frozenset({'cat food', 'tropical fruit'}),
#  frozenset({'cat food', 'coffee'}),
#  frozenset({'cat food', 'margarine'}),
#  frozenset({'cat food', 'citrus fruit'}),
#  frozenset({'hard cheese', 'misc. beverages'}),
#  frozenset({'domestic eggs', 'hard cheese'}),
#  frozenset({'dessert', 'hard cheese'}),
#  frozenset({'grapes', 'hard cheese'}),
#  frozenset({'hard cheese', 'whipped/sour cream'}),
#  frozenset({'hard cheese', 'pork'}),
#  frozenset({'berries', 'hard cheese'}),
#  frozenset({'hard cheese', 'napkins'}),
#  frozenset({'hard cheese', 'hygiene articles'}),
#  frozenset({'hamburger meat', 'hard cheese'}),
#  frozenset({'beverages', 'hard cheese'}),
#  frozenset({'hard cheese', 'shopping bags'}),
#  frozenset({'brown bread', 'hard cheese'}),
#  frozenset({'hard cheese', 'sausage'}),
#  frozenset({'canned beer', 'hard cheese'}),
#  frozenset({'hard cheese', 'waffles'}),
#  frozenset({'hard cheese', 'salty snack'}),
#  frozenset({'hard cheese', 'root vegetables'}),
#  frozenset({'candy', 'hard cheese'}),
#  frozenset({'hard cheese', 'pastry'}),
#  frozenset({'butter milk', 'hard cheese'}),
#  frozenset({'hard cheese', 'specialty bar'}),
#  frozenset({'hard cheese', 'sugar'}),
#  frozenset({'hard cheese', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'hard cheese'}),
#  frozenset({'chicken', 'hard cheese'}),
#  frozenset({'hard cheese', 'soda'}),
#  frozenset({'frankfurter', 'hard cheese'}),
#  frozenset({'beef', 'hard cheese'}),
#  frozenset({'curd', 'hard cheese'}),
#  frozenset({'hard cheese', 'white bread'}),
#  frozenset({'chocolate', 'hard cheese'}),
#  frozenset({'bottled water', 'hard cheese'}),
#  frozenset({'bottled beer', 'hard cheese'}),
#  frozenset({'UHT-milk', 'hard cheese'}),
#  frozenset({'hard cheese', 'rolls/buns'}),
#  frozenset({'butter', 'hard cheese'}),
#  frozenset({'hard cheese', 'other vegetables'}),
#  frozenset({'hard cheese', 'long life bakery product'}),
#  frozenset({'hard cheese', 'pip fruit'}),
#  frozenset({'cream cheese', 'hard cheese'}),
#  frozenset({'hard cheese', 'whole milk'}),
#  frozenset({'hard cheese', 'yogurt'}),
#  frozenset({'hard cheese', 'tropical fruit'}),
#  frozenset({'coffee', 'hard cheese'}),
#  frozenset({'hard cheese', 'margarine'}),
#  frozenset({'citrus fruit', 'hard cheese'}),
#  frozenset({'domestic eggs', 'misc. beverages'}),
#  frozenset({'dessert', 'misc. beverages'}),
#  frozenset({'grapes', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'whipped/sour cream'}),
#  frozenset({'misc. beverages', 'pork'}),
#  frozenset({'berries', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'napkins'}),
#  frozenset({'hygiene articles', 'misc. beverages'}),
#  frozenset({'hamburger meat', 'misc. beverages'}),
#  frozenset({'beverages', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'shopping bags'}),
#  frozenset({'brown bread', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'sausage'}),
#  frozenset({'canned beer', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'waffles'}),
#  frozenset({'misc. beverages', 'salty snack'}),
#  frozenset({'misc. beverages', 'root vegetables'}),
#  frozenset({'candy', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'pastry'}),
#  frozenset({'butter milk', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'specialty bar'}),
#  frozenset({'misc. beverages', 'sugar'}),
#  frozenset({'misc. beverages', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'misc. beverages'}),
#  frozenset({'chicken', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'soda'}),
#  frozenset({'frankfurter', 'misc. beverages'}),
#  frozenset({'beef', 'misc. beverages'}),
#  frozenset({'curd', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'white bread'}),
#  frozenset({'chocolate', 'misc. beverages'}),
#  frozenset({'bottled water', 'misc. beverages'}),
#  frozenset({'bottled beer', 'misc. beverages'}),
#  frozenset({'UHT-milk', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'rolls/buns'}),
#  frozenset({'butter', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'other vegetables'}),
#  frozenset({'long life bakery product', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'pip fruit'}),
#  frozenset({'cream cheese', 'misc. beverages'}),
#  frozenset({'misc. beverages', 'whole milk'}),
#  frozenset({'misc. beverages', 'yogurt'}),
#  frozenset({'misc. beverages', 'tropical fruit'}),
#  frozenset({'coffee', 'misc. beverages'}),
#  frozenset({'margarine', 'misc. beverages'}),
#  frozenset({'citrus fruit', 'misc. beverages'}),
#  frozenset({'dessert', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'grapes'}),
#  frozenset({'domestic eggs', 'whipped/sour cream'}),
#  frozenset({'domestic eggs', 'pork'}),
#  frozenset({'berries', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'napkins'}),
#  frozenset({'domestic eggs', 'hygiene articles'}),
#  frozenset({'domestic eggs', 'hamburger meat'}),
#  frozenset({'beverages', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'shopping bags'}),
#  frozenset({'brown bread', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'sausage'}),
#  frozenset({'canned beer', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'waffles'}),
#  frozenset({'domestic eggs', 'salty snack'}),
#  frozenset({'domestic eggs', 'root vegetables'}),
#  frozenset({'candy', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'pastry'}),
#  frozenset({'butter milk', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'specialty bar'}),
#  frozenset({'domestic eggs', 'sugar'}),
#  frozenset({'domestic eggs', 'newspapers'}),
#  frozenset({'domestic eggs', 'fruit/vegetable juice'}),
#  frozenset({'chicken', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'soda'}),
#  frozenset({'domestic eggs', 'frankfurter'}),
#  frozenset({'beef', 'domestic eggs'}),
#  frozenset({'curd', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'white bread'}),
#  frozenset({'chocolate', 'domestic eggs'}),
#  frozenset({'bottled water', 'domestic eggs'}),
#  frozenset({'bottled beer', 'domestic eggs'}),
#  frozenset({'UHT-milk', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'rolls/buns'}),
#  frozenset({'butter', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'other vegetables'}),
#  frozenset({'domestic eggs', 'long life bakery product'}),
#  frozenset({'domestic eggs', 'pip fruit'}),
#  frozenset({'cream cheese', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'whole milk'}),
#  frozenset({'domestic eggs', 'yogurt'}),
#  frozenset({'domestic eggs', 'tropical fruit'}),
#  frozenset({'coffee', 'domestic eggs'}),
#  frozenset({'domestic eggs', 'margarine'}),
#  frozenset({'citrus fruit', 'domestic eggs'}),
#  frozenset({'dessert', 'grapes'}),
#  frozenset({'dessert', 'whipped/sour cream'}),
#  frozenset({'dessert', 'pork'}),
#  frozenset({'berries', 'dessert'}),
#  frozenset({'dessert', 'napkins'}),
#  frozenset({'dessert', 'hygiene articles'}),
#  frozenset({'dessert', 'hamburger meat'}),
#  frozenset({'beverages', 'dessert'}),
#  frozenset({'dessert', 'shopping bags'}),
#  frozenset({'brown bread', 'dessert'}),
#  frozenset({'dessert', 'sausage'}),
#  frozenset({'canned beer', 'dessert'}),
#  frozenset({'dessert', 'waffles'}),
#  frozenset({'dessert', 'salty snack'}),
#  frozenset({'dessert', 'root vegetables'}),
#  frozenset({'candy', 'dessert'}),
#  frozenset({'dessert', 'pastry'}),
#  frozenset({'butter milk', 'dessert'}),
#  frozenset({'dessert', 'specialty bar'}),
#  frozenset({'dessert', 'sugar'}),
#  frozenset({'dessert', 'newspapers'}),
#  frozenset({'dessert', 'fruit/vegetable juice'}),
#  frozenset({'chicken', 'dessert'}),
#  frozenset({'dessert', 'soda'}),
#  frozenset({'dessert', 'frankfurter'}),
#  frozenset({'beef', 'dessert'}),
#  frozenset({'curd', 'dessert'}),
#  frozenset({'dessert', 'white bread'}),
#  frozenset({'chocolate', 'dessert'}),
#  frozenset({'bottled water', 'dessert'}),
#  frozenset({'bottled beer', 'dessert'}),
#  frozenset({'UHT-milk', 'dessert'}),
#  frozenset({'dessert', 'rolls/buns'}),
#  frozenset({'butter', 'dessert'}),
#  frozenset({'dessert', 'other vegetables'}),
#  frozenset({'dessert', 'long life bakery product'}),
#  frozenset({'dessert', 'pip fruit'}),
#  frozenset({'cream cheese', 'dessert'}),
#  frozenset({'dessert', 'whole milk'}),
#  frozenset({'dessert', 'yogurt'}),
#  frozenset({'dessert', 'tropical fruit'}),
#  frozenset({'coffee', 'dessert'}),
#  frozenset({'dessert', 'margarine'}),
#  frozenset({'citrus fruit', 'dessert'}),
#  frozenset({'grapes', 'whipped/sour cream'}),
#  frozenset({'grapes', 'pork'}),
#  frozenset({'berries', 'grapes'}),
#  frozenset({'grapes', 'napkins'}),
#  frozenset({'grapes', 'hygiene articles'}),
#  frozenset({'grapes', 'hamburger meat'}),
#  frozenset({'beverages', 'grapes'}),
#  frozenset({'grapes', 'shopping bags'}),
#  frozenset({'brown bread', 'grapes'}),
#  frozenset({'grapes', 'sausage'}),
#  frozenset({'canned beer', 'grapes'}),
#  frozenset({'grapes', 'waffles'}),
#  frozenset({'grapes', 'salty snack'}),
#  frozenset({'grapes', 'root vegetables'}),
#  frozenset({'candy', 'grapes'}),
#  frozenset({'grapes', 'pastry'}),
#  frozenset({'butter milk', 'grapes'}),
#  frozenset({'grapes', 'specialty bar'}),
#  frozenset({'grapes', 'sugar'}),
#  frozenset({'grapes', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'grapes'}),
#  frozenset({'chicken', 'grapes'}),
#  frozenset({'grapes', 'soda'}),
#  frozenset({'frankfurter', 'grapes'}),
#  frozenset({'beef', 'grapes'}),
#  frozenset({'curd', 'grapes'}),
#  frozenset({'grapes', 'white bread'}),
#  frozenset({'chocolate', 'grapes'}),
#  frozenset({'bottled water', 'grapes'}),
#  frozenset({'bottled beer', 'grapes'}),
#  frozenset({'UHT-milk', 'grapes'}),
#  frozenset({'grapes', 'rolls/buns'}),
#  frozenset({'butter', 'grapes'}),
#  frozenset({'grapes', 'other vegetables'}),
#  frozenset({'grapes', 'long life bakery product'}),
#  frozenset({'grapes', 'pip fruit'}),
#  frozenset({'cream cheese', 'grapes'}),
#  frozenset({'grapes', 'whole milk'}),
#  frozenset({'grapes', 'yogurt'}),
#  frozenset({'grapes', 'tropical fruit'}),
#  frozenset({'coffee', 'grapes'}),
#  frozenset({'grapes', 'margarine'}),
#  frozenset({'citrus fruit', 'grapes'}),
#  frozenset({'pork', 'whipped/sour cream'}),
#  frozenset({'berries', 'whipped/sour cream'}),
#  frozenset({'napkins', 'whipped/sour cream'}),
#  frozenset({'hygiene articles', 'whipped/sour cream'}),
#  frozenset({'hamburger meat', 'whipped/sour cream'}),
#  frozenset({'beverages', 'whipped/sour cream'}),
#  frozenset({'shopping bags', 'whipped/sour cream'}),
#  frozenset({'brown bread', 'whipped/sour cream'}),
#  frozenset({'sausage', 'whipped/sour cream'}),
#  frozenset({'canned beer', 'whipped/sour cream'}),
#  frozenset({'waffles', 'whipped/sour cream'}),
#  frozenset({'salty snack', 'whipped/sour cream'}),
#  frozenset({'root vegetables', 'whipped/sour cream'}),
#  frozenset({'candy', 'whipped/sour cream'}),
#  frozenset({'pastry', 'whipped/sour cream'}),
#  frozenset({'butter milk', 'whipped/sour cream'}),
#  frozenset({'specialty bar', 'whipped/sour cream'}),
#  frozenset({'sugar', 'whipped/sour cream'}),
#  frozenset({'newspapers', 'whipped/sour cream'}),
#  frozenset({'fruit/vegetable juice', 'whipped/sour cream'}),
#  frozenset({'chicken', 'whipped/sour cream'}),
#  frozenset({'soda', 'whipped/sour cream'}),
#  frozenset({'frankfurter', 'whipped/sour cream'}),
#  frozenset({'beef', 'whipped/sour cream'}),
#  frozenset({'curd', 'whipped/sour cream'}),
#  frozenset({'whipped/sour cream', 'white bread'}),
#  frozenset({'chocolate', 'whipped/sour cream'}),
#  frozenset({'bottled water', 'whipped/sour cream'}),
#  frozenset({'bottled beer', 'whipped/sour cream'}),
#  frozenset({'UHT-milk', 'whipped/sour cream'}),
#  frozenset({'rolls/buns', 'whipped/sour cream'}),
#  frozenset({'butter', 'whipped/sour cream'}),
#  frozenset({'other vegetables', 'whipped/sour cream'}),
#  frozenset({'long life bakery product', 'whipped/sour cream'}),
#  frozenset({'pip fruit', 'whipped/sour cream'}),
#  frozenset({'cream cheese', 'whipped/sour cream'}),
#  frozenset({'whipped/sour cream', 'whole milk'}),
#  frozenset({'whipped/sour cream', 'yogurt'}),
#  frozenset({'tropical fruit', 'whipped/sour cream'}),
#  frozenset({'coffee', 'whipped/sour cream'}),
#  frozenset({'margarine', 'whipped/sour cream'}),
#  frozenset({'citrus fruit', 'whipped/sour cream'}),
#  frozenset({'berries', 'pork'}),
#  frozenset({'napkins', 'pork'}),
#  frozenset({'hygiene articles', 'pork'}),
#  frozenset({'hamburger meat', 'pork'}),
#  frozenset({'beverages', 'pork'}),
#  frozenset({'pork', 'shopping bags'}),
#  frozenset({'brown bread', 'pork'}),
#  frozenset({'pork', 'sausage'}),
#  frozenset({'canned beer', 'pork'}),
#  frozenset({'pork', 'waffles'}),
#  frozenset({'pork', 'salty snack'}),
#  frozenset({'pork', 'root vegetables'}),
#  frozenset({'candy', 'pork'}),
#  frozenset({'pastry', 'pork'}),
#  frozenset({'butter milk', 'pork'}),
#  frozenset({'pork', 'specialty bar'}),
#  frozenset({'pork', 'sugar'}),
#  frozenset({'newspapers', 'pork'}),
#  frozenset({'fruit/vegetable juice', 'pork'}),
#  frozenset({'chicken', 'pork'}),
#  frozenset({'pork', 'soda'}),
#  frozenset({'frankfurter', 'pork'}),
#  frozenset({'beef', 'pork'}),
#  frozenset({'curd', 'pork'}),
#  frozenset({'pork', 'white bread'}),
#  frozenset({'chocolate', 'pork'}),
#  frozenset({'bottled water', 'pork'}),
#  frozenset({'bottled beer', 'pork'}),
#  frozenset({'UHT-milk', 'pork'}),
#  frozenset({'pork', 'rolls/buns'}),
#  frozenset({'butter', 'pork'}),
#  frozenset({'other vegetables', 'pork'}),
#  frozenset({'long life bakery product', 'pork'}),
#  frozenset({'pip fruit', 'pork'}),
#  frozenset({'cream cheese', 'pork'}),
#  frozenset({'pork', 'whole milk'}),
#  frozenset({'pork', 'yogurt'}),
#  frozenset({'pork', 'tropical fruit'}),
#  frozenset({'coffee', 'pork'}),
#  frozenset({'margarine', 'pork'}),
#  frozenset({'citrus fruit', 'pork'}),
#  frozenset({'berries', 'napkins'}),
#  frozenset({'berries', 'hygiene articles'}),
#  frozenset({'berries', 'hamburger meat'}),
#  frozenset({'berries', 'beverages'}),
#  frozenset({'berries', 'shopping bags'}),
#  frozenset({'berries', 'brown bread'}),
#  frozenset({'berries', 'sausage'}),
#  frozenset({'berries', 'canned beer'}),
#  frozenset({'berries', 'waffles'}),
#  frozenset({'berries', 'salty snack'}),
#  frozenset({'berries', 'root vegetables'}),
#  frozenset({'berries', 'candy'}),
#  frozenset({'berries', 'pastry'}),
#  frozenset({'berries', 'butter milk'}),
#  frozenset({'berries', 'specialty bar'}),
#  frozenset({'berries', 'sugar'}),
#  frozenset({'berries', 'newspapers'}),
#  frozenset({'berries', 'fruit/vegetable juice'}),
#  frozenset({'berries', 'chicken'}),
#  frozenset({'berries', 'soda'}),
#  frozenset({'berries', 'frankfurter'}),
#  frozenset({'beef', 'berries'}),
#  frozenset({'berries', 'curd'}),
#  frozenset({'berries', 'white bread'}),
#  frozenset({'berries', 'chocolate'}),
#  frozenset({'berries', 'bottled water'}),
#  frozenset({'berries', 'bottled beer'}),
#  frozenset({'UHT-milk', 'berries'}),
#  frozenset({'berries', 'rolls/buns'}),
#  frozenset({'berries', 'butter'}),
#  frozenset({'berries', 'other vegetables'}),
#  frozenset({'berries', 'long life bakery product'}),
#  frozenset({'berries', 'pip fruit'}),
#  frozenset({'berries', 'cream cheese'}),
#  frozenset({'berries', 'whole milk'}),
#  frozenset({'berries', 'yogurt'}),
#  frozenset({'berries', 'tropical fruit'}),
#  frozenset({'berries', 'coffee'}),
#  frozenset({'berries', 'margarine'}),
#  frozenset({'berries', 'citrus fruit'}),
#  frozenset({'hygiene articles', 'napkins'}),
#  frozenset({'hamburger meat', 'napkins'}),
#  frozenset({'beverages', 'napkins'}),
#  frozenset({'napkins', 'shopping bags'}),
#  frozenset({'brown bread', 'napkins'}),
#  frozenset({'napkins', 'sausage'}),
#  frozenset({'canned beer', 'napkins'}),
#  frozenset({'napkins', 'waffles'}),
#  frozenset({'napkins', 'salty snack'}),
#  frozenset({'napkins', 'root vegetables'}),
#  frozenset({'candy', 'napkins'}),
#  frozenset({'napkins', 'pastry'}),
#  frozenset({'butter milk', 'napkins'}),
#  frozenset({'napkins', 'specialty bar'}),
#  frozenset({'napkins', 'sugar'}),
#  frozenset({'napkins', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'napkins'}),
#  frozenset({'chicken', 'napkins'}),
#  frozenset({'napkins', 'soda'}),
#  frozenset({'frankfurter', 'napkins'}),
#  frozenset({'beef', 'napkins'}),
#  frozenset({'curd', 'napkins'}),
#  frozenset({'napkins', 'white bread'}),
#  frozenset({'chocolate', 'napkins'}),
#  frozenset({'bottled water', 'napkins'}),
#  frozenset({'bottled beer', 'napkins'}),
#  frozenset({'UHT-milk', 'napkins'}),
#  frozenset({'napkins', 'rolls/buns'}),
#  frozenset({'butter', 'napkins'}),
#  frozenset({'napkins', 'other vegetables'}),
#  frozenset({'long life bakery product', 'napkins'}),
#  frozenset({'napkins', 'pip fruit'}),
#  frozenset({'cream cheese', 'napkins'}),
#  frozenset({'napkins', 'whole milk'}),
#  frozenset({'napkins', 'yogurt'}),
#  frozenset({'napkins', 'tropical fruit'}),
#  frozenset({'coffee', 'napkins'}),
#  frozenset({'margarine', 'napkins'}),
#  frozenset({'citrus fruit', 'napkins'}),
#  frozenset({'hamburger meat', 'hygiene articles'}),
#  frozenset({'beverages', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'shopping bags'}),
#  frozenset({'brown bread', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'sausage'}),
#  frozenset({'canned beer', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'waffles'}),
#  frozenset({'hygiene articles', 'salty snack'}),
#  frozenset({'hygiene articles', 'root vegetables'}),
#  frozenset({'candy', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'pastry'}),
#  frozenset({'butter milk', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'specialty bar'}),
#  frozenset({'hygiene articles', 'sugar'}),
#  frozenset({'hygiene articles', 'newspapers'}),
#  frozenset({'fruit/vegetable juice', 'hygiene articles'}),
#  frozenset({'chicken', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'soda'}),
#  frozenset({'frankfurter', 'hygiene articles'}),
#  frozenset({'beef', 'hygiene articles'}),
#  frozenset({'curd', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'white bread'}),
#  frozenset({'chocolate', 'hygiene articles'}),
#  frozenset({'bottled water', 'hygiene articles'}),
#  frozenset({'bottled beer', 'hygiene articles'}),
#  frozenset({'UHT-milk', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'rolls/buns'}),
#  frozenset({'butter', 'hygiene articles'}),
#  frozenset({'hygiene articles', 'other vegetables'}),
#  frozenset({'hygiene articles', 'long life bakery product'}),
#  ...]

# %%
rules = ap.generateRules(L, suppData, minConf=0.1)
# Out:
# frozenset({'yogurt'}) --> frozenset({'whipped/sour cream'}) conf: 0.14868804664723032
# frozenset({'whipped/sour cream'}) --> frozenset({'yogurt'}) conf: 0.2893617021276596
# frozenset({'other vegetables'}) --> frozenset({'yogurt'}) conf: 0.22438255386232264
# frozenset({'yogurt'}) --> frozenset({'other vegetables'}) conf: 0.3112244897959184
# frozenset({'pip fruit'}) --> frozenset({'other vegetables'}) conf: 0.3454301075268817
# frozenset({'other vegetables'}) --> frozenset({'pip fruit'}) conf: 0.1350499211770888
# frozenset({'pastry'}) --> frozenset({'other vegetables'}) conf: 0.2537142857142857
# frozenset({'other vegetables'}) --> frozenset({'pastry'}) conf: 0.11665790856542302
# frozenset({'other vegetables'}) --> frozenset({'shopping bags'}) conf: 0.11981082501313715
# frozenset({'shopping bags'}) --> frozenset({'other vegetables'}) conf: 0.23529411764705885
# frozenset({'other vegetables'}) --> frozenset({'sausage'}) conf: 0.13925380977404098
# frozenset({'sausage'}) --> frozenset({'other vegetables'}) conf: 0.2867965367965368
# frozenset({'bottled beer'}) --> frozenset({'whole milk'}) conf: 0.2537878787878788
# frozenset({'shopping bags'}) --> frozenset({'whole milk'}) conf: 0.24871001031991746
# frozenset({'citrus fruit'}) --> frozenset({'other vegetables'}) conf: 0.34889434889434895
# frozenset({'other vegetables'}) --> frozenset({'citrus fruit'}) conf: 0.14923804519180242
# frozenset({'fruit/vegetable juice'}) --> frozenset({'whole milk'}) conf: 0.36849507735583686
# frozenset({'whole milk'}) --> frozenset({'fruit/vegetable juice'}) conf: 0.10425785913251093
# frozenset({'frankfurter'}) --> frozenset({'whole milk'}) conf: 0.3482758620689655
# frozenset({'newspapers'}) --> frozenset({'whole milk'}) conf: 0.34267515923566877
# frozenset({'whole milk'}) --> frozenset({'newspapers'}) conf: 0.10704337445284519
# frozenset({'margarine'}) --> frozenset({'whole milk'}) conf: 0.4131944444444444
# frozenset({'pip fruit'}) --> frozenset({'tropical fruit'}) conf: 0.2701612903225806
# frozenset({'tropical fruit'}) --> frozenset({'pip fruit'}) conf: 0.1947674418604651
# frozenset({'pip fruit'}) --> frozenset({'whole milk'}) conf: 0.3978494623655914
# frozenset({'whole milk'}) --> frozenset({'pip fruit'}) conf: 0.1177875049741345
# frozenset({'rolls/buns'}) --> frozenset({'whole milk'}) conf: 0.30790491984521834
# frozenset({'whole milk'}) --> frozenset({'rolls/buns'}) conf: 0.22164743334659767
# frozenset({'beef'}) --> frozenset({'whole milk'}) conf: 0.4050387596899225
# frozenset({'sausage'}) --> frozenset({'whole milk'}) conf: 0.3181818181818182
# frozenset({'whole milk'}) --> frozenset({'sausage'}) conf: 0.11699164345403898
# frozenset({'frozen vegetables'}) --> frozenset({'whole milk'}) conf: 0.4249471458773784
# frozenset({'pastry'}) --> frozenset({'rolls/buns'}) conf: 0.2354285714285714
# frozenset({'rolls/buns'}) --> frozenset({'pastry'}) conf: 0.11387506909894968
# frozenset({'fruit/vegetable juice'}) --> frozenset({'other vegetables'}) conf: 0.2911392405063291
# frozenset({'other vegetables'}) --> frozenset({'fruit/vegetable juice'}) conf: 0.10877561744613767
# frozenset({'domestic eggs'}) --> frozenset({'other vegetables'}) conf: 0.35096153846153844
# frozenset({'other vegetables'}) --> frozenset({'domestic eggs'}) conf: 0.11508145034156594
# frozenset({'other vegetables'}) --> frozenset({'butter'}) conf: 0.10352075669994745
# frozenset({'butter'}) --> frozenset({'other vegetables'}) conf: 0.3614678899082569
# frozenset({'rolls/buns'}) --> frozenset({'yogurt'}) conf: 0.18684355997788832
# frozenset({'yogurt'}) --> frozenset({'rolls/buns'}) conf: 0.2463556851311953
# frozenset({'soda'}) --> frozenset({'bottled water'}) conf: 0.1661807580174927
# frozenset({'bottled water'}) --> frozenset({'soda'}) conf: 0.2621895124195032
# frozenset({'tropical fruit'}) --> frozenset({'soda'}) conf: 0.1986434108527132
# frozenset({'soda'}) --> frozenset({'tropical fruit'}) conf: 0.11953352769679301
# frozenset({'soda'}) --> frozenset({'yogurt'}) conf: 0.15685131195335278
# frozenset({'yogurt'}) --> frozenset({'soda'}) conf: 0.19606413994169095
# frozenset({'pastry'}) --> frozenset({'whole milk'}) conf: 0.3737142857142857
# frozenset({'whole milk'}) --> frozenset({'pastry'}) conf: 0.1301233585356148
# frozenset({'root vegetables'}) --> frozenset({'yogurt'}) conf: 0.2369402985074627
# frozenset({'yogurt'}) --> frozenset({'root vegetables'}) conf: 0.18513119533527697
# frozenset({'brown bread'}) --> frozenset({'whole milk'}) conf: 0.3887147335423197
# frozenset({'domestic eggs'}) --> frozenset({'whole milk'}) conf: 0.47275641025641024
# frozenset({'whole milk'}) --> frozenset({'domestic eggs'}) conf: 0.11738957421408674
# frozenset({'pastry'}) --> frozenset({'soda'}) conf: 0.23657142857142854
# frozenset({'soda'}) --> frozenset({'pastry'}) conf: 0.1206997084548105
# frozenset({'soda'}) --> frozenset({'whole milk'}) conf: 0.22973760932944606
# frozenset({'whole milk'}) --> frozenset({'soda'}) conf: 0.15678471945881414
# frozenset({'other vegetables'}) --> frozenset({'soda'}) conf: 0.16920651602732528
# frozenset({'soda'}) --> frozenset({'other vegetables'}) conf: 0.18775510204081633
# frozenset({'pork'}) --> frozenset({'whole milk'}) conf: 0.3844797178130512
# frozenset({'other vegetables'}) --> frozenset({'pork'}) conf: 0.11192853389385181
# frozenset({'pork'}) --> frozenset({'other vegetables'}) conf: 0.37566137566137564
# frozenset({'whole milk'}) --> frozenset({'whipped/sour cream'}) conf: 0.12614405093513728
# frozenset({'whipped/sour cream'}) --> frozenset({'whole milk'}) conf: 0.449645390070922
# frozenset({'other vegetables'}) --> frozenset({'whipped/sour cream'}) conf: 0.14923804519180242
# frozenset({'whipped/sour cream'}) --> frozenset({'other vegetables'}) conf: 0.40283687943262414
# frozenset({'root vegetables'}) --> frozenset({'whole milk'}) conf: 0.44869402985074625
# frozenset({'whole milk'}) --> frozenset({'root vegetables'}) conf: 0.19140469558296855
# frozenset({'rolls/buns'}) --> frozenset({'bottled water'}) conf: 0.13156440022111662
# frozenset({'bottled water'}) --> frozenset({'rolls/buns'}) conf: 0.21895124195032198
# frozenset({'soda'}) --> frozenset({'shopping bags'}) conf: 0.14110787172011663
# frozenset({'shopping bags'}) --> frozenset({'soda'}) conf: 0.2497420020639835
# frozenset({'rolls/buns'}) --> frozenset({'sausage'}) conf: 0.1663902708678828
# frozenset({'sausage'}) --> frozenset({'rolls/buns'}) conf: 0.3257575757575758
# frozenset({'sausage'}) --> frozenset({'soda'}) conf: 0.25865800865800864
# frozenset({'soda'}) --> frozenset({'sausage'}) conf: 0.13935860058309038
# frozenset({'tropical fruit'}) --> frozenset({'rolls/buns'}) conf: 0.23449612403100775
# frozenset({'rolls/buns'}) --> frozenset({'tropical fruit'}) conf: 0.1337755666113875
# frozenset({'tropical fruit'}) --> frozenset({'root vegetables'}) conf: 0.2005813953488372
# frozenset({'root vegetables'}) --> frozenset({'tropical fruit'}) conf: 0.19309701492537312
# frozenset({'root vegetables'}) --> frozenset({'other vegetables'}) conf: 0.43470149253731344
# frozenset({'other vegetables'}) --> frozenset({'root vegetables'}) conf: 0.24487651077246453
# frozenset({'rolls/buns'}) --> frozenset({'root vegetables'}) conf: 0.13211719181868434
# frozenset({'root vegetables'}) --> frozenset({'rolls/buns'}) conf: 0.22294776119402987
# frozenset({'rolls/buns'}) --> frozenset({'soda'}) conf: 0.2084024322830293
# frozenset({'soda'}) --> frozenset({'rolls/buns'}) conf: 0.21982507288629738
# frozenset({'citrus fruit'}) --> frozenset({'yogurt'}) conf: 0.2616707616707617
# frozenset({'yogurt'}) --> frozenset({'citrus fruit'}) conf: 0.15524781341107868
# frozenset({'citrus fruit'}) --> frozenset({'whole milk'}) conf: 0.36855036855036855
# frozenset({'whole milk'}) --> frozenset({'citrus fruit'}) conf: 0.11937922801432549
# frozenset({'tropical fruit'}) --> frozenset({'whole milk'}) conf: 0.40310077519379844
# frozenset({'whole milk'}) --> frozenset({'tropical fruit'}) conf: 0.16553919617986468
# frozenset({'yogurt'}) --> frozenset({'bottled water'}) conf: 0.16472303206997083
# frozenset({'bottled water'}) --> frozenset({'yogurt'}) conf: 0.20791168353265868
# frozenset({'whole milk'}) --> frozenset({'bottled water'}) conf: 0.13450059689614005
# frozenset({'bottled water'}) --> frozenset({'whole milk'}) conf: 0.31094756209751606
# frozenset({'curd'}) --> frozenset({'whole milk'}) conf: 0.4904580152671756
# frozenset({'whole milk'}) --> frozenset({'curd'}) conf: 0.10226820533227217
# frozenset({'tropical fruit'}) --> frozenset({'other vegetables'}) conf: 0.34205426356589147
# frozenset({'other vegetables'}) --> frozenset({'tropical fruit'}) conf: 0.18549658434051497
# frozenset({'other vegetables'}) --> frozenset({'bottled water'}) conf: 0.1282186022070415
# frozenset({'bottled water'}) --> frozenset({'other vegetables'}) conf: 0.22447102115915363
# frozenset({'rolls/buns'}) --> frozenset({'other vegetables'}) conf: 0.23161967938087338
# frozenset({'other vegetables'}) --> frozenset({'rolls/buns'}) conf: 0.22017866526537044
# frozenset({'yogurt'}) --> frozenset({'whole milk'}) conf: 0.40160349854227406
# frozenset({'whole milk'}) --> frozenset({'yogurt'}) conf: 0.21925984878631116
# frozenset({'butter'}) --> frozenset({'whole milk'}) conf: 0.4972477064220184
# frozenset({'whole milk'}) --> frozenset({'butter'}) conf: 0.1078392359729407
# frozenset({'other vegetables'}) --> frozenset({'whole milk'}) conf: 0.38675775091960063
# frozenset({'whole milk'}) --> frozenset({'other vegetables'}) conf: 0.2928770393951452
# frozenset({'tropical fruit'}) --> frozenset({'yogurt'}) conf: 0.27906976744186046
# frozenset({'yogurt'}) --> frozenset({'tropical fruit'}) conf: 0.20991253644314867
# frozenset({'yogurt'}) --> frozenset({'whole milk', 'other vegetables'}) conf: 0.1596209912536443
# frozenset({'other vegetables'}) --> frozenset({'whole milk', 'yogurt'}) conf: 0.11508145034156594
# frozenset({'root vegetables'}) --> frozenset({'whole milk', 'other vegetables'}) conf: 0.2126865671641791
# frozenset({'other vegetables'}) --> frozenset({'whole milk', 'root vegetables'}) conf: 0.11981082501313715

# %%
rules
# Out:
# [(frozenset({'yogurt'}),
#   frozenset({'whipped/sour cream'}),
#   0.14868804664723032),
#  (frozenset({'whipped/sour cream'}),
#   frozenset({'yogurt'}),
#   0.2893617021276596),
#  (frozenset({'other vegetables'}), frozenset({'yogurt'}), 0.22438255386232264),
#  (frozenset({'yogurt'}), frozenset({'other vegetables'}), 0.3112244897959184),
#  (frozenset({'pip fruit'}),
#   frozenset({'other vegetables'}),
#   0.3454301075268817),
#  (frozenset({'other vegetables'}),
#   frozenset({'pip fruit'}),
#   0.1350499211770888),
#  (frozenset({'pastry'}), frozenset({'other vegetables'}), 0.2537142857142857),
#  (frozenset({'other vegetables'}), frozenset({'pastry'}), 0.11665790856542302),
#  (frozenset({'other vegetables'}),
#   frozenset({'shopping bags'}),
#   0.11981082501313715),
#  (frozenset({'shopping bags'}),
#   frozenset({'other vegetables'}),
#   0.23529411764705885),
#  (frozenset({'other vegetables'}),
#   frozenset({'sausage'}),
#   0.13925380977404098),
#  (frozenset({'sausage'}), frozenset({'other vegetables'}), 0.2867965367965368),
#  (frozenset({'bottled beer'}), frozenset({'whole milk'}), 0.2537878787878788),
#  (frozenset({'shopping bags'}),
#   frozenset({'whole milk'}),
#   0.24871001031991746),
#  (frozenset({'citrus fruit'}),
#   frozenset({'other vegetables'}),
#   0.34889434889434895),
#  (frozenset({'other vegetables'}),
#   frozenset({'citrus fruit'}),
#   0.14923804519180242),
#  (frozenset({'fruit/vegetable juice'}),
#   frozenset({'whole milk'}),
#   0.36849507735583686),
#  (frozenset({'whole milk'}),
#   frozenset({'fruit/vegetable juice'}),
#   0.10425785913251093),
#  (frozenset({'frankfurter'}), frozenset({'whole milk'}), 0.3482758620689655),
#  (frozenset({'newspapers'}), frozenset({'whole milk'}), 0.34267515923566877),
#  (frozenset({'whole milk'}), frozenset({'newspapers'}), 0.10704337445284519),
#  (frozenset({'margarine'}), frozenset({'whole milk'}), 0.4131944444444444),
#  (frozenset({'pip fruit'}), frozenset({'tropical fruit'}), 0.2701612903225806),
#  (frozenset({'tropical fruit'}), frozenset({'pip fruit'}), 0.1947674418604651),
#  (frozenset({'pip fruit'}), frozenset({'whole milk'}), 0.3978494623655914),
#  (frozenset({'whole milk'}), frozenset({'pip fruit'}), 0.1177875049741345),
#  (frozenset({'rolls/buns'}), frozenset({'whole milk'}), 0.30790491984521834),
#  (frozenset({'whole milk'}), frozenset({'rolls/buns'}), 0.22164743334659767),
#  (frozenset({'beef'}), frozenset({'whole milk'}), 0.4050387596899225),
#  (frozenset({'sausage'}), frozenset({'whole milk'}), 0.3181818181818182),
#  (frozenset({'whole milk'}), frozenset({'sausage'}), 0.11699164345403898),
#  (frozenset({'frozen vegetables'}),
#   frozenset({'whole milk'}),
#   0.4249471458773784),
#  (frozenset({'pastry'}), frozenset({'rolls/buns'}), 0.2354285714285714),
#  (frozenset({'rolls/buns'}), frozenset({'pastry'}), 0.11387506909894968),
#  (frozenset({'fruit/vegetable juice'}),
#   frozenset({'other vegetables'}),
#   0.2911392405063291),
#  (frozenset({'other vegetables'}),
#   frozenset({'fruit/vegetable juice'}),
#   0.10877561744613767),
#  (frozenset({'domestic eggs'}),
#   frozenset({'other vegetables'}),
#   0.35096153846153844),
#  (frozenset({'other vegetables'}),
#   frozenset({'domestic eggs'}),
#   0.11508145034156594),
#  (frozenset({'other vegetables'}), frozenset({'butter'}), 0.10352075669994745),
#  (frozenset({'butter'}), frozenset({'other vegetables'}), 0.3614678899082569),
#  (frozenset({'rolls/buns'}), frozenset({'yogurt'}), 0.18684355997788832),
#  (frozenset({'yogurt'}), frozenset({'rolls/buns'}), 0.2463556851311953),
#  (frozenset({'soda'}), frozenset({'bottled water'}), 0.1661807580174927),
#  (frozenset({'bottled water'}), frozenset({'soda'}), 0.2621895124195032),
#  (frozenset({'tropical fruit'}), frozenset({'soda'}), 0.1986434108527132),
#  (frozenset({'soda'}), frozenset({'tropical fruit'}), 0.11953352769679301),
#  (frozenset({'soda'}), frozenset({'yogurt'}), 0.15685131195335278),
#  (frozenset({'yogurt'}), frozenset({'soda'}), 0.19606413994169095),
#  (frozenset({'pastry'}), frozenset({'whole milk'}), 0.3737142857142857),
#  (frozenset({'whole milk'}), frozenset({'pastry'}), 0.1301233585356148),
#  (frozenset({'root vegetables'}), frozenset({'yogurt'}), 0.2369402985074627),
#  (frozenset({'yogurt'}), frozenset({'root vegetables'}), 0.18513119533527697),
#  (frozenset({'brown bread'}), frozenset({'whole milk'}), 0.3887147335423197),
#  (frozenset({'domestic eggs'}),
#   frozenset({'whole milk'}),
#   0.47275641025641024),
#  (frozenset({'whole milk'}),
#   frozenset({'domestic eggs'}),
#   0.11738957421408674),
#  (frozenset({'pastry'}), frozenset({'soda'}), 0.23657142857142854),
#  (frozenset({'soda'}), frozenset({'pastry'}), 0.1206997084548105),
#  (frozenset({'soda'}), frozenset({'whole milk'}), 0.22973760932944606),
#  (frozenset({'whole milk'}), frozenset({'soda'}), 0.15678471945881414),
#  (frozenset({'other vegetables'}), frozenset({'soda'}), 0.16920651602732528),
#  (frozenset({'soda'}), frozenset({'other vegetables'}), 0.18775510204081633),
#  (frozenset({'pork'}), frozenset({'whole milk'}), 0.3844797178130512),
#  (frozenset({'other vegetables'}), frozenset({'pork'}), 0.11192853389385181),
#  (frozenset({'pork'}), frozenset({'other vegetables'}), 0.37566137566137564),
#  (frozenset({'whole milk'}),
#   frozenset({'whipped/sour cream'}),
#   0.12614405093513728),
#  (frozenset({'whipped/sour cream'}),
#   frozenset({'whole milk'}),
#   0.449645390070922),
#  (frozenset({'other vegetables'}),
#   frozenset({'whipped/sour cream'}),
#   0.14923804519180242),
#  (frozenset({'whipped/sour cream'}),
#   frozenset({'other vegetables'}),
#   0.40283687943262414),
#  (frozenset({'root vegetables'}),
#   frozenset({'whole milk'}),
#   0.44869402985074625),
#  (frozenset({'whole milk'}),
#   frozenset({'root vegetables'}),
#   0.19140469558296855),
#  (frozenset({'rolls/buns'}),
#   frozenset({'bottled water'}),
#   0.13156440022111662),
#  (frozenset({'bottled water'}),
#   frozenset({'rolls/buns'}),
#   0.21895124195032198),
#  (frozenset({'soda'}), frozenset({'shopping bags'}), 0.14110787172011663),
#  (frozenset({'shopping bags'}), frozenset({'soda'}), 0.2497420020639835),
#  (frozenset({'rolls/buns'}), frozenset({'sausage'}), 0.1663902708678828),
#  (frozenset({'sausage'}), frozenset({'rolls/buns'}), 0.3257575757575758),
#  (frozenset({'sausage'}), frozenset({'soda'}), 0.25865800865800864),
#  (frozenset({'soda'}), frozenset({'sausage'}), 0.13935860058309038),
#  (frozenset({'tropical fruit'}),
#   frozenset({'rolls/buns'}),
#   0.23449612403100775),
#  (frozenset({'rolls/buns'}),
#   frozenset({'tropical fruit'}),
#   0.1337755666113875),
#  (frozenset({'tropical fruit'}),
#   frozenset({'root vegetables'}),
#   0.2005813953488372),
#  (frozenset({'root vegetables'}),
#   frozenset({'tropical fruit'}),
#   0.19309701492537312),
#  (frozenset({'root vegetables'}),
#   frozenset({'other vegetables'}),
#   0.43470149253731344),
#  (frozenset({'other vegetables'}),
#   frozenset({'root vegetables'}),
#   0.24487651077246453),
#  (frozenset({'rolls/buns'}),
#   frozenset({'root vegetables'}),
#   0.13211719181868434),
#  (frozenset({'root vegetables'}),
#   frozenset({'rolls/buns'}),
#   0.22294776119402987),
#  (frozenset({'rolls/buns'}), frozenset({'soda'}), 0.2084024322830293),
#  (frozenset({'soda'}), frozenset({'rolls/buns'}), 0.21982507288629738),
#  (frozenset({'citrus fruit'}), frozenset({'yogurt'}), 0.2616707616707617),
#  (frozenset({'yogurt'}), frozenset({'citrus fruit'}), 0.15524781341107868),
#  (frozenset({'citrus fruit'}), frozenset({'whole milk'}), 0.36855036855036855),
#  (frozenset({'whole milk'}), frozenset({'citrus fruit'}), 0.11937922801432549),
#  (frozenset({'tropical fruit'}),
#   frozenset({'whole milk'}),
#   0.40310077519379844),
#  (frozenset({'whole milk'}),
#   frozenset({'tropical fruit'}),
#   0.16553919617986468),
#  (frozenset({'yogurt'}), frozenset({'bottled water'}), 0.16472303206997083),
#  (frozenset({'bottled water'}), frozenset({'yogurt'}), 0.20791168353265868),
#  (frozenset({'whole milk'}),
#   frozenset({'bottled water'}),
#   0.13450059689614005),
#  (frozenset({'bottled water'}),
#   frozenset({'whole milk'}),
#   0.31094756209751606),
#  (frozenset({'curd'}), frozenset({'whole milk'}), 0.4904580152671756),
#  (frozenset({'whole milk'}), frozenset({'curd'}), 0.10226820533227217),
#  (frozenset({'tropical fruit'}),
#   frozenset({'other vegetables'}),
#   0.34205426356589147),
#  (frozenset({'other vegetables'}),
#   frozenset({'tropical fruit'}),
#   0.18549658434051497),
#  (frozenset({'other vegetables'}),
#   frozenset({'bottled water'}),
#   0.1282186022070415),
#  (frozenset({'bottled water'}),
#   frozenset({'other vegetables'}),
#   0.22447102115915363),
#  (frozenset({'rolls/buns'}),
#   frozenset({'other vegetables'}),
#   0.23161967938087338),
#  (frozenset({'other vegetables'}),
#   frozenset({'rolls/buns'}),
#   0.22017866526537044),
#  (frozenset({'yogurt'}), frozenset({'whole milk'}), 0.40160349854227406),
#  (frozenset({'whole milk'}), frozenset({'yogurt'}), 0.21925984878631116),
#  (frozenset({'butter'}), frozenset({'whole milk'}), 0.4972477064220184),
#  (frozenset({'whole milk'}), frozenset({'butter'}), 0.1078392359729407),
#  (frozenset({'other vegetables'}),
#   frozenset({'whole milk'}),
#   0.38675775091960063),
#  (frozenset({'whole milk'}),
#   frozenset({'other vegetables'}),
#   0.2928770393951452),
#  (frozenset({'tropical fruit'}), frozenset({'yogurt'}), 0.27906976744186046),
#  (frozenset({'yogurt'}), frozenset({'tropical fruit'}), 0.20991253644314867),
#  (frozenset({'yogurt'}),
#   frozenset({'other vegetables', 'whole milk'}),
#   0.1596209912536443),
#  (frozenset({'other vegetables'}),
#   frozenset({'whole milk', 'yogurt'}),
#   0.11508145034156594),
#  (frozenset({'root vegetables'}),
#   frozenset({'other vegetables', 'whole milk'}),
#   0.2126865671641791),
#  (frozenset({'other vegetables'}),
#   frozenset({'root vegetables', 'whole milk'}),
#   0.11981082501313715)]

# %% [markdown]
# ## **예제: 독버섯과 유사한 속성 찾기**

# %% [markdown]
# apriori 알고리즘을 이용해 독버섯의 공통적인 속성을 찾아보자.

# %%
mushDatSet = [line.split() for line in open('mushroom.dat').readlines()]

# %% [markdown]
# 이제 이 데이터 집합으로 어프라이어리 알고리즘을 수행해 보자.

# %%
L, suppData = apriori.apriori(mushDatSet, minSupport=0.3)

# %% [markdown]
# 독성에 대한 두 가지 속성에 대해 빈발 아이템 집합을 검색해 보자.

# %%
for item in L[1]:
    if item.intersection('2'): print(item)
# Out:
# frozenset({'2', '28'})
# frozenset({'2', '53'})
# frozenset({'2', '23'})
# frozenset({'2', '34'})
# frozenset({'2', '36'})
# frozenset({'2', '59'})
# frozenset({'2', '63'})
# frozenset({'2', '67'})
# frozenset({'2', '76'})
# frozenset({'2', '85'})
# frozenset({'2', '86'})
# frozenset({'2', '90'})
# frozenset({'2', '93'})
# frozenset({'39', '2'})

# %% [markdown]
# 또한, 큰 데이터 집합에 대해 반복할 수도 있다.

# %%
for item in L[3]:
    if item.intersection('2'): print(item)
# Out:
# frozenset({'63', '2', '34', '28'})
# frozenset({'85', '2', '34', '28'})
# frozenset({'86', '2', '34', '28'})
# frozenset({'90', '2', '34', '28'})
# frozenset({'2', '59', '34', '28'})
# frozenset({'63', '2', '59', '28'})
# frozenset({'85', '2', '59', '28'})
# frozenset({'86', '2', '59', '28'})
# frozenset({'90', '2', '59', '28'})
# frozenset({'63', '85', '2', '28'})
# frozenset({'86', '63', '2', '28'})
# frozenset({'86', '85', '2', '28'})
# frozenset({'86', '90', '2', '28'})
# frozenset({'90', '85', '2', '28'})
# frozenset({'2', '39', '59', '28'})
# frozenset({'39', '2', '34', '28'})
# frozenset({'63', '39', '2', '28'})
# frozenset({'85', '39', '2', '28'})
# frozenset({'86', '39', '2', '28'})
# frozenset({'90', '39', '2', '28'})
# frozenset({'53', '85', '2', '34'})
# frozenset({'86', '53', '2', '34'})
# frozenset({'53', '90', '2', '34'})
# frozenset({'53', '2', '34', '28'})
# frozenset({'53', '85', '2', '28'})
# frozenset({'86', '53', '85', '2'})
# frozenset({'86', '53', '90', '2'})
# frozenset({'86', '53', '2', '28'})
# frozenset({'53', '90', '2', '28'})
# frozenset({'53', '90', '85', '2'})
# frozenset({'53', '39', '2', '34'})
# frozenset({'53', '85', '39', '2'})
# frozenset({'86', '53', '39', '2'})
# frozenset({'53', '90', '39', '2'})
# frozenset({'53', '39', '2', '28'})
# frozenset({'63', '85', '2', '23'})
# frozenset({'90', '85', '2', '23'})
# frozenset({'85', '2', '23', '93'})
# frozenset({'90', '2', '23', '93'})
# frozenset({'36', '2', '34', '23'})
# frozenset({'2', '59', '34', '23'})
# frozenset({'63', '2', '34', '23'})
# frozenset({'85', '2', '34', '23'})
# frozenset({'63', '85', '2', '34'})
# frozenset({'85', '2', '34', '67'})
# frozenset({'85', '2', '34', '76'})
# frozenset({'86', '2', '34', '23'})
# frozenset({'86', '63', '2', '34'})
# frozenset({'86', '2', '34', '67'})
# frozenset({'86', '2', '34', '76'})
# frozenset({'86', '85', '2', '34'})
# frozenset({'90', '2', '34', '23'})
# frozenset({'90', '63', '2', '34'})
# frozenset({'90', '85', '2', '34'})
# frozenset({'86', '90', '2', '34'})
# frozenset({'2', '34', '23', '93'})
# frozenset({'63', '2', '34', '93'})
# frozenset({'85', '2', '34', '93'})
# frozenset({'86', '2', '34', '93'})
# frozenset({'90', '2', '34', '93'})
# frozenset({'36', '2', '59', '23'})
# frozenset({'36', '2', '59', '34'})
# frozenset({'36', '63', '2', '23'})
# frozenset({'36', '63', '2', '34'})
# frozenset({'36', '63', '2', '59'})
# frozenset({'36', '85', '2', '23'})
# frozenset({'36', '85', '2', '34'})
# frozenset({'36', '85', '2', '59'})
# frozenset({'36', '63', '85', '2'})
# frozenset({'36', '86', '2', '23'})
# frozenset({'36', '86', '2', '34'})
# frozenset({'36', '86', '2', '59'})
# frozenset({'36', '86', '63', '2'})
# frozenset({'36', '86', '85', '2'})
# frozenset({'36', '90', '2', '34'})
# frozenset({'36', '90', '2', '59'})
# frozenset({'36', '90', '63', '2'})
# frozenset({'36', '90', '85', '2'})
# frozenset({'36', '86', '90', '2'})
# frozenset({'36', '2', '23', '93'})
# frozenset({'36', '2', '34', '93'})
# frozenset({'36', '2', '59', '93'})
# frozenset({'36', '63', '2', '93'})
# frozenset({'36', '85', '2', '93'})
# frozenset({'36', '86', '2', '93'})
# frozenset({'36', '90', '2', '93'})
# frozenset({'63', '2', '59', '23'})
# frozenset({'63', '2', '59', '34'})
# frozenset({'85', '2', '59', '23'})
# frozenset({'85', '2', '59', '34'})
# frozenset({'63', '85', '2', '59'})
# frozenset({'86', '2', '59', '23'})
# frozenset({'86', '2', '59', '34'})
# frozenset({'86', '63', '2', '59'})
# frozenset({'86', '85', '2', '59'})
# frozenset({'90', '2', '59', '23'})
# frozenset({'90', '2', '59', '34'})
# frozenset({'90', '63', '2', '59'})
# frozenset({'90', '85', '2', '59'})
# frozenset({'86', '90', '2', '59'})
# frozenset({'2', '59', '23', '93'})
# frozenset({'2', '59', '34', '93'})
# frozenset({'63', '2', '59', '93'})
# frozenset({'85', '2', '59', '93'})
# frozenset({'86', '2', '59', '93'})
# frozenset({'90', '2', '59', '93'})
# frozenset({'86', '63', '2', '23'})
# frozenset({'86', '85', '2', '23'})
# frozenset({'86', '63', '85', '2'})
# frozenset({'86', '85', '2', '67'})
# frozenset({'86', '85', '2', '76'})
# frozenset({'90', '85', '63', '2'})
# frozenset({'63', '85', '2', '93'})
# frozenset({'86', '90', '2', '23'})
# frozenset({'86', '90', '63', '2'})
# frozenset({'86', '90', '85', '2'})
# frozenset({'86', '2', '23', '93'})
# frozenset({'86', '63', '2', '93'})
# frozenset({'86', '85', '2', '93'})
# frozenset({'86', '90', '2', '93'})
# frozenset({'90', '63', '2', '93'})
# frozenset({'90', '85', '2', '93'})
# frozenset({'39', '2', '34', '23'})
# frozenset({'36', '39', '2', '23'})
# frozenset({'36', '39', '2', '34'})
# frozenset({'2', '39', '59', '23'})
# frozenset({'2', '39', '59', '34'})
# frozenset({'36', '2', '39', '59'})
# frozenset({'2', '63', '39', '59'})
# frozenset({'2', '85', '39', '59'})
# frozenset({'2', '86', '39', '59'})
# frozenset({'2', '90', '39', '59'})
# frozenset({'2', '39', '59', '93'})
# frozenset({'63', '39', '2', '23'})
# frozenset({'63', '39', '2', '34'})
# frozenset({'36', '63', '39', '2'})
# frozenset({'39', '2', '34', '67'})
# frozenset({'39', '2', '34', '76'})
# frozenset({'85', '39', '2', '23'})
# frozenset({'85', '39', '2', '34'})
# frozenset({'36', '85', '39', '2'})
# frozenset({'63', '85', '39', '2'})
# frozenset({'85', '39', '2', '67'})
# frozenset({'85', '39', '2', '76'})
# frozenset({'86', '39', '2', '23'})
# frozenset({'86', '39', '2', '34'})
# frozenset({'36', '86', '39', '2'})
# frozenset({'86', '63', '39', '2'})
# frozenset({'86', '39', '2', '67'})
# frozenset({'86', '39', '2', '76'})
# frozenset({'86', '85', '39', '2'})
# frozenset({'90', '39', '2', '34'})
# frozenset({'36', '90', '39', '2'})
# frozenset({'90', '63', '39', '2'})
# frozenset({'90', '85', '39', '2'})
# frozenset({'86', '90', '39', '2'})
# frozenset({'39', '2', '23', '93'})
# frozenset({'39', '2', '34', '93'})
# frozenset({'36', '39', '2', '93'})
# frozenset({'63', '39', '2', '93'})
# frozenset({'85', '39', '2', '93'})
# frozenset({'86', '39', '2', '93'})
# frozenset({'90', '39', '2', '93'})

# %% [markdown]
# 이제 독성이 있는 버섯들의 속성이 어떤 것들이 있는지 살펴보고 이 속성에 따라 독성이 있음을 알아낼 수 있다.
